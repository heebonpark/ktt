# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.1.4)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.1)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.0)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.3)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.60.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl (356 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 6.2 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 8.9 MB/s eta 0:00:00
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 23.4 MB/s eta 0:00:00
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 5.8 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 18.7 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=aad0beb215346584b6290153129f91e44d54d139c943d984b8d36408016984f7
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, PyWavelets, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed PyWavelets-1.7.0 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 visions-0.7.6 ydata-profiling-4.9.0

# %%
import pandas as pd
import os
import glob
import zipfile
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles import Border, Side, Alignment, PatternFill, Font
from google.colab import drive
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.backends.backend_pdf import PdfPages

# 한글 폰트 설치 및 설정
# !apt-get install -y fonts-nanum
plt.rcParams['font.family'] = 'NanumGothic'

# 구글 드라이브를 마운트합니다.
drive.mount('/content/drive', force_remount=True)

# 압축 파일 경로 및 압축 해제 경로 설정
zip_file_path = '/content/drive/My Drive/회사업무/인허가_0812/LOCALDATA_YESTERDAY_CSV 2.zip'  # 실제 파일 경로로 변경
extract_folder = '/content/extracted_data'

# 폴더가 없으면 생성
os.makedirs(extract_folder, exist_ok=True)

# 압축 해제
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
except FileNotFoundError:
    print(f"Error: Specified zip file '{zip_file_path}' not found. Please check the path.")
    exit(1)

# 압축 해제된 폴더에서 모든 CSV 파일 목록 가져오기
all_files = glob.glob(os.path.join(extract_folder, "**/*.csv"), recursive=True)

if len(all_files) == 0:
    print("Warning: No CSV files found in the specified directory. Proceeding with an empty DataFrame.")
    dfs = []  # 빈 리스트로 초기화
else:
    # 각 파일을 읽어서 하나의 DataFrame으로 병합
    dfs = []
    for file in all_files:
        try:
            df = pd.read_csv(file, encoding='cp949', on_bad_lines='skip', dtype=str, low_memory=False)
            # 주소라는 키워드를 포함한 열 확인
            address_columns = [col for col in df.columns if '주소' in col]
            if not address_columns:
                print(f"No address column found in file: {file}")
                continue
            # '서울', '경기', '강원'이 포함된 행 필터링
            df_filtered = df[df[address_columns[0]].str.contains('서울|경기|강원', na=False)]
            dfs.append(df_filtered)
            print(f"Successfully read and filtered file: {file}")
        except Exception as e:
            print(f"Error reading file {file}: {e}")

if len(dfs) == 0:
    concatenated_df = pd.DataFrame()  # 이전 단계에서 파일이 없을 경우 빈 DataFrame 생성
else:
    concatenated_df = pd.concat(dfs, ignore_index=True)
    # 중복된 행 제거: 사업장명, 소재지전체주소, 영업상태명이 동일한 경우 하나만 남기고 제거
    concatenated_df.drop_duplicates(subset=['사업장명', '소재지전체주소', '영업상태명'], inplace=True)

    # '인허가일자' 기준으로 내림차순 정렬
    if '인허가일자' in concatenated_df.columns:
        concatenated_df['인허가일자'] = pd.to_datetime(concatenated_df['인허가일자'], format='%Y%m%d', errors='coerce')
        concatenated_df.sort_values(by='인허가일자', ascending=False, inplace=True)

# 필요한 열만 선택하여 필터링
selected_columns = ['소재지전체주소', '도로명전체주소', '도로명우편번호', '사업장명', '개방서비스명', '인허가일자', '인허가취소', '영업상태명', '폐업일자',
                    '휴업시작일', '휴업종료일', '재개업일자', '소재지전화', '최종수정시점', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '총면적', '소재지면적']

# 존재하는 열만 선택
existing_columns = [col for col in selected_columns if col in concatenated_df.columns]
filtered_df = concatenated_df[existing_columns]

# CSV 파일로 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
os.makedirs(output_dir, exist_ok=True)
output_csv_path = os.path.join(output_dir, '1.14일_병합(서울,경기,강원).csv')
filtered_df.to_csv(output_csv_path, index=False, encoding='cp949')

# 엑셀 파일 경로 설정
file1_path = os.path.join('/content/drive/My Drive/회사업무/행안부자료/0801', '1.영업구역별_주소현행화0725.xlsx')
file2_path = output_csv_path  # 이전 단계에서 생성한 파일 사용

# 파일 경로 확인
if not os.path.exists(file1_path):
    raise FileNotFoundError(f"{file1_path} 파일이 존재하지 않습니다. 경로를 확인하세요.")
if not os.path.exists(file2_path):
    raise FileNotFoundError(f"{file2_path} 파일이 존재하지 않습니다. 경로를 확인하세요.")

# 엑셀 파일 읽기
df1 = pd.read_excel(file1_path)
df2 = pd.read_csv(file2_path, encoding='cp949')

# 주소 정규화 함수
def normalize_address(address):
    if pd.isna(address):
        return address
    address = address.strip()
    address = address.replace('강원특별자치도', '강원도')
    address = address.replace('서울특별시', '서울시')
    if '*' in address:
        return None
    return address

# df1의 주소 정규화
df1['full_address'] = df1[['주소시', '주소군구', '주소동']].astype(str).agg(' '.join, axis=1).apply(normalize_address)
df1 = df1.dropna(subset=['full_address'])

# df2의 주소 정규화
df2['소재지전체주소'] = df2['소재지전체주소'].astype(str).apply(normalize_address)
df2['도로명전체주소'] = df2['도로명전체주소'].astype(str).apply(normalize_address)
df2 = df2.dropna(subset=['소재지전체주소', '도로명전체주소'])

# TF-IDF 벡터화
vectorizer = TfidfVectorizer().fit(df1['full_address'])
tfidf_matrix = vectorizer.transform(df1['full_address'])

# 유사한 주소 매핑
def get_best_match(address, tfidf_matrix, vectorizer, choices, threshold=0.7):
    if pd.isna(address):
        return None
    query_vec = vectorizer.transform([address])
    cosine_similarities = cosine_similarity(query_vec, tfidf_matrix).flatten()
    best_match_index = cosine_similarities.argmax()
    best_match_score = cosine_similarities[best_match_index]
    if best_match_score >= threshold:
        return choices[best_match_index]
    return None

choices = df1['full_address'].tolist()
df2['matched_address_소재지'] = df2['소재지전체주소'].apply(lambda x: get_best_match(x, tfidf_matrix, vectorizer, choices))
df2['matched_address_도로명'] = df2['도로명전체주소'].apply(lambda x: get_best_match(x, tfidf_matrix, vectorizer, choices))

df2['matched_address'] = df2.apply(lambda x: x['matched_address_소재지'] if pd.notna(x['matched_address_소재지']) else x['matched_address_도로명'], axis=1)

# 매핑되지 않은 항목 확인
unmatched = df2[df2['matched_address'].isna()]
print("매핑되지 않은 항목 수:", len(unmatched))

# 평수 계산을 위한 열 존재 확인 및 병합
merge_columns = ['full_address', '관리지사', 'SP담당']
if '총면적' in df1.columns:
    merge_columns.append('총면적')
if '소재지면적' in df1.columns:
    merge_columns.append('소재지면적')

df_merged = df2.merge(df1[merge_columns], left_on='matched_address', right_on='full_address', how='left', suffixes=('', '_df1'))

# 매핑 결과 확인
print("매핑 후 관리지사 및 SP담당이 비어있는 행 수:", df_merged[['관리지사', 'SP담당']].isna().sum())

# 평수 계산 (1평 = 3.305785 m^2)
def calculate_area(row):
    if '소재지면적' in row and pd.notna(row['소재지면적']):
        return round(row['소재지면적'] / 3.305785, 2)
    elif '총면적' in row and pd.notna(row['총면적']):
        return round(row['총면적'] / 3.305785, 2)
# 평수 계산을 이어서 실행
    else:
        return None

df_merged['평수'] = df_merged.apply(calculate_area, axis=1)

# 불필요한 열 제외하고 필요한 열만 선택
columns_to_keep = ['관리지사', 'SP담당', '사업장명', '개방서비스명', '업태구분명', '평수', '소재지전체주소', '도로명전체주소', '소재지전화', '폐업일자', '재개업일자', '영업상태명']
df_filtered = df_merged[columns_to_keep]

# 중복된 항목 제거
df_filtered.drop_duplicates(inplace=True)

# 평수 내림차순 정렬
df_filtered_sorted = df_filtered.sort_values(by='평수', ascending=False)

# NaN 값 처리
df_filtered_sorted['관리지사'] = df_filtered_sorted['관리지사'].fillna('Unknown')
df_filtered_sorted['SP담당'] = df_filtered_sorted['SP담당'].fillna('Unknown')

# 네이버 지도 하이퍼링크 생성 함수
def create_naver_map_link(address):
    return f"https://map.naver.com/v5/search/{address}"

# 엑셀 파일에 네이버 지도 링크 추가하는 함수
def add_naver_map_links(ws, address_col_idx):
    ws.insert_cols(1)  # 첫 번째 열에 열 추가
    ws.cell(row=1, column=1, value="네이버 지도 링크")  # 새 열에 헤더 추가

    for row in range(2, ws.max_row + 1):
        address = ws.cell(row=row, column=address_col_idx + 1).value
        if address:
            link = create_naver_map_link(address)
            ws.cell(row=row, column=1).hyperlink = link
            ws.cell(row=row, column=1).value = "네이버 지도 보기"
            ws.cell(row=row, column=1).style = "Hyperlink"

# 엑셀 파일에 데이터를 저장하고 스타일을 설정하는 함수
def save_to_excel(df, file_path):
    with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
        # 전체 시트 저장
        df.to_excel(writer, index=False, sheet_name='전체')

        # 영업/정상 시트 저장
        df_active = df[df['영업상태명'].isin(['영업/정상'])]
        df_active.to_excel(writer, index=False, sheet_name='영업_정상')

        # 폐업 시트 저장
        df_closed = df[df['영업상태명'] == '폐업']
        df_closed.to_excel(writer, index=False, sheet_name='폐업')

        workbook = writer.book
        thin_border = Border(left=Side(style='thin', color='D3D3D3'),
                             right=Side(style='thin', color='D3D3D3'),
                             top=Side(style='thin', color='D3D3D3'),
                             bottom=Side(style='thin', color='D3D3D3'))
        header_fill = PatternFill(start_color="000080", end_color="000080", fill_type="solid")
        header_font = Font(color="FFFFFF", bold=True)

        # 스타일 설정 함수
        def set_style(worksheet):
            for cell in worksheet[1]:
                cell.fill = header_fill
                cell.font = header_font
                cell.border = thin_border
                cell.alignment = Alignment(horizontal='center', vertical='center')
            for row in worksheet.iter_rows(min_row=2):
                for cell in row:
                    cell.border = thin_border
                    cell.alignment = Alignment(horizontal='center', vertical='center')
            for col in worksheet.columns:
                max_length = 0
                column = col[0].column_letter
                for cell in col:
                    try:
                        if len(str(cell.value)) > max_length:
                            max_length = len(cell.value)
                    except:
                        pass
                adjusted_width = (max_length + 2)
                worksheet.column_dimensions[column].width = adjusted_width

        set_style(writer.sheets['전체'])
        set_style(writer.sheets['영업_정상'])
        set_style(writer.sheets['폐업'])

        # 네이버 지도 링크 추가
        # '소재지전체주소'는 H열이므로 컬럼 인덱스는 8-1=7
        add_naver_map_links(writer.sheets['전체'], 7)
        add_naver_map_links(writer.sheets['영업_정상'], 7)
        add_naver_map_links(writer.sheets['폐업'], 7)

# 전체 데이터를 바탕으로 시각화 및 파일 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
for manager in df_filtered_sorted['관리지사'].unique():
    manager_dir = os.path.join(output_dir, manager)
    os.makedirs(manager_dir, exist_ok=True)
    df_manager = df_filtered_sorted[df_filtered_sorted['관리지사'] == manager]

    for sp in df_manager['SP담당'].unique():
        df_sp = df_manager[df_manager['SP담당'] == sp]
        sp_file_path = os.path.join(manager_dir, f'{manager}_{sp}_0814일.xlsx')
        save_to_excel(df_sp, sp_file_path)

# 전체 데이터를 저장
total_file_path = os.path.join(output_dir, '0814일_전체_최종결과물.xlsx')
save_to_excel(df_filtered_sorted, total_file_path)

# 전체 데이터를 바탕으로 시각화
status_counts = df_filtered_sorted.groupby(['관리지사', '영업상태명']).size().unstack(fill_value=0)
status_counts = status_counts.loc[status_counts.sum(axis=1).sort_values(ascending=False).index]

# 시각화 및 PDF 저장
pdf_path = os.path.join(output_dir, '전체_영업상태명_집계현황.pdf')
with PdfPages(pdf_path) as pdf:
    # 시각화 1: 관리지사별 영업상태명 집계현황
    fig1, ax1 = plt.subplots(figsize=(14, 10))
    status_counts.plot(kind='bar', stacked=True, ax=ax1, color=['skyblue', 'salmon'])
    ax1.set_title('관리지사별 영업상태명 집계현황', fontsize=16)
    ax1.set_xlabel('관리지사', fontsize=12)
    ax1.set_ylabel('건수', fontsize=12)
    ax1.legend(title='영업상태명', fontsize=10, title_fontsize='13')
    plt.xticks(rotation=90)
    plt.tight_layout()
    pdf.savefig(fig1)
    plt.close(fig1)

    # 시각화 2: SP담당자별 영업상태명 집계현황
    df_filtered_sorted['SP담당자'] = df_filtered_sorted['관리지사'].str.replace('지사', '') + '-' + df_filtered_sorted['SP담당']
    status_counts_sp = df_filtered_sorted.groupby(['SP담당자', '영업상태명']).size().unstack(fill_value=0)
    status_counts_sp = status_counts_sp.loc[status_counts_sp.sum(axis=1).sort_values(ascending=True).index]

    fig2, ax2 = plt.subplots(figsize=(16, 12))
    status_counts_sp.plot(kind='barh', stacked=True, ax=ax2, color=['#4caf50', '#f44336'])
    ax2.set_title('SP담당자별 영업상태명 집계현황', fontsize=18)
    ax2.set_xlabel('건수', fontsize=14)
    ax2.set_ylabel('SP담당자', fontsize=14)
    plt.tight_layout()
    pdf.savefig(fig2)
    plt.close(fig2)

print(f"전체 영업상태명 집계현황 PDF가 생성되었습니다: {pdf_path}")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (8,785 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Mounted at /content/drive
# Successfully read and filtered file: /content/extracted_data/20240812_03_08_01_P_▒╣┴ª╚╕└╟▒Γ╚╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_03_P_░ⁿ▒ñ└»╢≈╝▒╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_24_05_P_╚▐░╘└╜╜─┴í.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_11_P_└ⁿ┼δ╗τ┬√.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_09_01_P_│δ╖í┐¼╜└└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_42_01_P_├╝╖┬┤▄╖├└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_25_01_P_┤δ▒╘╕≡┴í╞≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_26_04_P_┼δ╜┼╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_09_P_╣Φ├Γ░í╜║└ⁿ╣«┴ñ║±╗τ╛≈└┌╚«└╬░╦╗τ┤δ╟α└┌.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_47_01_P_╗≤┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_14_04_P_└╜╣▌╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_06_P_▒▐╝÷░°╗τ┤δ╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_29_02_P_┴÷╟╧╝÷┐╡╟Γ┴╢╗τ▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_38_01_P_╜┬╕╢└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_33_02_P_╣½╡╡╟╨┐°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_06_P_╜─└░╞≈└σ├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_04_P_▒╣┴ª╚╕└╟╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_19_P_┴∩╝«╞╟╕┼┴ª┴╢░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_02_P_░╟░¡▒Γ┤╔╜─╟░└»┼δ└ⁿ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_06_P_┴╛├α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_29_01_P_┴÷╟╧╝÷╜├░°╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_02_P_░Φ╖«▒Γ╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_08_P_│≤╛ε├╠╣╬╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_02_04_P_─í░·▒Γ░°╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_21_01_P_└º┼╣▒▐╜─┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_06_P_└╧╣▌░╘└╙┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_14_01_P_┐┬╢≤└╬└╜╛╟╝¡║±╜║┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_11_P_╜─╟░┴ª┴╢░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_05_18_01_P_╣╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_14_05_P_└╜╣▌╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_06_03_P_░ⁿ▒ñ▒╪└σ└»╚∩╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_15_P_┐δ▒Γíñ╞≈└σ┴÷┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_08_P_└╟╖ß╣²└╬.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_35_01_P_╝÷┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_10_P_║╨┤ó╝÷┴²┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_49_01_P_┐Σ╛τ║╕╚ú╗τ▒│└░▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_03_P_░╟░¡▒Γ┤╔╜─╟░└╧╣▌╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_27_03_P_┴ª└τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_04_P_░Φ╖«▒Γ┴⌡╕φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_14_P_┴÷╣µ╣«╚¡┐°.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_48_02_P_╜┬░¡▒Γ┴ª┴╢╣╫╝÷└╘╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_10_P_└╟╖ß└»╗τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_39_01_P_╜Σ╕┼└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_08_P_╜─╟░╝╥║╨╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_21_P_╜─┐δ╛≤└╜╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_14_P_┐╦▒Γ╖∙┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_40_01_P_┐Σ╞«└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_05_P_└╬┼═│▌──╟╗┼═░╘└╙╜├╝│┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_08_03_P_╣«╚¡┐╣╝·╣²└╬.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_01_P_░Φ╖«▒Γ╝÷╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_04_16_01_P_└╬╝Γ╗τ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_02_03_P_└╟╖ß▒Γ▒Γ╞╟╕┼└╙┤δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_04_P_┐▄▒╣└╬░ⁿ▒ñ╡╡╜├╣╬╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_02_P_░í├α└╬░°╝÷┴ñ╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_03_P_░Φ╖«▒Γ┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_10_05_P_║±╡≡┐└╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_24_01_P_░ⁿ▒ñ╜─┤τ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_18_P_┴ª░·┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_01_P_░ⁿ▒ñ╝≈╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_12_P_╡┐╣░┐ε╝█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_23_02_P_└»╚∩┴╓┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_12_P_╜─╟░├╖░í╣░┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_29_03_P_┴÷╟╧╝÷┴ñ╚¡╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_07_P_└└▒▐╚»└┌└╠╝█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_03_P_░│└╬╟╧╝÷├│╕«╜├╝│░ⁿ╕«╛≈╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_13_P_╜─╟░╞╟╕┼╛≈▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_31_01_P_░±╟┴┐¼╜└└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_07_P_╝«└»╣╫╝«└»┤δ├╝┐¼╖ß╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_05_P_╛╚└ⁿ╗≤║±└╟╛α╟░╞╟╕┼╛≈╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_31_02_P_░±╟┴└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_31_03_P_╡ε╖╧├╝└░╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_05_P_╗τ╖ß┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_03_P_╝≈╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_18_P_╚»░µ─┴╝│╞├╚╕╗τ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_21_02_P_┴²┤▄▒▐╜─╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_10_P_└ⁿ╣«╚▐╛τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_34_01_P_║∙╗≤└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_36_01_P_╜║┼░└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_24_P_├α╗Ω╣░║╕░ⁿ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_10_P_╜─╟░└┌╡┐╞╟╕┼▒Γ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_05_P_└┌╡┐┬≈╛▀┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_12_P_╝÷┴·┐└┐░┐°╝│─í╜├╝│▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_09_P_╛╫╚¡╝«└»░í╜║┐δ╟░┴ª┴╢╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_03_P_╡╡├α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_11_P_╝╥╡╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_06_02_P_░ⁿ▒ñ░°┐¼└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_27_01_P_╕±└τ╝÷└╘└»┼δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_04_P_╗Ω╚─┴╢╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_48_01_P_╜┬░¡▒Γ└»┴÷░ⁿ╕«╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_08_02_P_┤δ┴▀╣«╚¡┐╣╝·▒Γ╚╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_04_P_║╬╚¡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_02_P_░╘└╙╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_02_P_░í├α║╨┤ó╣Φ├Γ╜├╝│░ⁿ╕«╛≈╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_26_03_P_└ⁿ╚¡▒╟└»╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_08_P_└»┐°╜├╝│╛≈▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_11_P_╡┐╣░╣╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_09_P_╜─╟░┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_10_P_└╧╣▌╡╡╜├░í╜║╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_07_P_├╗╝╥│Γ░╘└╙┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_24_02_P_░ⁿ▒ñ└»╚∩└╜╜─┴í╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_44_01_P_╕±┐σ└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_10_04_P_║±╡≡┐└╣░╜├├╗┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_04_P_├α╗Ω╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_23_01_P_┤▄╢⌡┴╓┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_08_P_┤δ▒Γ┐└┐░╣░┴·╣Φ├Γ╜├╝│╝│─í╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_13_03_P_┐╡╚¡╗≤┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_17_P_╚»░µ├°┴ñ┤δ╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_04_15_01_P_┐┴┐▄▒ñ░φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_02_P_░ⁿ▒ñ╞µ╝╟╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_13_04_P_┐╡╚¡╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_10_01_P_║±╡≡┐└╣░░¿╗≤╜╟╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_08_P_╝«└»╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_14_02_P_└╜╣▌.└╜╛╟┐╡╗≤╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_24_03_P_┐▄▒╣└╬└ⁿ┐δ└»╚∩└╜╜─┴í╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_13_02_P_┐╡╚¡╗≤┐╡░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_04_P_║╣╟╒└»┼δ░╘└╙┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_12_P_┴╛╟╒└»┐°╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_04_01_P_░í├α╗τ└░╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_01_P_┴²┤▄▒▐╜─╝╥╜─╟░╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_03_P_║╣╟╒┐╡╗≤╣░┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_01_P_║┤┐°.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_05_P_╡┐╣░└σ╣ª╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_13_P_╛▓╖╣▒Γ┴╛╖«┴ª║└┼⌡╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_49_02_P_└σ╖╩┴÷╡╡╗τ▒│└░▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_07_P_┤▄╡╢┴ñ╚¡┴╢┐└╝÷├│╕«╜├╝│╝│░Φ╜├░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_16_P_╚»░µ└ⁿ╣«░°╗τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_08_P_╡┐╣░╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_41_01_P_├╝└░╡╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_04_P_░╟╣░└º╗²░ⁿ╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_46_01_P_╣╬╣µ└º▒▐╝÷╜├╝│.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_50_02_P_└»╖ß┴≈╛≈╝╥░│╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_37_01_P_┴╛╟╒├╝└░╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_03_P_╡┐╣░┐δ└╟╖ß┐δ▒╕╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_45_02_P_╣░╖∙├ó░φ╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_26_05_P_╚─┐°╣µ╣«╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_25_P_├α╗Ω╣░┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_05_P_░╟╝│╞≤▒Γ╣░├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_12_P_└ⁿ╖┬▒Γ╝·░¿╕«╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_01_P_░ⁿ▒ñ▒╦╡╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_05_01_P_░╘└╙╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_02_P_░ⁿ▒ñ╗τ╛≈└┌.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_17_P_└»┼δ└ⁿ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_14_P_╞»┴ñ░φ╛╨░í╜║╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_07_P_└╧╣▌╛▀┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_11_06_P_╟╤┐┴├╝╟Φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_03_P_║╬╝╙└╟╖ß▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_32_01_P_┤τ▒╕└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_43_02_P_┤π╣Φ╝╥╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_14_03_P_└╜╣▌.└╜╛╟┐╡╗≤╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_05_19_01_P_└╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_05_P_╣┌╣░░ⁿ,╣╠╝·░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_02_02_P_└╟╖ß▒Γ▒Γ╝÷╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_06_P_╡┐╣░╗²╗Ω╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_13_P_└ⁿ╖┬▒Γ╝·╝│░Φ╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_06_P_╝«┐¼┼║┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_26_02_P_╣µ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_12_02_P_▒╣│╗┐▄┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_04_P_╡┐╣░┐δ└╟╛α╟░╡╡╕┼╗≤.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_20_P_┴²└»╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_02_P_└╟┐°.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_43_01_P_┤π╣Φ╡╡╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_12_01_P_▒╣│╗┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_06_P_╜├│╗╝°╚»░ⁿ▒ñ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_10_02_P_║±╡≡┐└╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_10_P_╡┐╣░└º┼╣░ⁿ╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_28_05_P_░φ╛╨░í╜║╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_15_P_╚»░µ░ⁿ╕«┤δ╟α▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_05_P_├α╗Ω░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_09_P_╡┐╣░└ⁿ╜├╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_06_20_02_P_└╟╖ß▒Γ░ⁿ╝╝┼╣╣░├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_06_20_01_P_╝╝┼╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_43_03_P_┤π╣Φ╝÷└╘╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_02_P_╡┐╣░╛α▒╣.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_24_04_P_└╧╣▌└╜╜─┴í.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_10_03_P_║±╡≡┐└╣░╝╥▒╪└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_12_03_P_┴╛╟╒┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_50_01_P_╣½╖ß┴≈╛≈╝╥░│╝╥.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_13_05_P_┐╡╚¡┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_07_P_╡┐╣░╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_04_17_01_P_├Γ╞╟╗τ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_06_01_P_░°┐¼└σ.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_01_P_░í├α║╨┤ó╝÷┴²┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_09_P_└╧╣▌└»┐°╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_10_33_01_P_╣½╡╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_08_26_01_P_┤┘┤▄░Φ╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_16_P_┐δ▒Γ│├╡┐▒Γ╞»┴ñ╝│║±.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_07_13_P_┴╛╟╒╚▐╛τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_03_13_01_P_┐╡╚¡╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_30_14_P_└·╝÷┴╢├╗╝╥╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_02_01_P_╛╚░µ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_01_01_06_P_╛α▒╣.csv
# Successfully read and filtered file: /content/extracted_data/20240812_09_27_02_P_┐°╕±╗²╗Ω╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_11_45_01_P_▒╣┴ª╣░╖∙┴╓╝▒╛≈.csv
# Successfully read and filtered file: /content/extracted_data/20240812_02_03_01_P_╡┐╣░║┤┐°.csv
# Successfully read and filtered file: /content/extracted_data/20240812_07_22_07_P_╜─╟░│├╡┐│├└σ╛≈.csv
# 매핑되지 않은 항목 수: 853
# 매핑 후 관리지사 및 SP담당이 비어있는 행 수: 관리지사    853
# SP담당    873
# dtype: int64
# <ipython-input-1-103fe816bf3a>:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop_duplicates(inplace=True)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 54889 (\N{HANGUL SYLLABLE HWANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:288: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 54889 (\N{HANGUL SYLLABLE HWANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:289: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 54984 (\N{HANGUL SYLLABLE HUN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48176 (\N{HANGUL SYLLABLE BAE}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 46024 (\N{HANGUL SYLLABLE DON}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 53469 (\N{HANGUL SYLLABLE TAEG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48337 (\N{HANGUL SYLLABLE BYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:302: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# ...
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44216 (\N{HANGUL SYLLABLE GYEOM}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 54596 (\N{HANGUL SYLLABLE PIL}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44049 (\N{HANGUL SYLLABLE GAB}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50756 (\N{HANGUL SYLLABLE WAN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-103fe816bf3a>:303: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# 전체 영업상태명 집계현황 PDF가 생성되었습니다: /content/drive/My Drive/회사업무/인허가_0812/전체_영업상태명_집계현황.pdf

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
import matplotlib.font_manager as fm

# 한글 폰트 설치 및 설정
# !apt-get install -y fonts-nanum
# !fc-cache -fv

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=12)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 폰트 설정

# 구글 드라이브를 마운트합니다.
drive.mount('/content/drive', force_remount=True)

# 정확한 파일 경로 입력
file_path = '/content/drive/My Drive/회사업무/인허가_0812/0814일_전체_최종결과물.xlsx'

if not os.path.exists(file_path):
    raise FileNotFoundError(f"{file_path} 파일이 존재하지 않습니다. 경로를 확인하세요.")

# 데이터 프레임 읽기
df_filtered_sorted = pd.read_excel(file_path)

# '중앙' 지사 및 'Unknown' 제외
df_filtered_sorted = df_filtered_sorted[(df_filtered_sorted['관리지사'] != '중앙') &
                                        (df_filtered_sorted['관리지사'] != 'Unknown') &
                                        (df_filtered_sorted['SP담당'] != 'Unknown')]

# 담당자 앞에 관리지사 이름 추가 (지사 제외)
df_filtered_sorted['SP담당자'] = df_filtered_sorted['관리지사'].str.replace('지사', '') + '-' + df_filtered_sorted['SP담당']

# '영업/정상'과 '폐업' 상태만 필터링
df_filtered_sorted = df_filtered_sorted[df_filtered_sorted['영업상태명'].isin(['영업/정상', '폐업'])]

# 매핑된 데이터만 필터링
df_filtered_sorted = df_filtered_sorted.dropna(subset=['관리지사', 'SP담당'])

# 전체 데이터를 바탕으로 시각화
status_counts = df_filtered_sorted.groupby(['SP담당자', '영업상태명']).size().unstack(fill_value=0)
status_counts = status_counts.loc[status_counts.sum(axis=1).sort_values(ascending=True).index]

# 시각화 (가로 막대 그래프)
fig, ax = plt.subplots(figsize=(16, 12))
colors = ['#4caf50', '#f44336']  # 영업/정상 = 녹색, 폐업 = 빨간색

# 막대 그래프 생성
bars = status_counts.plot(kind='barh', stacked=True, ax=ax, color=colors, width=0.8)

# 그래프 제목 및 레이블 설정
ax.set_title('SP담당자별 영업상태명 집계현황', fontsize=18, fontproperties=fontprop)
ax.set_xlabel('건수', fontsize=14, fontproperties=fontprop)
ax.set_ylabel('SP담당자', fontsize=14, fontproperties=fontprop)
plt.xticks(fontsize=12, fontproperties=fontprop)
plt.yticks(fontsize=12, fontproperties=fontprop)

# 막대에 숫자 표시
for container in bars.containers:
    bars.bar_label(container, label_type='center', fontsize=10, fontproperties=fontprop, color='white' if container.get_label() == '영업/정상' else 'black')

# 범례 설정
handles, labels = ax.get_legend_handles_labels()
legend = ax.legend(handles, labels, title='영업상태명', fontsize=12, title_fontsize='14', prop=fontprop, loc='lower right')
plt.setp(legend.get_title(), fontproperties=fontprop)

# 그래프에 그리드 추가
ax.grid(True, axis='x', linestyle='--', alpha=0.7)

# 그래프를 이미지로 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
fig_path = os.path.join(output_dir, '전체_영업상태명_집계현황_전문가_0814.png')
fig.savefig(fig_path, bbox_inches='tight')

# 그래프를 출력
plt.show()

print(f"전체 영업상태명 집계현황 전문가 그래프가 생성되었습니다: {fig_path}")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-fde3e247c926> in <cell line: 17>()
#      15
#      16 # 구글 드라이브를 마운트합니다.
# ---> 17 drive.mount('/content/drive', force_remount=True)
#      18
#      19 # 정확한 파일 경로 입력
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import pandas as pd
import os
import glob
import zipfile
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles import Border, Side, Alignment, PatternFill, Font
from google.colab import drive
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.backends.backend_pdf import PdfPages

# 한글 폰트 설치 및 설정
# !apt-get install -y fonts-nanum
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 구글 드라이브를 마운트합니다.
drive.mount('/content/drive', force_remount=True)

# 압축 파일 경로 및 압축 해제 경로 설정
zip_file_path = '/content/drive/My Drive/회사업무/인허가_0812/LOCALDATA_NOWMON_CSV 4.zip'
extract_folder = '/content/extracted_data'

# 폴더가 없으면 생성
os.makedirs(extract_folder, exist_ok=True)

# 압축 해제
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
except FileNotFoundError:
    print(f"Error: Specified zip file '{zip_file_path}' not found. Please check the path.")
    exit(1)

# 압축 해제된 폴더에서 모든 CSV 파일 목록 가져오기
all_files = glob.glob(os.path.join(extract_folder, "**/*.csv"), recursive=True)

if len(all_files) == 0:
    print("Warning: No CSV files found in the specified directory. Proceeding with an empty DataFrame.")
    dfs = []  # 빈 리스트로 초기화
else:
    # 각 파일을 읽어서 하나의 DataFrame으로 병합
    dfs = []
    for file in all_files:
        try:
            df = pd.read_csv(file, encoding='cp949', on_bad_lines='skip', dtype=str, low_memory=False)
            # 주소라는 키워드를 포함한 열 확인
            address_columns = [col for col in df.columns if '주소' in col]
            if not address_columns:
                print(f"No address column found in file: {file}")
                continue
            # '서울', '경기', '강원'이 포함된 행 필터링
            df_filtered = df[df[address_columns[0]].str.contains('서울|경기|강원', na=False)]
            dfs.append(df_filtered)
            print(f"Successfully read and filtered file: {file}")
        except Exception as e:
            print(f"Error reading file {file}: {e}")

if len(dfs) == 0:
    concatenated_df = pd.DataFrame()  # 이전 단계에서 파일이 없을 경우 빈 DataFrame 생성
else:
    concatenated_df = pd.concat(dfs, ignore_index=True)
    # 중복된 행 제거: 사업장명, 소재지전체주소, 영업상태명이 동일한 경우 하나만 남기고 제거
    concatenated_df.drop_duplicates(subset=['사업장명', '소재지전체주소', '영업상태명'], inplace=True)

    # '인허가일자' 기준으로 내림차순 정렬
    if '인허가일자' in concatenated_df.columns:
        concatenated_df['인허가일자'] = pd.to_datetime(concatenated_df['인허가일자'], format='%Y%m%d', errors='coerce')
        concatenated_df.sort_values(by='인허가일자', ascending=False, inplace=True)

# 필요한 열만 선택하여 필터링
selected_columns = ['소재지전체주소', '도로명전체주소', '도로명우편번호', '사업장명', '개방서비스명', '인허가일자', '인허가취소', '영업상태명', '폐업일자',
                    '휴업시작일', '휴업종료일', '재개업일자', '소재지전화', '최종수정시점', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '총면적', '소재지면적']

# 존재하는 열만 선택
existing_columns = [col for col in selected_columns if col in concatenated_df.columns]
filtered_df = concatenated_df[existing_columns]

# CSV 파일로 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
os.makedirs(output_dir, exist_ok=True)
output_csv_path = os.path.join(output_dir, '1.0801_12까지변동_병합(서울,경기,강원).csv')
filtered_df.to_csv(output_csv_path, index=False, encoding='cp949')

# 엑셀 파일 경로 설정
file1_path = os.path.join('/content/drive/My Drive/회사업무/행안부자료/0801', '1.영업구역별_주소현행화0725.xlsx')
file2_path = output_csv_path  # 이전 단계에서 생성한 파일 사용

# 파일 경로 확인
if not os.path.exists(file1_path):
    raise FileNotFoundError(f"{file1_path} 파일이 존재하지 않습니다. 경로를 확인하세요.")
if not os.path.exists(file2_path):
    raise FileNotFoundError(f"{file2_path} 파일이 존재하지 않습니다. 경로를 확인하세요.")

# 엑셀 파일 읽기
df1 = pd.read_excel(file1_path)
df2 = pd.read_csv(file2_path, encoding='cp949')

# 주소 정규화 함수
def normalize_address(address):
    if pd.isna(address):
        return address
    address = address.strip()
    address = address.replace('강원특별자치도', '강원도')
    address = address.replace('서울특별시', '서울시')
    if '*' in address:
        return None
    return address

# df1의 주소 정규화
df1['full_address'] = df1[['주소시', '주소군구', '주소동']].astype(str).agg(' '.join, axis=1).apply(normalize_address)
df1 = df1.dropna(subset=['full_address'])

# df2의 주소 정규화
df2['소재지전체주소'] = df2['소재지전체주소'].astype(str).apply(normalize_address)
df2['도로명전체주소'] = df2['도로명전체주소'].astype(str).apply(normalize_address)
df2 = df2.dropna(subset=['소재지전체주소', '도로명전체주소'])

# TF-IDF 벡터화
vectorizer = TfidfVectorizer().fit(df1['full_address'])
tfidf_matrix = vectorizer.transform(df1['full_address'])

# 유사한 주소 매핑
def get_best_match(address, tfidf_matrix, vectorizer, choices, threshold=0.7):
    if pd.isna(address):
        return None
    query_vec = vectorizer.transform([address])
    cosine_similarities = cosine_similarity(query_vec, tfidf_matrix).flatten()
    best_match_index = cosine_similarities.argmax()
    best_match_score = cosine_similarities[best_match_index]
    if best_match_score >= threshold:
        return choices[best_match_index]
    return None

choices = df1['full_address'].tolist()
df2['matched_address_소재지'] = df2['소재지전체주소'].apply(lambda x: get_best_match(x, tfidf_matrix, vectorizer, choices))
df2['matched_address_도로명'] = df2['도로명전체주소'].apply(lambda x: get_best_match(x, tfidf_matrix, vectorizer, choices))

df2['matched_address'] = df2.apply(lambda x: x['matched_address_소재지'] if pd.notna(x['matched_address_소재지']) else x['matched_address_도로명'], axis=1)

# 매핑되지 않은 항목 확인
unmatched = df2[df2['matched_address'].isna()]
print("매핑되지 않은 항목 수:", len(unmatched))

# 평수 계산을 위한 열 존재 확인 및 병합
merge_columns = ['full_address', '관리지사', 'SP담당']
if '총면적' in df1.columns:
    merge_columns.append('총면적')
if '소재지면적' in df1.columns:
    merge_columns.append('소재지면적')

df_merged = df2.merge(df1[merge_columns], left_on='matched_address', right_on='full_address', how='left', suffixes=('', '_df1'))

# 매핑 결과 확인
print("매핑 후 관리지사 및 SP담당이 비어있는 행 수:", df_merged[['관리지사', 'SP담당']].isna().sum())

# 평수 계산 (1평 = 3.305785 m^2)
def calculate_area(row):
    if '소재지면적' in row and pd.notna(row['소재지면적']):
        return round(row['소재지면적'] / 3.305785, 2)

    elif '총면적' in row and pd.notna(row['총면적']):
        return round(row['총면적'] / 3.305785, 2)
    else:
        return None

df_merged['평수'] = df_merged.apply(calculate_area, axis=1)

# 불필요한 열 제외하고 필요한 열만 선택
columns_to_keep = ['관리지사', 'SP담당', '사업장명', '개방서비스명', '업태구분명', '평수', '소재지전체주소', '도로명전체주소', '소재지전화', '폐업일자', '재개업일자', '영업상태명']
df_filtered = df_merged[columns_to_keep]

# 중복된 항목 제거
df_filtered.drop_duplicates(inplace=True)

# 평수 내림차순 정렬
df_filtered_sorted = df_filtered.sort_values(by='평수', ascending=False)

# NaN 값 처리
df_filtered_sorted['관리지사'] = df_filtered_sorted['관리지사'].fillna('Unknown')
df_filtered_sorted['SP담당'] = df_filtered_sorted['SP담당'].fillna('Unknown')

# 네이버 지도 하이퍼링크 생성 함수
def create_naver_map_link(address):
    return f"https://map.naver.com/v5/search/{address}"

# 엑셀 파일에 네이버 지도 링크 추가하는 함수
def add_naver_map_links(ws, address_col_idx):
    ws.insert_cols(1)  # 첫 번째 열에 열 추가
    ws.cell(row=1, column=1, value="네이버 지도 링크")  # 새 열에 헤더 추가

    for row in range(2, ws.max_row + 1):
        address = ws.cell(row=row, column=address_col_idx + 1).value
        if address:
            link = create_naver_map_link(address)
            ws.cell(row=row, column=1).hyperlink = link
            ws.cell(row=row, column=1).value = "네이버 지도 보기"
            ws.cell(row=row, column=1).style = "Hyperlink"

# 엑셀 파일에 데이터를 저장하고 스타일을 설정하는 함수
def save_to_excel(df, file_path):
    with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
        # 전체 시트 저장
        df.to_excel(writer, index=False, sheet_name='전체')

        # 영업/정상 시트 저장
        df_active = df[df['영업상태명'].isin(['영업/정상'])]
        df_active.to_excel(writer, index=False, sheet_name='영업_정상')

        # 폐업 시트 저장
        df_closed = df[df['영업상태명'] == '폐업']
        df_closed.to_excel(writer, index=False, sheet_name='폐업')

        workbook = writer.book
        thin_border = Border(left=Side(style='thin', color='D3D3D3'),
                             right=Side(style='thin', color='D3D3D3'),
                             top=Side(style='thin', color='D3D3D3'),
                             bottom=Side(style='thin', color='D3D3D3'))
        header_fill = PatternFill(start_color="000080", end_color="000080", fill_type="solid")
        header_font = Font(color="FFFFFF", bold=True)

        # 스타일 설정 함수
        def set_style(worksheet):
            for cell in worksheet[1]:
                cell.fill = header_fill
                cell.font = header_font
                cell.border = thin_border
                cell.alignment = Alignment(horizontal='center', vertical='center')
            for row in worksheet.iter_rows(min_row=2):
                for cell in row:
                    cell.border = thin_border
                    cell.alignment = Alignment(horizontal='center', vertical='center')
            for col in worksheet.columns:
                max_length = 0
                column = col[0].column_letter
                for cell in col:
                    try:
                        if len(str(cell.value)) > max_length:
                            max_length = len(cell.value)
                    except:
                        pass
                adjusted_width = (max_length + 2)
                worksheet.column_dimensions[column].width = adjusted_width

        set_style(writer.sheets['전체'])
        set_style(writer.sheets['영업_정상'])
        set_style(writer.sheets['폐업'])

        # 네이버 지도 링크 추가
        # '소재지전체주소'는 H열이므로 컬럼 인덱스는 8-1=7
        add_naver_map_links(writer.sheets['전체'], 7)
        add_naver_map_links(writer.sheets['영업_정상'], 7)
        add_naver_map_links(writer.sheets['폐업'], 7)

# 전체 데이터를 바탕으로 시각화 및 파일 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
for manager in df_filtered_sorted['관리지사'].unique():
    manager_dir = os.path.join(output_dir, manager)
    os.makedirs(manager_dir, exist_ok=True)
    df_manager = df_filtered_sorted[df_filtered_sorted['관리지사'] == manager]

    for sp in df_manager['SP담당'].unique():
        df_sp = df_manager[df_manager['SP담당'] == sp]
        sp_file_path = os.path.join(manager_dir, f'{manager}_{sp}_0812까지.xlsx')
        save_to_excel(df_sp, sp_file_path)

# 전체 데이터를 저장
total_file_path = os.path.join(output_dir, '0801_12까지 전체_최종결과물.xlsx')
save_to_excel(df_filtered_sorted, total_file_path)

# 전체 데이터를 바탕으로 시각화
status_counts = df_filtered_sorted.groupby(['관리지사', '영업상태명']).size().unstack(fill_value=0)
status_counts = status_counts.loc[status_counts.sum(axis=1).sort_values(ascending=False).index]

# 시각화 및 PDF 저장
pdf_path = os.path.join(output_dir, '전체_영업상태명_집계현황.pdf')
with PdfPages(pdf_path) as pdf:
    # 시각화 1: 관리지사별 영업상태명 집계현황
    fig1, ax1 = plt.subplots(figsize=(14, 10))
    status_counts.plot(kind='bar', stacked=True, ax=ax1, color=['skyblue', 'salmon'])
    ax1.set_title('관리지사별 영업상태명 집계현황', fontsize=16)
    ax1.set_xlabel('관리지사', fontsize=12)
    ax1.set_ylabel('건수', fontsize=12)
    ax1.legend(title='영업상태명', fontsize=10, title_fontsize='13')
    plt.xticks(rotation=90)
    plt.tight_layout()
    pdf.savefig(fig1)
    plt.close(fig1)

    # 시각화 2: SP담당자별 영업상태명 집계현황
    df_filtered_sorted['SP담당자'] = df_filtered_sorted['관리지사'].str.replace('지사', '') + '-' + df_filtered_sorted['SP담당']
    status_counts_sp = df_filtered_sorted.groupby(['SP담당자', '영업상태명']).size().unstack(fill_value=0)
    status_counts_sp = status_counts_sp.loc[status_counts_sp.sum(axis=1).sort_values(ascending=True).index]

    fig2, ax2 = plt.subplots(figsize=(16, 12))
    status_counts_sp.plot(kind='barh', stacked=True, ax=ax2, color=['#4caf50', '#f44336'])
    ax2.set_title('SP담당자별 영업상태명 집계현황', fontsize=18)
    ax2.set_xlabel('건수', fontsize=14)
    ax2.set_ylabel('SP담당자', fontsize=14)
    plt.tight_layout()
    pdf.savefig(fig2)
    plt.close(fig2)

print(f"전체 영업상태명 집계현황 PDF가 생성되었습니다: {pdf_path}")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 3s (3,831 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Mounted at /content/drive
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_24_02_P_░ⁿ▒ñ└»╚∩└╜╜─┴í╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_12_03_P_┴╛╟╒┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_03_P_║╣╟╒┐╡╗≤╣░┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_14_P_┴÷╣µ╣«╚¡┐°.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_45_02_P_╣░╖∙├ó░φ╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_44_01_P_╕±┐σ└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_18_P_╚»░µ─┴╝│╞├╚╕╗τ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_11_P_└ⁿ┼δ╗τ┬√.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_06_P_╜─└░╞≈└σ├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_03_P_║╬╝╙└╟╖ß▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_03_P_╡┐╣░┐δ└╟╖ß┐δ▒╕╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_12_P_└ⁿ╖┬▒Γ╝·░¿╕«╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_40_01_P_┐Σ╞«└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_05_P_╗τ╖ß┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_13_03_P_┐╡╚¡╗≤┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_07_P_╡┐╣░╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_06_P_└╧╣▌░╘└╙┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_23_02_P_└»╚∩┴╓┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_02_P_░ⁿ▒ñ╗τ╛≈└┌.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_33_01_P_╣½╡╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_39_01_P_╜Σ╕┼└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_36_01_P_╜║┼░└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_09_P_╣Φ├Γ░í╜║└ⁿ╣«┴ñ║±╗τ╛≈└┌╚«└╬░╦╗τ┤δ╟α└┌.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_08_P_╝«└»╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_05_P_░φ╛╨░í╜║╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_26_01_P_┤┘┤▄░Φ╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_06_20_02_P_└╟╖ß▒Γ░ⁿ╝╝┼╣╣░├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_11_P_╝╥╡╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_02_P_░Φ╖«▒Γ╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_24_P_├α╗Ω╣░║╕░ⁿ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_18_P_┴ª░·┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_04_P_┐▄▒╣└╬░ⁿ▒ñ╡╡╜├╣╬╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_13_P_╜─╟░╞╟╕┼╛≈▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_02_P_╡┐╣░╛α▒╣.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_05_P_╛╚└ⁿ╗≤║±└╟╛α╟░╞╟╕┼╛≈╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_05_P_└┌╡┐┬≈╛▀┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_03_P_░│└╬╟╧╝÷├│╕«╜├╝│░ⁿ╕«╛≈╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_15_P_╚»░µ░ⁿ╕«┤δ╟α▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_01_P_░ⁿ▒ñ▒╦╡╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_02_P_░╘└╙╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_04_P_├α╗Ω╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_33_02_P_╣½╡╡╟╨┐°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_25_01_P_┤δ▒╘╕≡┴í╞≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_21_02_P_┴²┤▄▒▐╜─╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_14_P_╞»┴ñ░φ╛╨░í╜║╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_13_04_P_┐╡╚¡╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_27_01_P_╕±└τ╝÷└╘└»┼δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_12_P_╜─╟░├╖░í╣░┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_04_P_╡┐╣░┐δ└╟╛α╟░╡╡╕┼╗≤.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_06_P_▒▐╝÷░°╗τ┤δ╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_13_P_┴╛╟╒╚▐╛τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_29_01_P_┴÷╟╧╝÷╜├░°╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_09_P_╜─╟░┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_04_P_░╟╣░└º╗²░ⁿ╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_07_P_┤▄╡╢┴ñ╚¡┴╢┐└╝÷├│╕«╜├╝│╝│░Φ╜├░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_21_P_╜─┐δ╛≤└╜╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_43_01_P_┤π╣Φ╡╡╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_08_02_P_┤δ┴▀╣«╚¡┐╣╝·▒Γ╚╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_34_01_P_║∙╗≤└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_14_P_┐╦▒Γ╖∙┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_07_P_└└▒▐╚»└┌└╠╝█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_04_P_║╣╟╒└»┼δ░╘└╙┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_06_P_┴╛├α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_50_01_P_╣½╖ß┴≈╛≈╝╥░│╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_14_03_P_└╜╣▌.└╜╛╟┐╡╗≤╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_09_P_└╧╣▌└»┐°╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_13_P_└ⁿ╖┬▒Γ╝·╝│░Φ╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_10_03_P_║±╡≡┐└╣░╝╥▒╪└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_12_02_P_▒╣│╗┐▄┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_14_P_└·╝÷┴╢├╗╝╥╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_41_01_P_├╝└░╡╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_04_16_01_P_└╬╝Γ╗τ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_09_P_╛╫╚¡╝«└»░í╜║┐δ╟░┴ª┴╢╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_24_05_P_╚▐░╘└╜╜─┴í.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_50_02_P_└»╖ß┴≈╛≈╝╥░│╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_08_03_P_╣«╚¡┐╣╝·╣²└╬.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_20_P_┴²└»╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_08_P_└»┐°╜├╝│╛≈▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_03_P_╝≈╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_02_P_└╟┐°.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_10_01_P_║±╡≡┐└╣░░¿╗≤╜╟╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_01_P_║┤┐°.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_25_P_├α╗Ω╣░┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_04_P_║╬╚¡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_26_04_P_┼δ╜┼╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_16_P_╚»░µ└ⁿ╣«░°╗τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_49_01_P_┐Σ╛τ║╕╚ú╗τ▒│└░▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_06_02_P_░ⁿ▒ñ░°┐¼└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_04_15_01_P_┐┴┐▄▒ñ░φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_10_04_P_║±╡≡┐└╣░╜├├╗┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_43_02_P_┤π╣Φ╝╥╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_16_P_┐δ▒Γ│├╡┐▒Γ╞»┴ñ╝│║±.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_13_01_P_┐╡╚¡╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_10_P_╜─╟░└┌╡┐╞╟╕┼▒Γ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_27_02_P_┐°╕±╗²╗Ω╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_10_P_║╨┤ó╝÷┴²┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_01_P_░Φ╖«▒Γ╝÷╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_01_P_░í├α║╨┤ó╝÷┴²┐ε╣▌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_19_P_┴∩╝«╞╟╕┼┴ª┴╢░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_08_01_P_▒╣┴ª╚╕└╟▒Γ╚╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_14_02_P_└╜╣▌.└╜╛╟┐╡╗≤╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_01_P_┴²┤▄▒▐╜─╝╥╜─╟░╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_47_01_P_╗≤┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_38_01_P_╜┬╕╢└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_10_02_P_║±╡≡┐└╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_13_P_╛▓╖╣▒Γ┴╛╖«┴ª║└┼⌡╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_05_P_├α╗Ω░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_01_P_╡┐╣░║┤┐°.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_12_01_P_▒╣│╗┐⌐╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_46_01_P_╣╬╣µ└º▒▐╝÷╜├╝│.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_43_03_P_┤π╣Φ╝÷└╘╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_24_04_P_└╧╣▌└╜╜─┴í.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_10_P_╡┐╣░└º┼╣░ⁿ╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_48_02_P_╜┬░¡▒Γ┴ª┴╢╣╫╝÷└╘╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_49_02_P_└σ╖╩┴÷╡╡╗τ▒│└░▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_11_P_╜─╟░┴ª┴╢░í░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_05_18_01_P_╣╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_48_01_P_╜┬░¡▒Γ└»┴÷░ⁿ╕«╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_12_P_╡┐╣░┐ε╝█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_27_03_P_┴ª└τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_04_17_01_P_├Γ╞╟╗τ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_12_P_╝÷┴·┐└┐░┐°╝│─í╜├╝│▒Γ┼╕.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_26_05_P_╚─┐°╣µ╣«╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_01_P_░ⁿ▒ñ╝≈╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_07_P_╝«└»╣╫╝«└»┤δ├╝┐¼╖ß╞╟╕┼╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_17_P_└»┼δ└ⁿ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_10_P_└╧╣▌╡╡╜├░í╜║╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_10_P_└╟╖ß└»╗τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_07_P_╜─╟░│├╡┐│├└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_02_03_P_└╟╖ß▒Γ▒Γ╞╟╕┼└╙┤δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_05_P_░╟╝│╞≤▒Γ╣░├│╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_14_04_P_└╜╣▌╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_05_P_╡┐╣░└σ╣ª╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_29_03_P_┴÷╟╧╝÷┴ñ╚¡╛≈├╝.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_02_P_░í├α└╬░°╝÷┴ñ╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_02_04_P_─í░·▒Γ░°╝╥.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_24_03_P_┐▄▒╣└╬└ⁿ┐δ└»╚∩└╜╜─┴í╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_01_P_░╘└╙╣░╣Φ▒▐╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_10_05_P_║±╡≡┐└╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_11_P_╡┐╣░╣╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_21_01_P_└º┼╣▒▐╜─┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_11_45_01_P_▒╣┴ª╣░╖∙┴╓╝▒╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_06_01_P_░°┐¼└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_14_05_P_└╜╣▌╣░┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_06_03_P_░ⁿ▒ñ▒╪└σ└»╚∩╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_08_P_╡┐╣░╝÷└╘╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_05_19_01_P_└╠┐δ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_02_P_░ⁿ▒ñ╞µ╝╟╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_06_P_╝«┐¼┼║┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_06_P_╜├│╗╝°╚»░ⁿ▒ñ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_31_03_P_╡ε╖╧├╝└░╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_15_P_┐δ▒Γíñ╞≈└σ┴÷┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_14_01_P_┐┬╢≤└╬└╜╛╟╝¡║±╜║┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_13_05_P_┐╡╚¡┴ª└█╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_06_P_╡┐╣░╗²╗Ω╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_04_P_░Φ╖«▒Γ┴⌡╕φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_29_02_P_┴÷╟╧╝÷┐╡╟Γ┴╢╗τ▒Γ░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_35_01_P_╝÷┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_02_01_P_╛╚░µ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_08_P_╜─╟░╝╥║╨╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_09_01_P_│δ╖í┐¼╜└└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_04_P_╗Ω╚─┴╢╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_03_P_░ⁿ▒ñ└»╢≈╝▒╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_28_03_P_░Φ╖«▒Γ┴ª┴╢╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_23_01_P_┤▄╢⌡┴╓┴í┐╡╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_26_03_P_└ⁿ╚¡▒╟└»╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_31_01_P_░±╟┴┐¼╜└└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_32_01_P_┤τ▒╕└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_31_02_P_░±╟┴└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_02_P_░╟░¡▒Γ┤╔╜─╟░└»┼δ└ⁿ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_08_26_02_P_╣µ╣«╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_08_P_└╟╖ß╣²└╬.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_02_P_░í├α║╨┤ó╣Φ├Γ╜├╝│░ⁿ╕«╛≈╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_02_02_P_└╟╖ß▒Γ▒Γ╝÷╕«╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_05_P_╣┌╣░░ⁿ,╣╠╝·░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_24_01_P_░ⁿ▒ñ╜─┤τ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_07_P_└╧╣▌╛▀┐╡└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_05_P_└╬┼═│▌──╟╗┼═░╘└╙╜├╝│┴ª░°╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_03_09_P_╡┐╣░└ⁿ╜├╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_03_P_╡╡├α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_10_P_└ⁿ╣«╚▐╛τ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_42_01_P_├╝╖┬┤▄╖├└σ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_17_P_╚»░µ├°┴ñ┤δ╟α╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_13_02_P_┐╡╚¡╗≤┐╡░ⁿ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_04_P_▒╣┴ª╚╕└╟╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_06_P_╟╤┐┴├╝╟Φ╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_09_30_08_P_┤δ▒Γ┐└┐░╣░┴·╣Φ├Γ╜├╝│╝│─í╗τ╛≈└σ.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_01_01_06_P_╛α▒╣.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_10_37_01_P_┴╛╟╒├╝└░╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_11_08_P_│≤╛ε├╠╣╬╣┌╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_07_22_03_P_░╟░¡▒Γ┤╔╜─╟░└╧╣▌╞╟╕┼╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_02_04_01_P_░í├α╗τ└░╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_06_20_01_P_╝╝┼╣╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_07_12_P_┴╛╟╒└»┐°╜├╝│╛≈.csv
# Successfully read and filtered file: /content/extracted_data/(20240801~20240811)_03_05_07_P_├╗╝╥│Γ░╘└╙┴ª░°╛≈.csv
# 매핑되지 않은 항목 수: 6653
# 매핑 후 관리지사 및 SP담당이 비어있는 행 수: 관리지사    6653
# SP담당    6933
# dtype: int64
# <ipython-input-1-65a79e1f6df1>:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop_duplicates(inplace=True)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 54889 (\N{HANGUL SYLLABLE HWANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:289: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 54889 (\N{HANGUL SYLLABLE HWANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:290: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 54984 (\N{HANGUL SYLLABLE HUN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 47497 (\N{HANGUL SYLLABLE REUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 53469 (\N{HANGUL SYLLABLE TAEG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 50521 (\N{HANGUL SYLLABLE ANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 48176 (\N{HANGUL SYLLABLE BAE}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 46024 (\N{HANGUL SYLLABLE DON}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:303: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.tight_layout()
# ...
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44049 (\N{HANGUL SYLLABLE GAB}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 54596 (\N{HANGUL SYLLABLE PIL}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44216 (\N{HANGUL SYLLABLE GYEOM}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 54889 (\N{HANGUL SYLLABLE HWANG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50756 (\N{HANGUL SYLLABLE WAN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 45812 (\N{HANGUL SYLLABLE DAM}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-1-65a79e1f6df1>:304: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# 전체 영업상태명 집계현황 PDF가 생성되었습니다: /content/drive/My Drive/회사업무/인허가_0812/전체_영업상태명_집계현황.pdf

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.1.4)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.1)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.0)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.3)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.60.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.9.0-py2.py3-none-any.whl (356 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 7.0 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 18.1 MB/s eta 0:00:00
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 27.7 MB/s eta 0:00:00
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 6.8 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=2d78a4373da08e1897e546e1243ff6fdb8404953e5cdb18a245c0a8087d69afd
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, PyWavelets, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed PyWavelets-1.7.0 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 visions-0.7.6 ydata-profiling-4.9.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.backends.backend_pdf import PdfPages
import os

# 한글 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 데이터프레임 준비: df_filtered_sorted

# 전체 데이터를 바탕으로 시각화
status_counts = df_filtered_sorted.groupby(['관리지사', '영업상태명']).size().unstack(fill_value=0)
status_counts = status_counts.loc[status_counts.sum(axis=1).sort_values(ascending=False).index]

# 시각화 및 PDF 저장
output_dir = '/content/drive/My Drive/회사업무/인허가_0812'
pdf_path = os.path.join(output_dir, '전체_영업상태명_집계현황.pdf')
with PdfPages(pdf_path) as pdf:
    # 시각화 1: 관리지사별 영업상태명 집계현황
    fig1, ax1 = plt.subplots(figsize=(14, 10))
    status_counts.plot(kind='bar', stacked=True, ax=ax1, color=['#6baed6', '#fb6a4a'])
    ax1.set_title('관리지사별 영업상태명 집계현황', fontsize=18, fontproperties=fontprop)
    ax1.set_xlabel('관리지사', fontsize=14, fontproperties=fontprop)
    ax1.set_ylabel('건수', fontsize=14, fontproperties=fontprop)
    ax1.legend(title='영업상태명', fontsize=12, title_fontsize='14', prop=fontprop)
    plt.xticks(rotation=90, fontsize=12, fontproperties=fontprop)
    plt.yticks(fontsize=12, fontproperties=fontprop)
    plt.tight_layout()
    pdf.savefig(fig1)
    plt.close(fig1)

    # 시각화 2: SP담당자별 영업상태명 집계현황
    df_filtered_sorted['SP담당자'] = df_filtered_sorted['관리지사'].str.replace('지사', '') + '-' + df_filtered_sorted['SP담당']
    status_counts_sp = df_filtered_sorted.groupby(['SP담당자', '영업상태명']).size().unstack(fill_value=0)
    status_counts_sp = status_counts_sp.loc[status_counts_sp.sum(axis=1).sort_values(ascending=True).index]

    fig2, ax2 = plt.subplots(figsize=(16, 12))
    status_counts_sp.plot(kind='barh', stacked=True, ax=ax2, color=['#4caf50', '#f44336'])
    ax2.set_title('SP담당자별 영업상태명 집계현황', fontsize=18, fontproperties=fontprop)
    ax2.set_xlabel('건수', fontsize=14, fontproperties=fontprop)
    ax2.set_ylabel('SP담당자', fontsize=14, fontproperties=fontprop)
    plt.xticks(fontsize=12, fontproperties=fontprop)
    plt.yticks(fontsize=12, fontproperties=fontprop)
    plt.tight_layout()
    pdf.savefig(fig2)
    plt.close(fig2)

print(f"전체 영업상태명 집계현황 PDF가 생성되었습니다: {pdf_path}")
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:32: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:32: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:32: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:32: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:32: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-2-ca1cb67cc3fd>:33: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-2-ca1cb67cc3fd>:33: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-2-ca1cb67cc3fd>:33: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   pdf.savefig(fig1)
# <ipython-input-2-ca1cb67cc3fd>:33: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig1)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:48: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   pdf.savefig(fig2)
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-2-ca1cb67cc3fd>:49: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   pdf.savefig(fig2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# 전체 영업상태명 집계현황 PDF가 생성되었습니다: /content/drive/My Drive/회사업무/인허가_0812/전체_영업상태명_집계현황.pdf
