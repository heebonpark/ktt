# %%
# 엑셀 파일 열고 실행

Sub SaveSheetAsCS()
    Dim ws As Worksheet
    Set ws = ThisWorkbook.Sheets("Sheet1")  ' 저장하고 싶은 시트 이름으로 설정하세요.
    Dim savePath As String
    savePath = "D:\시설\유지\'24년4월 조건요약.cs"  ' 파일 이름을 원하는 대로 설정하세요.

    ' CSV로 저장하듯이 처리하되 확장자만 .cs로 변경
    ws.SaveAs Filename:=savePath, FileFormat:=xlCSV, CreateBackup:=False
End Sub

에서

유지_columns = ['서비스상태(대)', '서비스상태(중)', '서비스(대)', '서비스(중)', '서비스(소)', '사업용구분', '공사의뢰유형', '회선방식(중)', 'KTT 월정료',
                '관리본부명', '관리지사명', '고객번호', '고객명', '계약번호', '계약자명', '서비스번호', '상호', '고객구분', '영업본부명', '영업지사명', '영업자명',
                '출동구역정보', '청약일자', '정지시작일자', '정지종료일자', '추천지사명']

헤더에 해당하는 열전체를 가져오는것 코드 실행해줘
# Out:
#   Cell In[6], line 5
#     Set ws = ThisWorkbook.Sheets("Sheet1")  ' 저장하고 싶은 시트 이름으로 설정하세요.
#                                             ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
# 라이브러리 실행
# !pip install pandas openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\python_v1\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# 파일 경로 및 시트 이름 설정
file_path = 'path_to_your_excel_file.xlsx'  # Excel 파일 경로
sheet_name = 'Sheet1'  # 읽어올 시트 이름

# Excel 파일 불러오기
df = pd.read_excel(file_path, sheet_name=sheet_name)

# .cs로 저장
output_path = r'D:\시설\유지\'24년4월 조건요약.cs'  # 저장할 파일 경로 및 이름
df.to_csv(output_path, index=False)  # 인덱스 없이 저장
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 sheet_name = 'Sheet1'  # 읽어올 시트 이름
#       7 # Excel 파일 불러오기
# ----> 8 df = pd.read_excel(file_path, sheet_name=sheet_name)
#      10 # .cs로 저장
#      11 output_path = r'D:\시설\유지\'24년4월 조건요약.cs'  # 저장할 파일 경로 및 이름
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_your_excel_file.xlsx'

# %%
# 라이브러리
# !pip install ipywidgets

# %%
# 해더추출

import pandas as pd

# 파일 경로 설정, 확장자가 .cs
file_path = 'D:/db/24년 4월 유지가입자.vol1/24년 4월 유지가입자.cs'

# CSV 파일 읽기, 헤더 및 데이터 타입 경고 처리
df = pd.read_csv(file_path, encoding='cp949', low_memory=False)

# 헤더만 출력, 보기 좋게 줄바꿈하여 표시
for column in df.columns:
    print(column)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       6 file_path = 'D:/db/24년 4월 유지가입자.vol1/24년 4월 유지가입자.cs'
#       8 # CSV 파일 읽기, 헤더 및 데이터 타입 경고 처리
# ----> 9 df = pd.read_csv(file_path, encoding='cp949', low_memory=False)
#      11 # 헤더만 출력, 보기 좋게 줄바꿈하여 표시
#      12 for column in df.columns:
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/db/24년 4월 유지가입자.vol1/24년 4월 유지가입자.cs'

# %%
# 계약번호 기준

import pandas as pd
from IPython.display import display, HTML

# 파일 경로 설정, 확장자가 .cs
file_path = 'D:/시설/유지/24년 4월 유지가입자.cs'

# CSV 파일 읽기, 헤더 및 데이터 타입 경고 처리
df = pd.read_csv(file_path, encoding='cp949', low_memory=False)

# 조회할 조건 설정
contract_number = '51970711'
partial_business_name = ''  # 사용자가 원하는 상호 일부 입력

# 조건에 맞는 데이터 필터링, 대소문자 구분 없이 검색
filtered_data = df[
    (df['계약번호'].astype(str) == contract_number) &
    (df['상호'].str.contains(partial_business_name, na=False, case=False))
][['청구번호', '계약번호', '상호', 'KTT월정료(조정)', '서비스상태(중)', '설치주소', '서비스(중)', '서비스(소)', '주민등록번호', '사업자번호', '보험등급', '영업자명']]

# 조건에 맞는 데이터만 표시
display(HTML(filtered_data.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>청구번호</th>
#       <th>계약번호</th>
#       <th>상호</th>
#       <th>KTT월정료(조정)</th>
#       <th>서비스상태(중)</th>
#       <th>설치주소</th>
#       <th>서비스(중)</th>
#       <th>서비스(소)</th>
#       <th>주민등록번호</th>
#       <th>사업자번호</th>
#       <th>보험등급</th>
#       <th>영업자명</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>287955</th>
#       <td>42130459</td>
#       <td>51970711</td>
#       <td>신촌PLA</td>
#       <td>50000</td>
#       <td>유지</td>
#       <td>서울 마포구 노고산동 ********</td>
#       <td>GiGAeyes Basic</td>
#       <td>GiGAeyes Basic</td>
#       <td>-*******</td>
#       <td>7490801809</td>
#       <td>무보험</td>
#       <td>김아람</td>
#     </tr>
#   </tbody>
# </table>

# %%
#  최종 === 체크박스

import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# 파일 경로 설정
file_path = 'D:/시설/유지/24년 4월 유지가입자.cs'


# CSV 파일 읽기, 모든 데이터를 문자열로 처리
df = pd.read_csv(file_path, encoding='cp949', dtype=str)
df.fillna('', inplace=True)  # NaN 값을 빈 문자열로 대체

# 입력 위젯 설정
input_fields = {
    '계약번호': '계약 번호 입력',
    '상호': '상호 부분 입력',
    '고객명': '고객명 부분 입력',
    '설치주소': '설치 주소 부분 입력',
    '관리본부명': '관리 본부명 입력',
    '관리지사명': '관리 지사명 입력',
    # '영업구역정보': '영업 구역 정보 입력',
    '영업자명': '구역 담당 영업사원 입력'
}

inputs = {key: widgets.Text(placeholder=desc, description=f'{key}:') for key, desc in input_fields.items()}

# 체크박스와 컬럼 이름 구성
checkboxes = [widgets.Checkbox(value=False, description=label) for label in df.columns]
checkbox_container = widgets.VBox(children=[widgets.HBox(checkboxes[i:i+5]) for i in range(0, len(checkboxes), 5)])

# 전체 선택/해제 버튼
toggle_buttons = widgets.ToggleButtons(
    options=['Select All', 'Deselect All'],
    description='Check:',
    disabled=False,
    button_style='',  # 'success', 'info', 'warning', 'danger' or ''
)

def toggle_checkboxes(change):
    if change['new'] == 'Select All':
        for checkbox in checkboxes:
            checkbox.value = True
    elif change['new'] == 'Deselect All':
        for checkbox in checkboxes:
            checkbox.value = False
    toggle_buttons.value = None  # Reset toggle button state

toggle_buttons.observe(toggle_checkboxes, 'value')

# 실행 버튼
run_button = widgets.Button(description='조회 실행', button_style='success', icon='search')
# 저장 버튼
save_button = widgets.Button(description='Excel로 저장', button_style='info', icon='save')

output = widgets.Output()

def run_query(b):
    with output:
        clear_output(wait=True)
        try:
            # 필터링 조건 적용
            condition = True
            for field, widget in inputs.items():
                if widget.value.strip():  # 입력값에서 공백 제거
                    condition &= df[field].str.contains(widget.value.strip(), case=False)
            filtered_data = df.loc[condition]
            selected_columns = [cb.description for cb in checkboxes if cb.value]
            if not selected_columns:
                raise ValueError("결과로 표시할 컬럼을 선택하세요.")
            if filtered_data.empty:
                raise ValueError("조회된데이터가 없습니다. 조건을 확인해주세요.")
            styled_html = filtered_data[selected_columns].to_html(escape=False, classes='styledTable')
            styled_css = "<style>.styledTable {width: 100%; border-collapse: collapse;} .styledTable th, .styledTable td {border: 1px solid #dddddd; padding: 8px; text-align: left;} .styledTable tr:nth-child(even) {background-color: #f7f7f7;} .styledTable tr:nth-child(odd) {background-color: #e7e7e7;}</style>"
            display(HTML(styled_css + styled_html))
        except Exception as e:
            display(HTML(f"<div style='color: red;'>Error: {e}</div>"))

def save_to_excel(b):
    try:
        if 'filtered_data' in globals() and 'selected_columns' in globals():
            filtered_data[selected_columns].to_excel('추출리스트.xlsx', index=False)
            with output:
                clear_output(wait=True)
                display(HTML("<div style='color: green;'>Data successfully saved to '추출리스트.xlsx'</div>"))
        else:
            raise ValueError("저장할 데이터가 없습니다. 먼저 조회를 실행하세요.")
    except Exception as e:
        with output:
            clear_output(wait=True)
            display(HTML(f"<div style='color: red;'>Error saving file: {e}</div>"))

# 이벤트 핸들러 연결
run_button.on_click(run_query)
save_button.on_click(save_to_excel)

# 입력 필드와 버튼을 같은 행에 배치
input_row = widgets.HBox([widgets.VBox([inputs[field] for field in inputs.keys()]), run_button, save_button])

# 체크박스 토글과 컬럼 선택을 관리하는 행
checkbox_toggle_row = widgets.HBox([toggle_buttons])

# UI 구성
ui = widgets.VBox([input_row, checkbox_container, checkbox_toggle_row, output])
display(ui)
# Out:
# VBox(children=(HBox(children=(VBox(children=(Text(value='', description='계약번호:', placeholder='계약 번호 입력'), Text…

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# 파일 경로 설정
file_path = 'D:/시설/유지/24년 4월 유지가입자.cs'

# CSV 파일 읽기, 인코딩 및 타입 지정
df = pd.read_csv(file_path, encoding='cp949', dtype=str)
df.fillna('', inplace=True)  # Replace NaN values with empty strings

# Check if the '금액' column exists and convert it to numeric
if '금액' in df.columns:
    df['100000'] = pd.to_numeric(df['150000'], errors='coerce').fillna(0)
else:
    print("Column '금액' does not exist in the DataFrame. Please verify the correct column name.")

# 입력 위젯 설정
input_fields = {
    '계약번호': '계약 번호 입력',
    '상호': '상호 부분 입력',
    '고객명': '고객명 부분 입력',
    '설치주소': '설치 주소 부분 입력',
    '관리본부명': '관리 본부명 입력',
    '관리지사명': '관리 지사명 입력',
    '영업자명': '구역 담당 영업사원 입력'
}
inputs = {key: widgets.Text(placeholder=desc, description=f'{key}:') for key, desc in input_fields.items()}

# 체크박스와 컬럼 이름 구성
checkboxes = [widgets.Checkbox(value=False, description=label) for label in df.columns]
checkbox_container = widgets.VBox(children=[widgets.HBox(checkboxes[i:i+5]) for i in range(0, len(checkboxes), 5)])

# 전체 선택/해제 버튼
toggle_buttons = widgets.ToggleButtons(
    options=['Select All', 'Deselect All'],
    description='Check:',
    disabled=False,
    button_style='',  # 'success', 'info', 'warning', 'danger' or ''
)

def toggle_checkboxes(change):
    if change['new'] == 'Select All':
        for checkbox in checkboxes:
            checkbox.value = True
    elif change['new'] == 'Deselect All':
        for checkbox in checkboxes:
            checkbox.value = False
    toggle_buttons.value = None  # Reset toggle button state

toggle_buttons.observe(toggle_checkboxes, 'value')

# 실행 버튼
run_button = widgets.Button(description='조회 실행', button_style='success', icon='search')
# 저장 버튼
save_button = widgets.Button(description='Excel로 저장', button_style='info', icon='save')

output = widgets.Output()

def run_query(b):
    with output:
        clear_output(wait=True)
        condition = pd.Series([True] * len(df))
        for field, widget in inputs.items():
            if widget.value.strip():  # 입력값에서 공백 제거
                condition &= df[field].str.contains(widget.value.strip(), case=False)
        filtered_data = df.loc[condition]
        selected_columns = [cb.description for cb in checkboxes if cb.value]
        if not selected_columns:
            raise ValueError("결과로 표시할 컬럼을 선택하세요.")
        if filtered_data.empty:
            display(HTML("<div>No data found matching the criteria.</div>"))
        else:
            display(HTML(filtered_data[selected_columns].to_html(escape=False, classes='styledTable')))
        
def save_to_excel(b):
    try:
        if 'filtered_data' in globals() and 'selected_columns' in globals():
            filtered_data[selected_columns].to_excel('추출리스트.xlsx', index=False)
            with output:
                clear_output(wait=True)
                display(HTML("<div style='color: green;'>Data successfully saved to '추출리스트.xlsx'</div>"))
        else:
            raise ValueError("저장할 데이터가 없습니다. 먼저 조회를 실행하세요.")
    except Exception as e:
        with output:
            clear_output(wait=True)
            display(HTML(f"<div style='color: red;'>Error saving file: {e}</div>"))

# 이벤트 핸들러 연결
run_button.on_click(run_query)
save_button.on_click(save_to_excel)

# UI 구성
ui = widgets.VBox([
    widgets.HBox(list(inputs.values())),
    checkbox_container,
    widgets.HBox([toggle_buttons, run_button, save_button]),
    output
])
display(ui)
# Out:
# Column '금액' does not exist in the DataFrame. Please verify the correct column name.
# VBox(children=(HBox(children=(Text(value='', description='계약번호:', placeholder='계약 번호 입력'), Text(value='', desc…

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# Load and prepare the data

df = pd.read_csv(file_path, encoding='cp949', dtype=str)
df.fillna('', inplace=True)
if '금액' in df.columns:
    df['금액'] = pd.to_numeric(df['금액'], errors='coerce').fillna(0)

# Define the input fields
input_fields = {
    '계약번호': '계약 번호 입력',
    '상호': '상호 부분 입력',
    '고객명': '고객명 부분 입력',
    '설치주소': '설치 주소 부분 입력',
    '관리본부명': '관리 본부명 입력',
    '관리지사명': '관리 지사명 입력',
    '영업자명': '구역 담당 영업사원 입력'
}
inputs = {key: widgets.Text(placeholder=desc, description=f'{key}:') for key, desc in input_fields.items()}

# Define monetary ranges and create a range slider
monetary_values = [(x, x) for x in range(0, 1000001, 100000)] + [("1M+", float('inf'))]
monetary_range_slider = widgets.SelectionRangeSlider(
    options=monetary_values,
    index=(0, 10),
    description='금액 범위:',
    orientation='horizontal',
    layout={'width': '500px'}
)

# Setup checkboxes for selecting columns
checkboxes = [widgets.Checkbox(value=False, description=label) for label in df.columns]
checkbox_container = widgets.VBox(children=[widgets.HBox(checkboxes[i:i+5]) for i in range(0, len(checkboxes), 5)])

# Execution and output functions
def run_query(b):
    with output:
        clear_output(wait=True)
        condition = pd.Series([True] * len(df))
        for field, widget in inputs.items():
            if widget.value.strip():
                condition &= df[field].str.contains(widget.value.strip(), case=False)
        min_val, max_val = monetary_range_slider.value
        if max_val == float('inf'):
            condition &= (df['금액'] >= min_val)
        else:
            condition &= (df['금액'] >= min_val) & (df['금액'] <= max_val)
        filtered_data = df.loc[condition]
        selected_columns = [cb.description for cb in checkboxes if cb.value]
        if filtered_data.empty:
            display(HTML("<div>No data found matching the criteria.</div>"))
        else:
            styled_html = filtered_data[selected_columns].to_html(escape=False, classes='styledTable')
            display(HTML(styled_html))

# Styling for the table
table_style = """
<style>
.styledTable {width: 100%; border-collapse: collapse;}
.styledTable th, .styledTable td {border: 1px solid #dddddd; padding: 8px; text-align: left;}
.styledTable th {background-color: #4CAF50; color: white;}
.styledTable tr:nth-child(even) {background-color: #f2f2f2;}
</style>
"""

# Layout configuration
run_button = widgets.Button(description='조회 실행', button_style='success', icon='search')
run_button.on_click(run_query)
output = widgets.Output()

ui = widgets.VBox([
    widgets.HBox(list(inputs.values()) + [monetary_range_slider]),
    widgets.HBox([run_button]),
    checkbox_container,
    output
])
display(ui)
display(HTML(table_style))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Load and prepare the data
#       6 file_path = 'D:/db/24년 4월 유지가입자.vol1/24년 4월 유지가입자.cs'
# ----> 7 df = pd.read_csv(file_path, encoding='cp949', dtype=str)
#       8 df.fillna('', inplace=True)
#       9 if '금액' in df.columns:
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\envs\Python_v1\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/db/24년 4월 유지가입자.vol1/24년 4월 유지가입자.cs'
