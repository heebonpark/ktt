# %%
import win32com.client as win32
import os

# 저장 폴더 생성
save_folder = os.path.expanduser("~\\Documents\\시설\\일일영업실적_임철우 대시보드\\모음")
os.makedirs(save_folder, exist_ok=True)

# 저장 파일 경로 (마침표 제거한 안전한 파일명 사용)
csv_path = os.path.join(save_folder, "2024-2025_3월_해지대시보드모음.csv")

# 엑셀 앱 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 대상 시트 복사 및 저장
sheet_name = "3"  # 복사할 시트명
ws = wb.Sheets(sheet_name)
ws.Copy()  # 새 워크북으로 복사
new_wb = excel.ActiveWorkbook

# CSV로 저장
new_wb.SaveAs(csv_path, FileFormat=6)  # FileFormat=6 = CSV
new_wb.Close(False)

print(f"✅ CSV 저장 완료: {csv_path}")
# Out:
# ✅ CSV 저장 완료: C:\Users\User\Documents\시설\일일영업실적_임철우 대시보드\모음\2024-2025_3월_해지대시보드모음.csv

# %%
import win32com.client as win32
import os

# 저장 폴더 생성
save_folder = os.path.expanduser("~\\Documents\\시설\\일일실적_해지현황(21년)\\전사해지2401~12월")
os.makedirs(save_folder, exist_ok=True)

# 저장 파일 경로 (마침표 제거한 안전한 파일명 사용)
csv_path = os.path.join(save_folder, "2024년_21년_해지모음(1월~12월).csv")

# 엑셀 앱 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 대상 시트 복사 및 저장
sheet_name = "db"  # 복사할 시트명
ws = wb.Sheets(sheet_name)
ws.Copy()  # 새 워크북으로 복사
new_wb = excel.ActiveWorkbook

# CSV로 저장
new_wb.SaveAs(csv_path, FileFormat=6)  # FileFormat=6 = CSV
new_wb.Close(False)

print(f"✅ CSV 저장 완료: {csv_path}")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[19], line 22
#      19 new_wb = excel.ActiveWorkbook
#      21 # CSV로 저장
# ---> 22 new_wb.SaveAs(csv_path, FileFormat=6)  # FileFormat=6 = CSV
#      23 new_wb.Close(False)
#      25 print(f"✅ CSV 저장 완료: {csv_path}")
#
# File <COMObject <unknown>>:4, in SaveAs(self, Filename, FileFormat, Password, WriteResPassword, ReadOnlyRecommended, CreateBackup, AccessMode, ConflictResolution, AddToMru, TextCodepage, TextVisualLayout, Local)
#
# com_error: (-2147352567, '예외가 발생했습니다.', (0, 'Microsoft Excel', "읽기 전용 문서 '2024년_21년_해지모음(1월~12월).csv'을(를) 열 수 없습니다.", 'xlmain11.chm', 0, -2146827284), None)

# %%
# 파이썬실행
# 1단계 열려있는 엑셀파일 csv파일로 저장

import win32com.client as win32
import os

# 열려 있는 엑셀 인스턴스에 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 대상 시트 지정
# sheet_name = "DB_4.4"  # 작업할 시트 이름
sheet_name = "2412"  # 작업할 시트 이름

csv_path = os.path.expanduser("~\\Documents\\2024년_12월_유지.csv")  # 내 문서에 저장

# 시트 복사 후 CSV로 저장
ws = wb.Sheets(sheet_name)
ws.Copy()  # 새 워크북에 복사
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(csv_path, FileFormat=6)  # CSV
new_wb.Close(False)

print(f"✅ CSV 저장 완료: {csv_path}")
# Out:
# ✅ CSV 저장 완료: C:\Users\User\Documents\2024년_12월_유지.csv

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 열려 있는 엑셀 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 대상 시트명 설정
sheet_name = "해지250101-0410"  # 작업 대상 시트
csv_path = os.path.expanduser("~\\Documents\\해지마감2401_엑셀변환_선택컬럼.csv")

# 3. 시트 복사 → 임시 새 워크북으로 저장
ws = wb.Sheets(sheet_name)
ws.Copy()  # 시트를 새로운 워크북으로 복사
new_wb = excel.ActiveWorkbook
tmp_path = os.path.expanduser("~\\Documents\\__해지마감2401.csv")
new_wb.SaveAs(tmp_path, FileFormat=6)  # CSV로 저장
new_wb.Close(False)

print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. Pandas로 임시 CSV 로드 & 컬럼 미리보기
df = pd.read_csv(tmp_path, encoding='utf-8-sig')
print("✅ 컬럼 미리보기:")
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")

# 5. 원하는 컬럼명 입력 (여기서 사용자 입력 or 직접 설정 가능)
# 아래 줄을 직접 원하는 컬럼명으로 수정 가능
selected_columns = ["계약번호", "상호", "정지시작일자", "정지희망종료일"]  # 예시

# 6. 선택한 컬럼만 필터링
filtered_df = df[selected_columns]

# 7. 최종 CSV로 저장
filtered_df.to_csv(csv_path, index=False, encoding='utf-8-sig')
print(f"🎉 선택한 컬럼만 포함된 CSV 저장 완료: {csv_path}")

# 8. 임시 파일 삭제 (선택)
os.remove(tmp_path)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3 import os
#       5 # 1. 열려 있는 엑셀 인스턴스 연결
# ----> 6 excel = win32.GetActiveObject("Excel.Application")
#       7 wb = excel.ActiveWorkbook
#       9 # 2. 대상 시트명 설정
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\__init__.py:93, in GetActiveObject(Class, clsctx)
#      89 """
#      90 Python friendly version of GetObject's ProgID/CLSID functionality.
#      91 """
#      92 resultCLSID = pywintypes.IID(Class)
# ---> 93 dispatch = pythoncom.GetActiveObject(resultCLSID)
#      94 dispatch = dispatch.QueryInterface(pythoncom.IID_IDispatch)
#      95 return __WrapDispatch(dispatch, Class, resultCLSID=resultCLSID, clsctx=clsctx)
#
# com_error: (-2147221021, '작업을 사용할 수 없습니다.', None, None)

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 열려 있는 엑셀 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 대상 시트명 설정
sheet_name = "해지data"  # 작업 대상 시트
csv_path = os.path.expanduser("~\\Documents\\해지마감2401_엑셀변환_선택컬럼.csv")

# 3. 시트 복사 → 임시 새 워크북으로 저장
ws = wb.Sheets(sheet_name)
ws.Copy()  # 시트를 새로운 워크북으로 복사
new_wb = excel.ActiveWorkbook
tmp_path = os.path.expanduser("~\\Documents\\해지마감2401.csv")
new_wb.SaveAs(tmp_path, FileFormat=6)  # CSV로 저장
new_wb.Close(False)

print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. Pandas로 임시 CSV 로드 & 컬럼 미리보기
df = pd.read_csv(tmp_path, encoding='utf-8-sig')
print("✅ 컬럼 미리보기:")
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")

# 5. 원하는 컬럼명 입력 (여기서 사용자 입력 or 직접 설정 가능)
# 아래 줄을 직접 원하는 컬럼명으로 수정 가능
selected_columns = ["관리본부", "관리지사", "기본서비스(대)", "계약번호", "상호", "KTT월정료(조정)", "시설구분", "요금구분", "해지일자", "채널구분"]  # 예시

# 6. 선택한 컬럼만 필터링
filtered_df = df[selected_columns]

# 7. 최종 CSV로 저장
filtered_df.to_csv(csv_path, index=False, encoding='utf-8-sig')
print(f"🎉 선택한 컬럼만 포함된 CSV 저장 완료: {csv_path}")

# 8. 임시 파일 삭제 (선택)
os.remove(tmp_path)
# Out:
# ✅ 임시 CSV 저장 완료: C:\Users\User\Documents\해지마감2401.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 24
#      21 print(f"✅ 임시 CSV 저장 완료: {tmp_path}")
#      23 # 4. Pandas로 임시 CSV 로드 & 컬럼 미리보기
# ---> 24 df = pd.read_csv(tmp_path, encoding='utf-8-sig')
#      25 print("✅ 컬럼 미리보기:")
#      26 for i, col in enumerate(df.columns, start=1):
#
# ...

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 열려 있는 엑셀 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 대상 시트명 설정
sheet_name = "해지data"  # 작업 대상 시트
tmp_path = os.path.expanduser("~\\Documents\\__임시_해지마감2401.csv")
final_csv_path = os.path.expanduser("~\\Documents\\해지마감2401_선택컬럼.csv")

# 3. 시트 복사 → 임시 새 워크북으로 저장
ws = wb.Sheets(sheet_name)
ws.Copy()  # 시트를 새로운 워크북으로 복사
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)  # CSV로 저장
new_wb.Close(False)

print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. Pandas로 임시 CSV 로드 & 컬럼 미리보기
df = pd.read_csv(tmp_path, encoding='utf-8-sig')
print("\n✅ 컬럼 미리보기:")
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")

# 5. 원하는 컬럼명 지정 (존재하지 않는 컬럼은 무시되도록 처리)
requested_columns = ["관리본부", "관리지사", "기본서비스(대)", "계약번호", "상호",
                     "KTT월정료(조정)", "시설구분", "요금구분", "해지일자", "채널구분"]

# 실제 존재하는 컬럼만 필터링
selected_columns = [col for col in requested_columns if col in df.columns]

if not selected_columns:
    print("⚠️ 요청한 컬럼 중 유효한 컬럼이 없습니다. 저장을 중단합니다.")
else:
    filtered_df = df[selected_columns]

    # 6. 최종 CSV 저장
    filtered_df.to_csv(final_csv_path, index=False, encoding='utf-8-sig')
    print(f"\n🎉 선택한 컬럼만 포함된 CSV 저장 완료: {final_csv_path}")

# 7. 임시 파일 삭제
os.remove(tmp_path)
# Out:
# ✅ 임시 CSV 저장 완료: C:\Users\User\Documents\__임시_해지마감2401.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 24
#      21 print(f"✅ 임시 CSV 저장 완료: {tmp_path}")
#      23 # 4. Pandas로 임시 CSV 로드 & 컬럼 미리보기
# ---> 24 df = pd.read_csv(tmp_path, encoding='utf-8-sig')
#      25 print("\n✅ 컬럼 미리보기:")
#      26 for i, col in enumerate(df.columns, start=1):
#
# ...

# %%
# import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 대상 시트명 및 파일 경로 설정
sheet_name = "해지data"
tmp_path = os.path.expanduser("~\\Documents\\__임시_해지마감2401.csv")
final_csv_path = os.path.expanduser("~\\Documents\\해지마감2401_선택컬럼.csv")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)  # FileFormat=6 → CSV
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지하여 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 감지 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 모든 인코딩 방식 실패. 중단합니다.")
    exit()

# 5. 컬럼 미리보기 출력
print("\n📌 시트에 포함된 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

# 6. 선택할 컬럼 번호 입력
input_str = input("\n✅ 저장할 컬럼 번호를 쉼표(,)로 입력하세요 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in input_str.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

# 7. 선택된 컬럼만 저장
if selected_columns:
    df[selected_columns].to_csv(final_csv_path, index=False, encoding='utf-8-sig')
    print(f"\n🎉 선택한 컬럼만 포함된 CSV 저장 완료: {final_csv_path}")
else:
    print("⚠️ 선택된 컬럼이 없습니다. CSV 저장을 생략합니다.")

# 8. 임시 파일 삭제
os.remove(tmp_path)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[17], line 6
#       3 import os
#       5 # 1. 엑셀 열려 있는 인스턴스 연결
# ----> 6 excel = win32.GetActiveObject("Excel.Application")
#       7 wb = excel.ActiveWorkbook
#       9 # 2. 대상 시트명 및 파일 경로 설정
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\__init__.py:93, in GetActiveObject(Class, clsctx)
#      89 """
#      90 Python friendly version of GetObject's ProgID/CLSID functionality.
#      91 """
#      92 resultCLSID = pywintypes.IID(Class)
# ---> 93 dispatch = pythoncom.GetActiveObject(resultCLSID)
#      94 dispatch = dispatch.QueryInterface(pythoncom.IID_IDispatch)
#      95 return __WrapDispatch(dispatch, Class, resultCLSID=resultCLSID, clsctx=clsctx)
#
# com_error: (-2147221021, '작업을 사용할 수 없습니다.', None, None)

# %%
# 데이터프레임의 컬럼명 확인
print("해지data")
print(df.columns.tolist())
# Out:
# 해지data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 데이터프레임의 컬럼명 확인
#       2 print("해지data")
# ----> 3 print(df.columns.tolist())
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 해지

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "해지data"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("~\\Documents\\__임시_해지마감2401.csv")
final_csv_path = os.path.expanduser("~\\Documents\\해지마감2401_선택컬럼_필터적용.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["요금구분", "채널구분", "관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
    (df["요금구분"] == "대상") &
    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
    (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[15], line 6
#       3 import os
#       5 # 1. 엑셀 열려 있는 인스턴스 연결
# ----> 6 excel = win32.GetActiveObject("Excel.Application")
#       7 wb = excel.ActiveWorkbook
#       9 # 2. 시트명 고정: "해지data"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\__init__.py:93, in GetActiveObject(Class, clsctx)
#      89 """
#      90 Python friendly version of GetObject's ProgID/CLSID functionality.
#      91 """
#      92 resultCLSID = pywintypes.IID(Class)
# ---> 93 dispatch = pythoncom.GetActiveObject(resultCLSID)
#      94 dispatch = dispatch.QueryInterface(pythoncom.IID_IDispatch)
#      95 return __WrapDispatch(dispatch, Class, resultCLSID=resultCLSID, clsctx=clsctx)
#
# com_error: (-2147221021, '작업을 사용할 수 없습니다.', None, None)

# %% [markdown]
# ## 월별 유지시설중 관리본부명 강원본부, 서부본부를 현기준 현행화

# %%
import xlwings as xw

# 열려 있는 엑셀 파일에서 '3월' 시트 선택
wb = xw.apps.active.books.active
ws = wb.sheets['3월']

# B열 데이터 읽기
관리본부_range = ws.range('B1').expand('down')
관리본부_values = 관리본부_range.value

# B1이 '관리본부'인지 확인
if not 관리본부_values or 관리본부_values[0] != '관리본부명':
    raise ValueError("B1 셀이 '관리본부'가 아닙니다.")

# 정제된 리ㅁ스트 생성
정제된_값들 = ['본부명_정제']
for val in 관리본부_values[1:]:
    if val == '강원본부':
        정제된_값들.append('강북/강원본부')
    elif val == '서부본부':
        정제된_값들.append('강남/서부본부')
    else:
        정제된_값들.append(val)

# A열에 그대로 덮어쓰기
ws.range('A1').value = [[v] for v in 정제된_값들]

# %%
import xlwings as xw

# 엑셀 열기 및 시트 선택
wb = xw.apps.active.books.active
ws = wb.sheets['3월']

# D열 전체 읽기
관리지사_range = ws.range('D1').expand('down')
관리지사_values = 관리지사_range.value

# 헤더 확인
if not 관리지사_values or 관리지사_values[0] != '관리지사명':
    raise ValueError("D1 셀이 '관리지사명'이 아닙니다.")

# D2부터 끝까지 값만 수정
for i, val in enumerate(관리지사_values[1:], start=2):  # i는 Excel 행 번호
    if val == '춘천고객지원팀':
        ws.range(f'D{i}').value = '원주지사'

# %%
import xlwings as xw

# 엑셀 열기 및 '3월' 시트 선택
wb = xw.apps.active.books.active
ws = wb.sheets['3월']

# ===== 1. B열 '관리본부명' → A열에 정제된 값 덮어쓰기 =====
관리본부_range = ws.range('B1').expand('down')
관리본부_values = 관리본부_range.value

if not 관리본부_values or 관리본부_values[0] != '관리본부명':
    raise ValueError("B1 셀이 '관리본부명'이 아닙니다.")

정제된_값들 = ['본부명_정제']
for val in 관리본부_values[1:]:
    if val == '강원본부':
        정제된_값들.append('강북/강원본부')
    elif val == '서부본부':
        정제된_값들.append('강남/서부본부')
    else:
        정제된_값들.append(val)

ws.range('A1').value = [[v] for v in 정제된_값들]

# ===== 2. D열 '관리지사명'에서 '춘천고객지원팀' → '원주지사' =====
관리지사_range = ws.range('D1').expand('down')
관리지사_values = 관리지사_range.value

if not 관리지사_values or 관리지사_values[0] != '관리지사명':
    raise ValueError("D1 셀이 '관리지사명'이 아닙니다.")

for i, val in enumerate(관리지사_values[1:], start=2):
    if val == '춘천고객지원팀':
        ws.range(f'D{i}').value = '원주지사'

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "3월"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출2403.csv")
final_csv_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출 선택컬럼_2403.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
#    (df["요금구분"] == "대상") &
#    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
#   (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)

# # 조건컬럼 2,4,5,7,9,10,11,12,14,15,16,19,25,166,41,42,52,100,154,121,143,169,157,160,,168
# Out:
# ▶️ 선택된 시트: 3월
# ✅ 임시 CSV 저장 완료: D:\시설\유지\2025\3월\3월마감 조건추출2403.csv
# ❌ 인코딩 실패: utf-8-sig
# C:\Users\User\AppData\Local\Temp\ipykernel_19376\1306040618.py:36: DtypeWarning: Columns (17,23,33,49,50,55,63,67,70,83,96,97,98,109,112,119,121,152,155,163,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tmp_path, encoding=enc)
# ✅ 인코딩 성공: cp949
#
# 📋 시트 컬럼 목록:
# 1. 관리본부코드
# 2. 관리본부명
# 3. 관리지사코드
# 4. 관리지사명
# 5. 고객번호
# 6. 고객명
# 7. 계약번호
# 8. 계약자명
# 9. 서비스번호
# 10. 서비스(대)
# 11. 서비스(중)
# 12. 서비스(소)
# 13. 영상전환일
# 14. 상호
# 15. 고객구분
# 16. 사업용구분
# 17. 주민등록번호
# 18. 사업자번호
# 19. 계약상태(대)
# 20. 계약상태(중)
# 21. 서비스상태(대)
# 22. 서비스상태(중)
# 23. 접속전화번호
# 24. 설치우편번호
# 25. 설치주소
# 26. 견적월정료
# 27. 월정료
# 28. 할인율
# 29. 계약개월수
# 30. 월정료면제사유
# 31. 면제시작일
# 32. 면제종료일
# 33. 계약보증금
# 34. 보증금면제사유
# 35. 판매상품비
# 36. 견적설치공사비
# 37. 설치공사할부개월
# 38. 계약공사비
# 39. 면제공사비
# 40. 실징수액
# 41. 계약시작일
# 42. 계약종료일
# 43. 영업구분
# 44. 추천구분
# 45. 추천경로
# 46. 영업본부코드
# 47. 영업본부명
# 48. 영업지사코드
# 49. 영업지사명
# ...

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "3월"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출2403.csv")
final_csv_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출 선택컬럼_2403.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
#    (df["요금구분"] == "대상") &
#    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
#   (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)

# # 조건컬럼 2,4,5,7,9,10,11,12,14,15,16,19,25,166,41,42,52,100,154,121,143,169,157,160,,168
# Out:
# ❌ 시트명 '3월'이 엑셀에 존재하지 않습니다.
# 📌 시트 목록: ['3월마감 조건추출 선택컬럼_2403']
# ▶️ 선택된 시트: 3월
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[1], line 24
#      21 tmp_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출2403.csv")
#      22 final_csv_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출 선택컬럼_2403.csv")
# ---> 24 ws = wb.Sheets(sheet_name)
#      25 ws.Copy()
#      26 new_wb = excel.ActiveWorkbook
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\dynamic.py:226, in CDispatch.__call__(self, *args)
#     223 if invkind is not None:
#     224     allArgs = (dispid, LCID, invkind, 1) + args
#     225     return self._get_good_object_(
# --> 226         self._oleobj_.Invoke(*allArgs), self._olerepr_.defaultDispatchName, None
#     227     )
#     228 raise TypeError("This dispatch object does not define a default method")
#
# ...

# %%
import xlwings as xw

# 엑셀 열기 및 '3월' 시트 선택
wb = xw.apps.active.books.active
ws = wb.sheets['분석']

# ===== 1. B열 '관리본부명' → A열에 정제된 값 덮어쓰기 =====
관리본부_range = ws.range('B1').expand('down')
관리본부_values = 관리본부_range.value

if not 관리본부_values or 관리본부_values[0] != '관리본부':
    raise ValueError("B1 셀이 '관리본부명'이 아닙니다.")

정제된_값들 = ['본부명_정제']
for val in 관리본부_values[1:]:
    if val == '강원본부':
        정제된_값들.append('강북/강원본부')
    elif val == '서부본부':
        정제된_값들.append('강남/서부본부')
    else:
        정제된_값들.append(val)

ws.range('A1').value = [[v] for v in 정제된_값들]

# ===== 2. D열 '관리지사명'에서 '춘천고객지원팀' → '원주지사' =====
관리지사_range = ws.range('D1').expand('down')
관리지사_values = 관리지사_range.value

if not 관리지사_values or 관리지사_values[0] != '관리지사':
    raise ValueError("D1 셀이 '관리지사명'이 아닙니다.")

for i, val in enumerate(관리지사_values[1:], start=2):
    if val == '춘천고객지원팀':
        ws.range(f'D{i}').value = '원주지사'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 30
#      27 관리지사_values = 관리지사_range.value
#      29 if not 관리지사_values or 관리지사_values[0] != '관리지사':
# ---> 30     raise ValueError("D1 셀이 '관리지사명'이 아닙니다.")
#      32 for i, val in enumerate(관리지사_values[1:], start=2):
#      33     if val == '춘천고객지원팀':
#
# ValueError: D1 셀이 '관리지사명'이 아닙니다.

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "해지250101-0410"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\분석\\25년해지분석(01-0410)조건추출240415.csv")
final_csv_path = os.path.expanduser"D:\\시설\\분석\\25년해지분석(01-0410)조건추출240415.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
#    (df["요금구분"] == "대상") &
#    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
#   (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)
# Out:
#   Cell In[25], line 22
#     final_csv_path = os.path.expanduser"D:\\시설\\분석\\25년해지분석(01-0410)조건추출240415.csv")
#                                                                                    ^
# SyntaxError: unmatched ')'

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "해지data"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\분석\\temp_해지data.csv")
final_csv_path = os.path.expanduser("D:\\시설\\분석\\25년해지분석(01-0410)조건추출240415.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
filtered_df = df[
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 import os
#       5 # 1. 엑셀 열려 있는 인스턴스 연결
# ----> 6 excel = win32.GetActiveObject("Excel.Application")
#       7 wb = excel.ActiveWorkbook
#       9 # 2. 시트명 고정: "해지data"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\__init__.py:93, in GetActiveObject(Class, clsctx)
#      89 """
#      90 Python friendly version of GetObject's ProgID/CLSID functionality.
#      91 """
#      92 resultCLSID = pywintypes.IID(Class)
# ---> 93 dispatch = pythoncom.GetActiveObject(resultCLSID)
#      94 dispatch = dispatch.QueryInterface(pythoncom.IID_IDispatch)
#      95 return __WrapDispatch(dispatch, Class, resultCLSID=resultCLSID, clsctx=clsctx)
#
# com_error: (-2147221021, '작업을 사용할 수 없습니다.', None, None)

# %% [markdown]
# ## csv.cs.xls.xlsm

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 인스턴스 자동 연결
try:
    excel = win32.GetActiveObject("Excel.Application")
    print("✅ 기존 엑셀 인스턴스 연결됨")
except:
    excel = win32.Dispatch("Excel.Application")
    print("✅ 새 엑셀 인스턴스 실행됨")

excel.Visible = True

# 2. 열려 있는 파일 중 하나 선택 (자동 or 수동)
workbooks = excel.Workbooks
if workbooks.Count == 0:
    print("❌ 열려 있는 엑셀 파일이 없습니다. 수동으로 열어주세요.")
    exit()

print("\n📁 열려 있는 엑셀 파일 목록:")
for i in range(workbooks.Count):
    print(f"{i+1}. {workbooks.Item(i+1).Name}")

file_index = int(input("\n🔢 분석할 파일 번호를 선택하세요: ")) - 1
wb = workbooks.Item(file_index + 1)

# 3. 시트 목록 확인
sheet_names = [sheet.Name for sheet in wb.Sheets]
print("\n📄 시트 목록:")
for i, name in enumerate(sheet_names):
    print(f"{i+1}. {name}")

sheet_index = int(input("\n🔢 분석할 시트 번호를 선택하세요: ")) - 1
sheet_name = sheet_names[sheet_index]
print(f"\n▶️ 선택된 시트: {sheet_name}")

# 4. 시트 복사 후 임시 CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\분석\\temp_해지data.csv")
final_csv_path = os.path.expanduser("D:\\시설\\분석\\25년해지분석(조건추출).csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)  # FileFormat=6 → CSV
new_wb.Close(False)
print(f"✅ 시트를 임시 CSV로 저장: {tmp_path}")

# 5. CSV 인코딩 자동 감지 및 로딩
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except Exception:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 6. 컬럼 선택
print("\n📋 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호 입력 (예: 1,3,5): ").strip()
if not col_input:
    print("⚠️ 컬럼 선택이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 유효하지 않습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 7. 필터 적용
required_cols = ["관리본부명", "서비스(대)"]
if not all(col in df.columns for col in required_cols):
    print(f"⚠️ 필수 컬럼이 누락됨: {required_cols}")
    os.remove(tmp_path)
    exit()

filtered_df = df[df["서비스(대)"].str.strip() == "기본서비스"]

# 8. 최종 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용된 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)
# Out:
# ✅ 새 엑셀 인스턴스 실행됨
# ❌ 열려 있는 엑셀 파일이 없습니다. 수동으로 열어주세요.
#
# 📁 열려 있는 엑셀 파일 목록:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 25
#      22 for i in range(workbooks.Count):
#      23     print(f"{i+1}. {workbooks.Item(i+1).Name}")
# ---> 25 file_index = int(input("\n🔢 분석할 파일 번호를 선택하세요: ")) - 1
#      26 wb = workbooks.Item(file_index + 1)
#      28 # 3. 시트 목록 확인
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# ...

# %%
pip install xlwings
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xlwings as xw
import pandas as pd

# ✅ 현재 열려있는 엑셀 파일 가져오기
wb = xw.apps.active.books.active

# ✅ 시트 객체 지정
sheet_2501 = wb.sheets['2501']
sheet_2502 = wb.sheets['2502']

# ✅ 시트 내용을 데이터프레임으로 불러오기
df_2501 = sheet_2501.range('A1').options(pd.DataFrame, header=1, index=False, expand='table').value
df_2502 = sheet_2502.range('H1').options(pd.DataFrame, header=1, index=False, expand='table').value

# ✅ 필수 컬럼 존재 확인
if '서비스(소)' not in df_2501.columns or 'L/i(BM)' not in df_2501.columns:
    raise ValueError("2501 시트에 '서비스(소)' 또는 'L/i(BM)' 컬럼이 없습니다.")
if '서비스(소)' not in df_2502.columns or 'L/i(BM)' not in df_2502.columns:
    raise ValueError("2502 시트에 '서비스(소)' 또는 'L/i(BM)' 컬럼이 없습니다.")

# ✅ 2502에서 서비스(소) 기준 L/i(BM) 매핑
mapping_dict = df_2502.set_index('서비스(소)')['L/i(BM)'].dropna().to_dict()

# ✅ 적용: 2501에서 비어있는 경우만 업데이트
updated_count = 0
for i in df_2501.index:
    current_val = df_2501.at[i, 'L/i(BM)']
    service_key = df_2501.at[i, '서비스(소)']
    if pd.isna(current_val) and service_key in mapping_dict:
        df_2501.at[i, 'L/i(BM)'] = mapping_dict[service_key]
        updated_count += 1

# ✅ 수정된 df 다시 엑셀에 반영
sheet_2501.range('A1').value = [df_2501.columns.tolist()] + df_2501.values.tolist()

print(f"✅ 완료: 총 {updated_count}개의 'L/i(BM)' 셀이 업데이트 되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 19
#      17     raise ValueError("2501 시트에 '서비스(소)' 또는 'L/i(BM)' 컬럼이 없습니다.")
#      18 if '서비스(소)' not in df_2502.columns or 'L/i(BM)' not in df_2502.columns:
# ---> 19     raise ValueError("2502 시트에 '서비스(소)' 또는 'L/i(BM)' 컬럼이 없습니다.")
#      21 # ✅ 2502에서 서비스(소) 기준 L/i(BM) 매핑
#      22 mapping_dict = df_2502.set_index('서비스(소)')['L/i(BM)'].dropna().to_dict()
#
# ValueError: 2502 시트에 '서비스(소)' 또는 'L/i(BM)' 컬럼이 없습니다.

# %% [markdown]
# ## 유지시설 시트 조건 병합

# %%
import win32com.client as win32
import pandas as pd
import os
import traceback

# ✅ 추출할 컬럼들
merge_columns = [
    '관리본부명', '관리지사명', '계약번호', '상호', 'L/i(BM)', '서비스(소)', '서비스상태(중)',
    '시설구분', '요금구분', '영업구역정보', 'KTT월정료', '제외사유'
]

save_path = r'D:\병합결과_선택컬럼.csv'

# ✅ 엑셀 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# ✅ 병합 대상 시트 (수동 or 자동 선택)
target_sheets = [sheet.Name for sheet in wb.Sheets]

# ✅ 중간 저장 리스트 (병합은 마지막에)
all_data = []

for sheet_name in target_sheets:
    try:
        ws = wb.Sheets(sheet_name)
        used_range = ws.UsedRange
        n_rows = used_range.Rows.Count
        n_cols = used_range.Columns.Count

        if n_rows < 2:
            print(f"⚠️ 시트 '{sheet_name}'은 비어있음")
            continue

        # 필요한 범위만 불러오기 (전체 셀 말고)
        data = ws.Range(ws.Cells(1,1), ws.Cells(n_rows, n_cols)).Value

        if not data:
            continue

        headers = data[0]
        records = data[1:]

        df = pd.DataFrame(records, columns=headers)
        valid_cols = [col for col in merge_columns if col in df.columns]

        if valid_cols:
            filtered = df[valid_cols].copy()
            filtered['출처시트'] = sheet_name
            all_data.append(filtered)

    except Exception as e:
        print(f"❌ 시트 '{sheet_name}' 오류 발생:")
        print(traceback.format_exc())

# ✅ 메모리 효율적으로 병합
if all_data:
    result_df = pd.concat(all_data, ignore_index=True)
    result_df.to_csv(save_path, index=False, encoding='utf-8-sig', errors='ignore')
    print(f"✅ 저장 완료: {save_path}")
    print(f"총 행 수: {len(result_df)}")
else:
    print("⚠️ 병합할 데이터가 없습니다.")
# Out:
# ❌ 시트 '2411' 오류 발생:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_22220\1891737260.py", line 36, in <module>
#     data = ws.Range(ws.Cells(1,1), ws.Cells(n_rows, n_cols)).Value
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\dynamic.py", line 628, in __getattr__
#     ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pywintypes.com_error: (-2147024882, '메모리 리소스가 부족하기 때문에 이 작업을 완료할 수 없습니다.', None, None)

# %%
import win32com.client as win32
import pandas as pd
import os
import traceback

# ✅ 공통 추출 컬럼
extract_columns = [
   '관리본부명', '관리지사명', '계약번호', '상호', 'L/i(BM)', '서비스(소)', '서비스상태(중)',
    '시설구분', '요금구분', '영업구역정보', 'KTT월정료', '제외사유'
]

# ✅ 저장 폴더 (원하는 경로로 변경)
output_dir = r'D:\시트별_저장결과'
os.makedirs(output_dir, exist_ok=True)

# ✅ 엑셀 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# ✅ 시트 목록 가져오기
sheet_names = [sheet.Name for sheet in wb.Sheets]

for sheet_name in sheet_names:
    try:
        print(f"\n▶️ 시트 처리 중: {sheet_name}")

        ws = wb.Sheets(sheet_name)

        # 1행 헤더 읽기 (A1 ~ AX1까지 50개 컬럼)
        headers = ws.Range("A1", ws.Cells(1, 50)).Value[0]
        if not headers or all(h is None for h in headers):
            print(f"⚠️ 시트 '{sheet_name}'에 유효한 헤더 없음, 건너뜀")
            continue

        # 최대 5000행까지 제한해서 읽기
        max_rows = 5000
        max_cols = len(headers)
        data_range = ws.Range(ws.Cells(1, 1), ws.Cells(max_rows, max_cols)).Value

        df = pd.DataFrame(data_range[1:], columns=headers)

        # 유효한 컬럼만 필터링
        valid_cols = [col for col in extract_columns if col in df.columns]
        if not valid_cols:
            print(f"⚠️ 시트 '{sheet_name}'에 추출 가능한 컬럼 없음")
            continue

        filtered_df = df[valid_cols].copy()

        # 저장 파일 경로
        file_name = f"{sheet_name}_조건컬럼.csv"
        file_path = os.path.join(output_dir, file_name)

        # CSV 저장
        filtered_df.to_csv(file_path, index=False, encoding='utf-8-sig')
        print(f"✅ 저장 완료: {file_path}")

    except Exception as e:
        print(f"❌ 시트 '{sheet_name}' 오류 발생:")
        print(traceback.format_exc())
# Out:
# ▶️ 시트 처리 중: 2411
# ✅ 저장 완료: D:\시트별_저장결과\2411_조건컬럼.csv
#
# ▶️ 시트 처리 중: 2412
# ✅ 저장 완료: D:\시트별_저장결과\2412_조건컬럼.csv
#
# ▶️ 시트 처리 중: 2501
# ✅ 저장 완료: D:\시트별_저장결과\2501_조건컬럼.csv
#
# ▶️ 시트 처리 중: 2502
# ✅ 저장 완료: D:\시트별_저장결과\2502_조건컬럼.csv
#
# ▶️ 시트 처리 중: 2503
# ✅ 저장 완료: D:\시트별_저장결과\2503_조건컬럼.csv
#
# ▶️ 시트 처리 중: Sheet6
# ✅ 저장 완료: D:\시트별_저장결과\Sheet6_조건컬럼.csv

# %%
import os
import pandas as pd

# ✅ 시트별 CSV 저장된 폴더 경로
folder_path = r'D:\시트별_저장결과'

# ✅ 최종 병합된 파일 저장 경로
output_file = os.path.join(folder_path, '병합_조건컬럼_전체.csv')

# ✅ CSV 병합 처리
merged_data = []

for filename in os.listdir(folder_path):
    if filename.endswith('.csv') and '_조건컬럼' in filename:
        file_path = os.path.join(folder_path, filename)
        try:
            df = pd.read_csv(file_path, encoding='utf-8-sig')
            df['출처파일'] = filename.replace('_조건컬럼.csv', '')
            merged_data.append(df)
        except Exception as e:
            print(f"❌ 파일 '{filename}' 읽기 오류: {e}")

# ✅ 병합 및 저장
if merged_data:
    result_df = pd.concat(merged_data, ignore_index=True)
    result_df.to_csv(output_file, index=False, encoding='utf-8-sig')
    print(f"✅ 병합 완료: {output_file}")
    print(f"▶️ 총 행 수: {len(result_df)}")
else:
    print("⚠️ 병합할 CSV 파일이 없습니다.")
# Out:
# ✅ 병합 완료: D:\시트별_저장결과\병합_조건컬럼_전체.csv
# ▶️ 총 행 수: 24995

# %%
import win32com.client as win32
import pandas as pd
import os
import traceback

# ▶️ 추출할 컬럼 리스트
extract_columns = [
  '관리본부명', '관리지사명', '계약번호', '상호', 'L/i(BM)', '서비스(소)', '서비스상태(중)',
    '시설구분', '요금구분', '영업구역정보', 'KTT월정료', '제외사유'
]

# ▶️ 저장 폴더 경로
output_dir = r'D:\시트별_저장결과'
os.makedirs(output_dir, exist_ok=True)

# ▶️ 엑셀 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# ▶️ 시트 전체 반복
for sheet in wb.Sheets:
    sheet_name = sheet.Name
    try:
        print(f"\n▶️ 시트 처리 중: {sheet_name}")
        used_range = sheet.UsedRange
        n_rows = used_range.Rows.Count
        n_cols = used_range.Columns.Count

        # 전체 데이터 범위만큼 불러오기
        data = sheet.Range(sheet.Cells(1,1), sheet.Cells(n_rows, n_cols)).Value

        if not data or len(data) < 2:
            print(f"⚠️ 시트 '{sheet_name}' 데이터 없음, 건너뜀")
            continue

        headers = data[0]
        records = data[1:]
        df = pd.DataFrame(records, columns=headers)

        # 추출 컬럼 필터링
        valid_cols = [col for col in extract_columns if col in df.columns]
        if not valid_cols:
            print(f"⚠️ 유효 컬럼 없음: {sheet_name}")
            continue

        filtered_df = df[valid_cols].copy()
        file_name = f"{sheet_name}_조건컬럼.csv"
        file_path = os.path.join(output_dir, file_name)
        filtered_df.to_csv(file_path, index=False, encoding='utf-8-sig')

        print(f"✅ 저장 완료: {file_path} (총 {len(filtered_df)}행)")

    except Exception as e:
        print(f"❌ 오류 발생 @ 시트 {sheet_name}")
        print(traceback.format_exc())
# Out:
# ▶️ 시트 처리 중: 2411
# ❌ 오류 발생 @ 시트 2411
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_22220\1837252320.py", line 30, in <module>
#     data = sheet.Range(sheet.Cells(1,1), sheet.Cells(n_rows, n_cols)).Value
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\dynamic.py", line 628, in __getattr__
#     ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pywintypes.com_error: (-2147024882, '메모리 리소스가 부족하기 때문에 이 작업을 완료할 수 없습니다.', None, None)
#
#
# ▶️ 시트 처리 중: 2412
# ✅ 저장 완료: D:\시트별_저장결과\2412_조건컬럼.csv (총 435790행)
#
# ▶️ 시트 처리 중: 2501
# ❌ 오류 발생 @ 시트 2501
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_22220\1837252320.py", line 30, in <module>
#     data = sheet.Range(sheet.Cells(1,1), sheet.Cells(n_rows, n_cols)).Value
# ...

# %%
import win32com.client as win32
import csv
import os
import traceback

# ▶️ 조건 컬럼
extract_columns = [
    '관리본부명', '관리지사명', '계약번호', '상호', 'L/i(BM)', '서비스(소)', '서비스상태(중)',
    '시설구분', '요금구분', '영업구역정보', 'KTT월정료', '제외사유'
]

# ▶️ 저장 폴더
output_dir = r'D:\시트별_저장결과'
os.makedirs(output_dir, exist_ok=True)

# ▶️ Excel 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook
sheets = wb.Sheets

for sheet in sheets:
    try:
        sheet_name = sheet.Name
        print(f"\n▶️ 시트 처리 시작: {sheet_name}")

        used_range = sheet.UsedRange
        n_rows = used_range.Rows.Count
        n_cols = used_range.Columns.Count
        print(f"행 수: {n_rows}, 열 수: {n_cols}")

        # 헤더 불러오기
        header_range = sheet.Range(sheet.Cells(1, 1), sheet.Cells(1, n_cols)).Value[0]
        col_indices = {col: idx for idx, col in enumerate(header_range) if col in extract_columns}

        if not col_indices:
            print(f"⚠️ 추출할 컬럼 없음, 건너뜀: {sheet_name}")
            continue

        # 저장 경로
        file_name = f"{sheet_name}_조건컬럼.csv"
        file_path = os.path.join(output_dir, file_name)

        with open(file_path, mode='w', newline='', encoding='utf-8-sig') as f:
            writer = csv.writer(f)
            writer.writerow(col_indices.keys())  # 헤더 저장

            # 각 행 순회하며 추출 컬럼만 저장
            for i in range(2, n_rows + 1):
                row_values = sheet.Range(sheet.Cells(i, 1), sheet.Cells(i, n_cols)).Value[0]
                if row_values:
                    selected = [row_values[col_indices[col]] if col_indices[col] < len(row_values) else '' for col in col_indices]
                    writer.writerow(selected)

        print(f"✅ 저장 완료: {file_path}")

    except Exception as e:
        print(f"❌ 오류 발생 @ 시트 '{sheet.Name}'")
        print(traceback.format_exc())
# Out:
# ▶️ 시트 처리 시작: 2411
# 행 수: 394348, 열 수: 174
# ✅ 저장 완료: D:\시트별_저장결과\2411_조건컬럼.csv
#
# ▶️ 시트 처리 시작: 2412
# 행 수: 435791, 열 수: 52
# ✅ 저장 완료: D:\시트별_저장결과\2412_조건컬럼.csv
#
# ▶️ 시트 처리 시작: 2501
# 행 수: 440614, 열 수: 173
# ✅ 저장 완료: D:\시트별_저장결과\2501_조건컬럼.csv
#
# ▶️ 시트 처리 시작: 2502
# 행 수: 440439, 열 수: 89
# ✅ 저장 완료: D:\시트별_저장결과\2502_조건컬럼.csv
#
# ▶️ 시트 처리 시작: 2503
# 행 수: 441041, 열 수: 173
# ✅ 저장 완료: D:\시트별_저장결과\2503_조건컬럼.csv
#
# ▶️ 시트 처리 시작: Sheet6
# 행 수: 440439, 열 수: 2
# ✅ 저장 완료: D:\시트별_저장결과\Sheet6_조건컬럼.csv

# %%
N-VOC

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "상세데이터"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\N-VOC분석\\병합\\NVOC240131.csv")
final_csv_path = os.path.expanduser("D:\\시설\\N-VOC분석\\병합\\NVOC240131_1.csv")

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
#    (df["요금구분"] == "대상") &
#    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
#   (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)

# # 조건컬럼 2,4,5,7,9,10,11,12,14,15,16,19,25,166,41,42,52,100,132,133,154,121,143,169,157,160,,168
# Out:
# ❌ 시트명 '상세데이터'이 엑셀에 존재하지 않습니다.
# 📌 시트 목록: ['3월']
# ▶️ 선택된 시트: 상세데이터
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[1], line 24
#      21 tmp_path = os.path.expanduser("D:\\시설\\N-VOC분석\\병합\\NVOC240131.csv")
#      22 final_csv_path = os.path.expanduser("D:\\시설\\N-VOC분석\\병합\\NVOC240131_1.csv")
# ---> 24 ws = wb.Sheets(sheet_name)
#      25 ws.Copy()
#      26 new_wb = excel.ActiveWorkbook
#
# File C:\ProgramData\anaconda3\Lib\site-packages\win32com\client\dynamic.py:226, in CDispatch.__call__(self, *args)
#     223 if invkind is not None:
#     224     allArgs = (dispid, LCID, invkind, 1) + args
#     225     return self._get_good_object_(
# --> 226         self._oleobj_.Invoke(*allArgs), self._olerepr_.defaultDispatchName, None
#     227     )
#     228 raise TypeError("This dispatch object does not define a default method")
#
# ...

# %%
import win32com.client as win32
import pandas as pd
import os

# 1. 엑셀 열려 있는 인스턴스 연결
excel = win32.GetActiveObject("Excel.Application")
wb = excel.ActiveWorkbook

# 2. 시트명 고정: "해지data"
sheet_name = "3월"
sheet_names = [sheet.Name for sheet in wb.Sheets]

if sheet_name not in sheet_names:
    print(f"❌ 시트명 '{sheet_name}'이 엑셀에 존재하지 않습니다.")
    print("📌 시트 목록:", sheet_names)
    exit()

print(f"▶️ 선택된 시트: {sheet_name}")

# 3. 시트 복사 → 임시 워크북 → CSV 저장
tmp_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\_temp_3월마감.csv")  # ✅ 임시 파일로 수정
final_csv_path = os.path.expanduser("D:\\시설\\유지\\2025\\3월\\3월마감 조건추출 선택컬럼_2403.csv")

# 이후 동일...

ws = wb.Sheets(sheet_name)
ws.Copy()
new_wb = excel.ActiveWorkbook
new_wb.SaveAs(tmp_path, FileFormat=6)
new_wb.Close(False)
print(f"✅ 임시 CSV 저장 완료: {tmp_path}")

# 4. 인코딩 자동 감지 후 읽기
encodings = ["utf-8-sig", "cp949", "euc-kr", "utf-8"]
df = None
for enc in encodings:
    try:
        df = pd.read_csv(tmp_path, encoding=enc)
        print(f"✅ 인코딩 성공: {enc}")
        break
    except UnicodeDecodeError:
        print(f"❌ 인코딩 실패: {enc}")

if df is None:
    print("❌ 인코딩 실패로 종료합니다.")
    exit()

# 5. 컬럼 미리보기 및 사용자 선택
print("\n📋 시트 컬럼 목록:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")

col_input = input("\n✅ 저장할 컬럼 번호를 쉼표로 입력 (예: 1,3,5): ")
selected_indices = [int(i.strip()) - 1 for i in col_input.split(",") if i.strip().isdigit()]
selected_columns = [df.columns[i] for i in selected_indices if i < len(df.columns)]

if not selected_columns:
    print("⚠️ 선택한 컬럼이 없습니다. 종료합니다.")
    os.remove(tmp_path)
    exit()

# 6. 필터에 필요한 컬럼 체크
required_cols = ["관리본부명", "서비스(대)"]
for col in required_cols:
    if col not in df.columns:
        print(f"⚠️ 필터 조건에 필요한 컬럼 '{col}' 이 존재하지 않습니다.")
        os.remove(tmp_path)
        exit()

# 7. 조건 필터 적용
# df["KTT월정료(조정)"] = pd.to_numeric(df["월정료조정"], errors="coerce")

filtered_df = df[
#    (df["요금구분"] == "대상") &
#    (df["채널구분"] == "SP") &
#   (df["월정료조정"] >= 100000) &
#   (df["관리본부명"].isin(["강북/강원본부", "강원본부"])) &
    (df["서비스(대)"] == "기본서비스")
]

# 8. 선택한 컬럼만 저장
if not filtered_df.empty:
    filtered_df[selected_columns].to_csv(final_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 조건 적용 + 선택 컬럼만 CSV 저장 완료:\n{final_csv_path}")
else:
    print("\n⚠️ 조건을 만족하는 데이터가 없습니다. 파일 저장 생략됨.")

# 9. 임시 파일 삭제
os.remove(tmp_path)


## 2,4,5,7,9,10,11,12,14,15,16,19,25,166,41,42,52,100,132,133,154,121,143,169,157,160,,168
# Out:
# ▶️ 선택된 시트: 3월
# ✅ 임시 CSV 저장 완료: D:\시설\유지\2025\3월\_temp_3월마감.csv
# ❌ 인코딩 실패: utf-8-sig
# C:\Users\User\AppData\Local\Temp\ipykernel_19260\3488979981.py:38: DtypeWarning: Columns (17,23,33,49,50,55,63,67,70,83,96,97,98,109,112,119,121,152,155,163,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tmp_path, encoding=enc)
# ✅ 인코딩 성공: cp949
#
# 📋 시트 컬럼 목록:
# 1. 관리본부코드
# 2. 관리본부명
# 3. 관리지사코드
# 4. 관리지사명
# 5. 고객번호
# 6. 고객명
# 7. 계약번호
# 8. 계약자명
# 9. 서비스번호
# 10. 서비스(대)
# 11. 서비스(중)
# 12. 서비스(소)
# 13. 영상전환일
# 14. 상호
# 15. 고객구분
# 16. 사업용구분
# 17. 주민등록번호
# 18. 사업자번호
# 19. 계약상태(대)
# 20. 계약상태(중)
# 21. 서비스상태(대)
# 22. 서비스상태(중)
# 23. 접속전화번호
# 24. 설치우편번호
# 25. 설치주소
# 26. 견적월정료
# 27. 월정료
# 28. 할인율
# 29. 계약개월수
# 30. 월정료면제사유
# 31. 면제시작일
# 32. 면제종료일
# 33. 계약보증금
# 34. 보증금면제사유
# 35. 판매상품비
# 36. 견적설치공사비
# 37. 설치공사할부개월
# 38. 계약공사비
# 39. 면제공사비
# 40. 실징수액
# 41. 계약시작일
# 42. 계약종료일
# 43. 영업구분
# 44. 추천구분
# 45. 추천경로
# 46. 영업본부코드
# 47. 영업본부명
# 48. 영업지사코드
# 49. 영업지사명
# ...
