# %%
from google.colab import drive
drive.mount('/content/drive')\
# Out:
#   File "<ipython-input-1-06034a04053c>", line 2
#     drive.mount('/content/drive')\
#                                   ^
# SyntaxError: incomplete input

# %%
import os
from datetime import datetime
import zipfile

# 외장 하드에 있는 폴더 경로
external_hard_drive_folder = '/content/Extreme SSD/phb_baeck'  # 수정 필요

# 구글 드라이브 내의 백업 폴더 경로
backup_folder = '/content/drive/MyDrive/개인/외장하드_backup_folder'

# 백업 폴더가 없으면 생성
if not os.path.exists(backup_folder):
    os.makedirs(backup_folder)

# 압축 파일 이름을 현재 날짜를 포함하여 생성
zip_filename = os.path.join(backup_folder, f'backup_{datetime.now().strftime("%Y%m%d_%H%M%S")}.zip')

# %%
# 폴더를 zip 파일로 압축
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for root, dirs, files in os.walk(external_hard_drive_folder):
        for file in files:
            zipf.write(os.path.join(root, file),
                       os.path.relpath(os.path.join(root, file),
                                       os.path.join(external_hard_drive_folder, '..')))

print(f'폴더가 압축되어 {zip_filename}에 저장되었습니다.')

# %%
from google.colab import drive
import os
from datetime import datetime
import zipfile

# 구글 드라이브를 마운트
drive.mount('/content/drive')

# 외장 하드에 있는 폴더 경로
external_hard_drive_folder = '/content/external_hard_drive_folder'  # 수정 필요

# 구글 드라이브 내의 백업 폴더 경로
backup_folder = '/content/drive/MyDrive/backup_folder'

# 백업 폴더가 없으면 생성
if not os.path.exists(backup_folder):
    os.makedirs(backup_folder)

# 압축 파일 이름을 현재 날짜를 포함하여 생성
zip_filename = os.path.join(backup_folder, f'backup_{datetime.now().strftime("%Y%m%d_%H%M%S")}.zip')

# 폴더를 zip 파일로 압축
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for root, dirs, files in os.walk(external_hard_drive_folder):
        for file in files:
            zipf.write(os.path.join(root, file),
                       os.path.relpath(os.path.join(root, file),
                                       os.path.join(external_hard_drive_folder, '..')))

print(f'폴더가 압축되어 {zip_filename}에 저장되었습니다.')
