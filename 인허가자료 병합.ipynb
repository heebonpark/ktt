# %%
pip install pandas pyodbc

# %%
pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# Collecting pandas
#   Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.1

# %%
pip install --upgrade pandas

# %%
pip uninstall pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install --upgrade pandas

# %%
pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: pip in c:\users\user\anaconda3\lib\site-packages (23.3.1)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 1.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.1 MB 2.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.1 MB 2.0 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.1 MB 2.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.1 MB 2.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 2.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 2.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.1 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 2.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.1 MB 2.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-24.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip --version
# Out:
# pip 24.0 from C:\Users\User\anaconda3\Lib\site-packages\pip (python 3.11)Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Note: you may need to restart the kernel to use updated packages.Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: pip in c:\users\user\anaconda3\lib\site-packages (24.0)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
# 가상환경 생성
python -m venv myenv
# Out:
#   Cell In[13], line 2
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
# 윈도우에서 가상 환경  활성화
myenv\Scripts\activate
# Out:
#   Cell In[14], line 2
#     myenv\Scripts\activate
#           ^
# SyntaxError: unexpected character after line continuation character

# %%
# 가상환경에서 판다스 설치
pip install pandas

# %%
pip install --no-binary :all: pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Collecting pandas
#   Downloading pandas-2.2.1.tar.gz (4.4 MB)
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      - -------------------------------------- 0.2/4.4 MB 5.1 MB/s eta 0:00:01
#      --- ------------------------------------ 0.3/4.4 MB 4.1 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.6/4.4 MB 4.5 MB/s eta 0:00:01
#      ------ --------------------------------- 0.7/4.4 MB 4.6 MB/s eta 0:00:01
#      -------- ------------------------------- 1.0/4.4 MB 4.3 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.2/4.4 MB 4.5 MB/s eta 0:00:01
#      ------------- -------------------------- 1.4/4.4 MB 4.3 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.8/4.4 MB 4.5 MB/s eta 0:00:01
#      ------------------ --------------------- 2.1/4.4 MB 4.4 MB/s eta 0:00:01
#      --------------------- ------------------ 2.4/4.4 MB 4.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.6/4.4 MB 4.4 MB/s eta 0:00:01
#      -------------------------- ------------- 2.9/4.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.1/4.4 MB 4.5 MB/s eta 0:00:01
#      ------------------------------ --------- 3.3/4.4 MB 4.5 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.7/4.4 MB 4.4 MB/s eta 0:00:01
#      ------------------------------------ --- 4.0/4.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  4.3/4.4 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------  4.4/4.4 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------- 4.4/4.4 MB 4.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [104 lines of output]
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   Looking in indexes: https://pypi.org/simple/
#   Collecting meson-python==0.13.1
#     Downloading meson_python-0.13.1.tar.gz (68 kB)
#        ---------------------------------------- 0.0/68.5 kB ? eta -:--:--
#        ----------------------------------- ---- 61.4/68.5 kB 3.2 MB/s eta 0:00:01
#        ---------------------------------------- 68.5/68.5 kB 1.2 MB/s eta 0:00:00
#     Installing build dependencies: started
#     Installing build dependencies: still running...
#     Installing build dependencies: still running...
#     Installing build dependencies: still running...
#     Installing build dependencies: still running...
#     Installing build dependencies: still running...
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Installing backend dependencies: started
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: still running...
#     Installing backend dependencies: finished with status 'error'
#     error: subprocess-exited-with-error
#
#     pip subprocess to install backend dependencies did not run successfully.
#     exit code: 1
#
#     [55 lines of output]
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     Looking in indexes: https://pypi.org/simple/
#     Collecting ninja>=1.8.2
#       Downloading ninja-1.11.1.1.tar.gz (132 kB)
#          ---------------------------------------- 0.0/132.4 kB ? eta -:--:--
#          -------------------------------------- 132.4/132.4 kB 2.6 MB/s eta 0:00:00
#       Installing build dependencies: started
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: still running...
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#       Preparing metadata (pyproject.toml): started
#       Preparing metadata (pyproject.toml): finished with status 'done'
#     Building wheels for collected packages: ninja
#       Building wheel for ninja (pyproject.toml): started
#       Building wheel for ninja (pyproject.toml): finished with status 'error'
#       error: subprocess-exited-with-error
#
#       Building wheel for ninja (pyproject.toml) did not run successfully.
#       exit code: 1
#
#       [15 lines of output]
#       C:\Users\User\AppData\Local\Temp\pip-build-env-utwb1qjv\overlay\Lib\site-packages\setuptools_scm\git.py:308: UserWarning: git archive did not support describe output
#         warnings.warn("git archive did not support describe output")
#       C:\Users\User\AppData\Local\Temp\pip-build-env-utwb1qjv\overlay\Lib\site-packages\setuptools_scm\git.py:327: UserWarning: unprocessed git archival found (no export subst applied)
#         warnings.warn("unprocessed git archival found (no export subst applied)")
#       Traceback (most recent call last):
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-utwb1qjv\overlay\Lib\site-packages\skbuild\setuptools_wrap.py", line 645, in setup
#           cmkr = cmaker.CMaker(cmake_executable)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-utwb1qjv\overlay\Lib\site-packages\skbuild\cmaker.py", line 148, in __init__
#           self.cmake_version = get_cmake_version(self.cmake_executable)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-utwb1qjv\overlay\Lib\site-packages\skbuild\cmaker.py", line 105, in get_cmake_version
#           raise SKBuildError(msg) from err
#
#       Problem with the CMake installation, aborting build. CMake executable is cmake
#       [end of output]
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       ERROR: Failed building wheel for ninja
#     Failed to build ninja
#     ERROR: Could not build wheels for ninja, which is required to install pyproject.toml-based projects
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install backend dependencies did not run successfully.
#   exit code: 1
#
#   See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip uninstall pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Collecting pandas
#   Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.1
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
python -m venv myenv
myenv\Scripts\activate # Windows
source myenv/bin/activate # macOS/Linux
pip install pandas
# Out:
#   Cell In[6], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip uninstall pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install --no-binary :all: pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [75 lines of output]
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   Looking in indexes: https://pypi.org/simple/
#   Collecting meson-python==0.13.1
#     Using cached meson_python-0.13.1.tar.gz (68 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Installing backend dependencies: started
#     Installing backend dependencies: still running...
#     Installing backend dependencies: finished with status 'error'
#     error: subprocess-exited-with-error
#
#     pip subprocess to install backend dependencies did not run successfully.
#     exit code: 1
#
#     [44 lines of output]
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     Looking in indexes: https://pypi.org/simple/
#     Collecting ninja>=1.8.2
#       Using cached ninja-1.11.1.1.tar.gz (132 kB)
#       Installing build dependencies: started
#       Installing build dependencies: still running...
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#       Preparing metadata (pyproject.toml): started
#       Preparing metadata (pyproject.toml): finished with status 'done'
#     Building wheels for collected packages: ninja
#       Building wheel for ninja (pyproject.toml): started
#       Building wheel for ninja (pyproject.toml): finished with status 'error'
#       error: subprocess-exited-with-error
#
#       Building wheel for ninja (pyproject.toml) did not run successfully.
#       exit code: 1
#
#       [15 lines of output]
#       C:\Users\User\AppData\Local\Temp\pip-build-env-jc9ov4j7\overlay\Lib\site-packages\setuptools_scm\git.py:308: UserWarning: git archive did not support describe output
#         warnings.warn("git archive did not support describe output")
#       C:\Users\User\AppData\Local\Temp\pip-build-env-jc9ov4j7\overlay\Lib\site-packages\setuptools_scm\git.py:327: UserWarning: unprocessed git archival found (no export subst applied)
#         warnings.warn("unprocessed git archival found (no export subst applied)")
#       Traceback (most recent call last):
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-jc9ov4j7\overlay\Lib\site-packages\skbuild\setuptools_wrap.py", line 645, in setup
#           cmkr = cmaker.CMaker(cmake_executable)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-jc9ov4j7\overlay\Lib\site-packages\skbuild\cmaker.py", line 148, in __init__
#           self.cmake_version = get_cmake_version(self.cmake_executable)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\User\AppData\Local\Temp\pip-build-env-jc9ov4j7\overlay\Lib\site-packages\skbuild\cmaker.py", line 105, in get_cmake_version
#           raise SKBuildError(msg) from err
#
#       Problem with the CMake installation, aborting build. CMake executable is cmake
#       [end of output]
#
#       note: This error originates from a subprocess, and is likely not a problem with pip.
#       ERROR: Failed building wheel for ninja
#     Failed to build ninja
#     ERROR: Could not build wheels for ninja, which is required to install pyproject.toml-based projects
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install backend dependencies did not run successfully.
#   exit code: 1
#
#   See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# Collecting pandas
#   Downloading pandas-2.2.2.tar.gz (4.4 MB)
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      --- ------------------------------------ 0.4/4.4 MB 5.6 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.6/4.4 MB 5.4 MB/s eta 0:00:01
#      ------- -------------------------------- 0.9/4.4 MB 4.9 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.1/4.4 MB 5.0 MB/s eta 0:00:01
#      ------------ --------------------------- 1.4/4.4 MB 4.8 MB/s eta 0:00:01
#      -------------- ------------------------- 1.6/4.4 MB 4.6 MB/s eta 0:00:01
#      --------------- ------------------------ 1.7/4.4 MB 4.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 2.0/4.4 MB 4.7 MB/s eta 0:00:01
#      -------------------- ------------------- 2.2/4.4 MB 4.7 MB/s eta 0:00:01
#      --------------------- ------------------ 2.4/4.4 MB 4.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.6/4.4 MB 4.7 MB/s eta 0:00:01
#      ------------------------- -------------- 2.8/4.4 MB 4.6 MB/s eta 0:00:01
#      --------------------------- ------------ 3.1/4.4 MB 4.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.3/4.4 MB 4.6 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.4 MB 4.6 MB/s eta 0:00:01
#      --------------------------------- ------ 3.7/4.4 MB 4.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.9/4.4 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------- -- 4.1/4.4 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  4.4/4.4 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  4.4/4.4 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------- 4.4/4.4 MB 4.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0

# %%
conda update pandas
# Out:
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\home\qi\directive\expect.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\home\support\char_encoding\unicode\lowercase_table.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\home\support\detail\lexer\containers\ptr_vector.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\home\x3\char\unicode.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\home\x3\support\traits\optional_traits.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\classic_dynamic.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\classic_ref_const_ref_actor.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\karma_binary.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\karma_repeat.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\qi.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\qi_numeric.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\include\support_ascii.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\spirit\repository\include\qi_advance.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\statechart\detail\reaction_dispatcher.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\system\detail\snprintf.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\test\data\index_sequence.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\test\impl\xml_log_formatter.ipp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\test\utils\iterator\token_iterator.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\thread\csbl\memory.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\thread\futures\wait_for_all.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\tti\detail\dlambda.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\type_erasure\is_empty.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\type_traits\conjunction.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\type_traits\is_empty.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\type_traits\make_void.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\units\base_units\angle\steradian.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\units\detail\cmath_impl.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\units\physical_dimensions\resistivity.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\units\systems\cgs\velocity.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\units\systems\si\codata\electron_constants.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\url\detail\over_allocator.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\url\grammar\impl\delim_rule.ipp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\url\rfc\impl\ipv4_address_rule.ipp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\variant\detail\enable_recursive_fwd.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\vmd\detail\data_equal_common.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\vmd\detail\recurse\data_equal\data_equal_1.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\wave\cpplexer\re2clex\aq.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\winapi\handle_info.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\xpressive\detail\core\linker.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\Library\include\boost\xpressive\detail\core\matcher\regex_matcher.hpp.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\America\Indiana\Marengo.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Asia\Choibalsan.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Asia\Manila.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Australia\Adelaide.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Etc\GMT+9.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Europe\Istanbul.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Indian\Kerguelen.c~.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\User\anaconda3\share\zoneinfo\Pacific\Norfolk.c~.  Please remove this file manually (you may need to reboot to free file handles)
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.7.0          |  py311haa95532_0         153 KB
#     aiohttp-3.9.3              |  py311h2bbff1b_0         779 KB
#     anaconda-cloud-auth-0.5.0  |  py311haa95532_0          50 KB
#     annotated-types-0.6.0      |  py311haa95532_0          26 KB
#     anyio-4.2.0                |  py311haa95532_0         238 KB
#     arrow-cpp-14.0.2           |       ha81ea56_1         8.5 MB
#     astropy-5.3.4              |  py311hd7041d2_0         9.7 MB
#     async-lru-2.0.4            |  py311haa95532_0          21 KB
#     attrs-23.1.0               |  py311haa95532_0         165 KB
#     autopep8-2.0.4             |     pyhd3eb1b0_0          44 KB
#     aws-c-auth-0.6.19          |       h2bbff1b_0          95 KB
#     aws-c-cal-0.5.20           |       h2bbff1b_0          41 KB
#     aws-c-common-0.8.5         |       h2bbff1b_0         198 KB
#     aws-c-compression-0.2.16   |       h2bbff1b_0          21 KB
#     aws-c-event-stream-0.2.15  |       hd77b12b_0          50 KB
#     aws-c-http-0.6.25          |       h2bbff1b_0         181 KB
#     aws-c-io-0.13.10           |       h2bbff1b_0         153 KB
#     aws-c-mqtt-0.7.13          |       h2bbff1b_0          65 KB
#     aws-c-s3-0.1.51            |       h2bbff1b_0          68 KB
#     aws-c-sdkutils-0.1.6       |       h2bbff1b_0          48 KB
#     aws-checksums-0.1.13       |       h2bbff1b_0          50 KB
#     aws-crt-cpp-0.18.16        |       hd77b12b_0         194 KB
#     aws-sdk-cpp-1.10.55        |       hd77b12b_0         2.1 MB
#     black-24.3.0               |  py311haa95532_0         402 KB
#     bokeh-3.4.0                |  py311h746a85d_1         5.9 MB
#     boost-cpp-1.82.0           |       h59b6b97_2          11 KB
#     botocore-1.31.64           |  py311haa95532_0         6.9 MB
#     bottleneck-1.3.7           |  py311hd7041d2_0         134 KB
#     brotli-python-1.0.9        |  py311hd77b12b_7         310 KB
#     bzip2-1.0.8                |       h2bbff1b_5          78 KB
#     c-blosc2-2.12.0            |       h2f4ed9d_0         222 KB
#     cffi-1.16.0                |  py311h2bbff1b_0         303 KB
#     click-8.1.7                |  py311haa95532_0         222 KB
#     colorcet-3.1.0             |  py311haa95532_0         614 KB
#     comm-0.2.1                 |  py311haa95532_0          17 KB
#     conda-index-0.4.0          |     pyhd3eb1b0_0         173 KB
#     conda-repo-cli-1.0.88      |  py311haa95532_0         200 KB
#     constantly-23.10.4         |  py311haa95532_0          33 KB
#     contourpy-1.2.0            |  py311h59b6b97_0         218 KB
#     cookiecutter-2.6.0         |  py311haa95532_0         161 KB
#     cryptography-42.0.5        |  py311h89fc84f_0         1.2 MB
#     cssselect-1.2.0            |  py311haa95532_0          49 KB
#     curl-8.5.0                 |       he2ea4bf_0         156 KB
#     cytoolz-0.12.2             |  py311h2bbff1b_0         339 KB
#     dal-2023.1.1               |   h59b6b97_48682        26.5 MB
#     dask-2023.11.0             |  py311haa95532_0           6 KB
#     dask-core-2023.11.0        |  py311haa95532_0         3.0 MB
#     datashader-0.16.0          |  py311haa95532_0        17.1 MB
#     dill-0.3.7                 |  py311haa95532_0         249 KB
#     distributed-2023.11.0      |  py311haa95532_0         1.7 MB
#     filelock-3.13.1            |  py311haa95532_0          24 KB
#     flake8-7.0.0               |  py311haa95532_0         137 KB
#     flask-2.2.5                |  py311haa95532_0         208 KB
#     frozenlist-1.4.0           |  py311h2bbff1b_0          47 KB
#     fsspec-2023.10.0           |  py311haa95532_0         359 KB
#     gflags-2.2.2               |       hd77b12b_1         247 KB
#     glog-0.5.0                 |       hd77b12b_1          93 KB
#     gmpy2-2.1.2                |  py311h7f96b67_0         140 KB
#     greenlet-3.0.1             |  py311hd77b12b_0         222 KB
#     holoviews-1.18.3           |  py311haa95532_0         5.2 MB
#     huggingface_hub-0.20.3     |  py311haa95532_0         515 KB
#     hvplot-0.9.2               |  py311haa95532_0         1.9 MB
#     icu-73.1                   |       h6c2663c_0        29.5 MB
#     imageio-2.33.1             |  py311haa95532_0         645 KB
#     imbalanced-learn-0.11.0    |  py311haa95532_1         383 KB
#     importlib-metadata-7.0.1   |  py311haa95532_0          49 KB
#     importlib_metadata-7.0.1   |       hd3eb1b0_0           8 KB
#     incremental-22.10.0        |     pyhd3eb1b0_0          18 KB
#     intel-openmp-2023.1.0      |   h59b6b97_46320         2.7 MB
#     ipykernel-6.28.0           |  py311haa95532_0         246 KB
#     ipython-8.20.0             |  py311haa95532_0         1.5 MB
#     ipywidgets-8.1.2           |  py311haa95532_0         252 KB
#     itemloaders-1.1.0          |  py311haa95532_0          31 KB
#     jinja2-3.1.3               |  py311haa95532_0         354 KB
#     jmespath-1.0.1             |  py311haa95532_0          51 KB
#     jsonpatch-1.33             |  py311haa95532_0          54 KB
#     jsonschema-4.19.2          |  py311haa95532_0         213 KB
#     jsonschema-specifications-2023.7.1|  py311haa95532_0          16 KB
#     jupyter-1.0.0              |  py311haa95532_9           8 KB
#     jupyter-lsp-2.2.0          |  py311haa95532_0         107 KB
#     jupyter_client-8.6.0       |  py311haa95532_0         252 KB
#     jupyter_core-5.5.0         |  py311haa95532_0         112 KB
#     jupyter_events-0.8.0       |  py311haa95532_0          58 KB
#     jupyter_server-2.10.0      |  py311haa95532_0         596 KB
#     jupyter_server_terminals-0.4.4|  py311haa95532_1          29 KB
#     jupyterlab-4.0.11          |  py311haa95532_0         4.6 MB
#     jupyterlab_server-2.25.1   |  py311haa95532_0         114 KB
#     jupyterlab_widgets-3.0.10  |  py311haa95532_0         196 KB
#     keyring-24.3.1             |  py311haa95532_0         100 KB
#     lazy_loader-0.3            |  py311haa95532_0          21 KB
#     libboost-1.82.0            |       h3399ecb_2        23.1 MB
#     libcurl-8.5.0              |       h86230a5_0         343 KB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     libmamba-1.5.8             |       h99b1521_1         3.9 MB
#     libmambapy-1.5.8           |  py311h77c03ed_1         248 KB
#     libpq-12.17                |       h906ac69_0         3.2 MB
#     llvmlite-0.42.0            |  py311hf2fb9eb_0        18.6 MB
#     markupsafe-2.1.3           |  py311h2bbff1b_0          28 KB
#     matplotlib-3.8.0           |  py311haa95532_0           9 KB
#     matplotlib-base-3.8.0      |  py311hf62ec03_0         7.6 MB
#     mistune-2.0.4              |  py311haa95532_0         108 KB
#     mkl-2023.1.0               |   h6b88ed4_46358       155.9 MB
#     more-itertools-10.1.0      |  py311haa95532_0         107 KB
#     mpc-1.1.0                  |       h7edee0f_1         260 KB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     mpir-3.0.0                 |       hec2e145_1         1.3 MB
#     multidict-6.0.4            |  py311h2bbff1b_0          54 KB
#     nbclient-0.8.0             |  py311haa95532_0         137 KB
#     nbconvert-7.10.0           |  py311haa95532_0         532 KB
#     nest-asyncio-1.6.0         |  py311haa95532_0          17 KB
#     notebook-7.0.8             |  py311haa95532_0         3.4 MB
#     notebook-shim-0.2.3        |  py311haa95532_0          27 KB
#     numba-0.59.1               |  py311hf62ec03_0         5.9 MB
#     numexpr-2.8.7              |  py311h1fcbade_0         160 KB
#     numpy-1.26.4               |  py311hdab7c0b_0          11 KB
#     numpy-base-1.26.4          |  py311hd01c5d8_0         9.1 MB
#     overrides-7.4.0            |  py311haa95532_0          38 KB
#     packaging-23.2             |  py311haa95532_0         173 KB
#     panel-1.4.1                |  py311haa95532_0        18.7 MB
#     param-2.1.0                |  py311haa95532_0         269 KB
#     parsel-1.8.1               |  py311haa95532_0          52 KB
#     partd-1.4.1                |  py311haa95532_0          49 KB
#     plotly-5.19.0              |  py311h746a85d_0         5.8 MB
#     prompt-toolkit-3.0.43      |  py311haa95532_0         746 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     py-cpuinfo-9.0.0           |  py311haa95532_0          87 KB
#     pyarrow-14.0.2             |  py311h847bd2a_0         3.7 MB
#     pycodestyle-2.11.1         |  py311haa95532_0          95 KB
#     pycosat-0.6.6              |  py311h2bbff1b_0          82 KB
#     pydantic-2.5.3             |  py311haa95532_0         720 KB
#     pydantic-core-2.14.6       |  py311h062c2fa_0         1.7 MB
#     pyflakes-3.2.0             |  py311haa95532_0         173 KB
#     pylint-venv-3.0.3          |  py311haa95532_0          13 KB
#     pyodbc-5.0.1               |  py311hd77b12b_0          66 KB
#     pyopenssl-24.0.0           |  py311haa95532_0         125 KB
#     pyqt-5.15.10               |  py311hd77b12b_0         4.1 MB
#     pyqt5-sip-12.13.0          |  py311h2bbff1b_0          75 KB
#     pyqtwebengine-5.15.10      |  py311hd77b12b_0         134 KB
#     pytables-3.9.2             |  py311h91a9f6a_0         1.5 MB
#     python-lsp-black-2.0.0     |  py311haa95532_0          17 KB
#     python-lsp-jsonrpc-1.1.2   |     pyhd3eb1b0_0          12 KB
#     python-lsp-server-1.10.0   |  py311haa95532_0         179 KB
#     pytoolconfig-1.2.6         |  py311haa95532_0          36 KB
#     pyviz_comms-3.0.2          |  py311haa95532_0          57 KB
#     pywavelets-1.5.0           |  py311hd7041d2_0         3.6 MB
#     pywin32-ctypes-0.2.2       |  py311haa95532_0          56 KB
#     pyyaml-6.0.1               |  py311h2bbff1b_0         185 KB
#     pyzmq-25.1.2               |  py311hd77b12b_0         493 KB
#     qdarkstyle-3.2.3           |     pyhd3eb1b0_0         615 KB
#     qt-main-5.15.2             |      h19c9488_10        59.4 MB
#     qtconsole-5.5.1            |  py311haa95532_0         271 KB
#     qtpy-2.4.1                 |  py311haa95532_0         148 KB
#     queuelib-1.6.2             |  py311haa95532_0          36 KB
#     referencing-0.30.2         |  py311haa95532_0          78 KB
#     regex-2023.10.3            |  py311h2bbff1b_0         389 KB
#     requests-2.31.0            |  py311haa95532_1         125 KB
#     rich-13.3.5                |  py311haa95532_0         566 KB
#     rope-1.12.0                |  py311haa95532_0         596 KB
#     rpds-py-0.10.6             |  py311h062c2fa_0         202 KB
#     s3fs-2023.10.0             |  py311haa95532_0          77 KB
#     safetensors-0.4.2          |  py311hcbdf901_0         290 KB
#     scikit-image-0.22.0        |  py311hb4ba03d_0         9.9 MB
#     scikit-learn-1.2.2         |  py311hd77b12b_1         7.6 MB
#     scipy-1.12.0               |  py311h9f229c6_0        26.1 MB
#     scrapy-2.11.1              |  py311haa95532_0         870 KB
#     semver-3.0.2               |  py311haa95532_0         101 KB
#     send2trash-1.8.2           |  py311haa95532_0          81 KB
#     sip-6.7.12                 |  py311hd77b12b_0         615 KB
#     snappy-1.1.10              |       h6c2663c_1          92 KB
#     sniffio-1.3.0              |  py311haa95532_0          18 KB
#     soupsieve-2.5              |  py311haa95532_0          93 KB
#     spyder-5.5.1               |  py311haa95532_0        11.0 MB
#     spyder-kernels-2.5.0       |  py311haa95532_0         204 KB
#     sqlalchemy-2.0.25          |  py311h2bbff1b_0         3.8 MB
#     sympy-1.12                 |  py311haa95532_0        14.4 MB
#     tabulate-0.9.0             |  py311haa95532_0          90 KB
#     tokenizers-0.15.1          |  py311h49fca51_0         1.8 MB
#     tomli-2.0.1                |  py311haa95532_0          31 KB
#     tornado-6.3.3              |  py311h2bbff1b_0         856 KB
#     transformers-4.37.2        |  py311haa95532_0        10.0 MB
#     twisted-23.10.0            |  py311haa95532_0         6.8 MB
#     typing-extensions-4.9.0    |  py311haa95532_1          10 KB
#     typing_extensions-4.9.0    |  py311haa95532_1          70 KB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     urllib3-2.0.7              |  py311haa95532_0         233 KB
#     utf8proc-2.6.1             |       h2bbff1b_1          96 KB
#     w3lib-2.1.2                |  py311haa95532_0          44 KB
#     widgetsnbextension-4.0.10  |  py311haa95532_0         949 KB
#     xz-5.4.6                   |       h8cc25b3_0         587 KB
#     yaml-cpp-0.8.0             |       hd77b12b_0         2.0 MB
#     yapf-0.40.2                |  py311haa95532_0         492 KB
#     yarl-1.9.3                 |  py311h2bbff1b_0         118 KB
#     zeromq-4.3.5               |       hd77b12b_0         5.2 MB
#     zict-3.0.0                 |  py311haa95532_0         119 KB
#     zipp-3.17.0                |  py311haa95532_0          25 KB
#     ------------------------------------------------------------
#                                            Total:       585.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   annotated-types    pkgs/main/win-64::annotated-types-0.6.0-py311haa95532_0
#   async-lru          pkgs/main/win-64::async-lru-2.0.4-py311haa95532_0
#   aws-c-auth         pkgs/main/win-64::aws-c-auth-0.6.19-h2bbff1b_0
#   aws-c-cal          pkgs/main/win-64::aws-c-cal-0.5.20-h2bbff1b_0
#   aws-c-compression  pkgs/main/win-64::aws-c-compression-0.2.16-h2bbff1b_0
#   aws-c-http         pkgs/main/win-64::aws-c-http-0.6.25-h2bbff1b_0
#   aws-c-io           pkgs/main/win-64::aws-c-io-0.13.10-h2bbff1b_0
#   aws-c-mqtt         pkgs/main/win-64::aws-c-mqtt-0.7.13-h2bbff1b_0
#   aws-c-s3           pkgs/main/win-64::aws-c-s3-0.1.51-h2bbff1b_0
#   aws-c-sdkutils     pkgs/main/win-64::aws-c-sdkutils-0.1.6-h2bbff1b_0
#   aws-crt-cpp        pkgs/main/win-64::aws-crt-cpp-0.18.16-hd77b12b_0
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311hd77b12b_7
#   gmpy2              pkgs/main/win-64::gmpy2-2.1.2-py311h7f96b67_0
#   jsonschema-specif~ pkgs/main/win-64::jsonschema-specifications-2023.7.1-py311haa95532_0
#   jupyter-lsp        pkgs/main/win-64::jupyter-lsp-2.2.0-py311haa95532_0
#   jupyter_server_te~ pkgs/main/win-64::jupyter_server_terminals-0.4.4-py311haa95532_1
#   mpc                pkgs/main/win-64::mpc-1.1.0-h7edee0f_1
#   mpfr               pkgs/main/win-64::mpfr-4.0.2-h62dcd97_1
#   mpir               pkgs/main/win-64::mpir-3.0.0-hec2e145_1
#   overrides          pkgs/main/win-64::overrides-7.4.0-py311haa95532_0
#   pydantic-core      pkgs/main/win-64::pydantic-core-2.14.6-py311h062c2fa_0
#   referencing        pkgs/main/win-64::referencing-0.30.2-py311haa95532_0
#   rich               pkgs/main/win-64::rich-13.3.5-py311haa95532_0
#   rpds-py            pkgs/main/win-64::rpds-py-0.10.6-py311h062c2fa_0
#   semver             pkgs/main/win-64::semver-3.0.2-py311haa95532_0
#   tomli              pkgs/main/win-64::tomli-2.0.1-py311haa95532_0
#
# The following packages will be REMOVED:
#
#   aiofiles-22.1.0-py311haa95532_0
#   aiosqlite-0.18.0-py311haa95532_0
#   async-timeout-4.0.2-py311haa95532_0
#   backcall-0.2.0-pyhd3eb1b0_0
#   brotlipy-0.7.0-py311h2bbff1b_1002
#   datasets-2.12.0-py311haa95532_0
#   datashape-0.5.4-py311haa95532_1
#   glib-2.69.1-h5dc1a3c_2
#   ipython_genutils-0.2.0-pyhd3eb1b0_1
#   jinja2-time-0.2.0-pyhd3eb1b0_3
#   jupyter_server_fileid-0.9.0-py311haa95532_0
#   jupyter_server_ydoc-0.8.0-py311haa95532_1
#   jupyter_ydoc-0.2.4-py311haa95532_0
#   libwebp-1.3.2-hbc33d0d_0
#   multiprocess-0.70.14-py311haa95532_0
#   nbclassic-0.5.5-py311haa95532_0
#   pathlib-1.0.1-pyhd3eb1b0_1
#   pcre-8.45-hd77b12b_0
#   poyo-0.5.0-pyhd3eb1b0_0
#   pyrsistent-0.18.0-py311h2bbff1b_0
#   python-xxhash-2.0.2-py311h2bbff1b_1
#   qtwebkit-5.212-h2bbfb41_5
#   responses-0.13.3-pyhd3eb1b0_0
#   toml-0.10.2-pyhd3eb1b0_0
#   xxhash-0.8.0-h2bbff1b_3
#   y-py-0.5.9-py311hb6bf4ef_0
#   ypy-websocket-0.8.2-py311haa95532_0
#
# The following packages will be UPDATED:
#
#   aiobotocore                         2.5.0-py311haa95532_0 --> 2.7.0-py311haa95532_0
#   aiohttp                             3.8.5-py311h2bbff1b_0 --> 3.9.3-py311h2bbff1b_0
#   anaconda-cloud-au~                  0.1.3-py311haa95532_0 --> 0.5.0-py311haa95532_0
#   anyio                               3.5.0-py311haa95532_0 --> 4.2.0-py311haa95532_0
#   arrow-cpp                               11.0.0-ha81ea56_2 --> 14.0.2-ha81ea56_1
#   astropy                               5.1-py311h5bb9823_0 --> 5.3.4-py311hd7041d2_0
#   attrs                              22.1.0-py311haa95532_0 --> 23.1.0-py311haa95532_0
#   autopep8                               1.6.0-pyhd3eb1b0_1 --> 2.0.4-pyhd3eb1b0_0
#   aws-c-common                             0.6.8-h2bbff1b_1 --> 0.8.5-h2bbff1b_0
#   aws-c-event-stream                       0.1.6-hd77b12b_6 --> 0.2.15-hd77b12b_0
#   aws-checksums                           0.1.11-h2bbff1b_2 --> 0.1.13-h2bbff1b_0
#   aws-sdk-cpp                            1.8.185-hd77b12b_1 --> 1.10.55-hd77b12b_0
#   black                              23.3.0-py311haa95532_0 --> 24.3.0-py311haa95532_0
#   bokeh                               3.2.1-py311h746a85d_0 --> 3.4.0-py311h746a85d_1
#   boost-cpp                               1.82.0-h59b6b97_1 --> 1.82.0-h59b6b97_2
#   botocore                          1.29.76-py311haa95532_0 --> 1.31.64-py311haa95532_0
#   bottleneck                          1.3.5-py311h5bb9823_0 --> 1.3.7-py311hd7041d2_0
#   bzip2                                    1.0.8-he774522_0 --> 1.0.8-h2bbff1b_5
#   c-blosc2                                 2.8.0-hd77b12b_0 --> 2.12.0-h2f4ed9d_0
#   cffi                               1.15.1-py311h2bbff1b_3 --> 1.16.0-py311h2bbff1b_0
#   click                               8.0.4-py311haa95532_0 --> 8.1.7-py311haa95532_0
#   colorcet                            3.0.1-py311haa95532_0 --> 3.1.0-py311haa95532_0
#   comm                                0.1.2-py311haa95532_0 --> 0.2.1-py311haa95532_0
#   conda-index        pkgs/main/win-64::conda-index-0.3.0-p~ --> pkgs/main/noarch::conda-index-0.4.0-pyhd3eb1b0_0
#   conda-repo-cli                     1.0.75-py311haa95532_0 --> 1.0.88-py311haa95532_0
#   constantly                         15.1.0-py311haa95532_0 --> 23.10.4-py311haa95532_0
#   contourpy                           1.0.5-py311h59b6b97_0 --> 1.2.0-py311h59b6b97_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.3-~ --> pkgs/main/win-64::cookiecutter-2.6.0-py311haa95532_0
#   cryptography                       41.0.3-py311h89fc84f_0 --> 42.0.5-py311h89fc84f_0
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyh~ --> pkgs/main/win-64::cssselect-1.2.0-py311haa95532_0
#   curl                                     8.1.1-h2bbff1b_0 --> 8.5.0-he2ea4bf_0
#   cytoolz                            0.12.0-py311h2bbff1b_0 --> 0.12.2-py311h2bbff1b_0
#   dal                               2023.1.1-h59b6b97_48681 --> 2023.1.1-h59b6b97_48682
#   dask                             2023.6.0-py311haa95532_0 --> 2023.11.0-py311haa95532_0
#   dask-core                        2023.6.0-py311haa95532_0 --> 2023.11.0-py311haa95532_0
#   datashader                         0.15.2-py311haa95532_0 --> 0.16.0-py311haa95532_0
#   dill                                0.3.6-py311haa95532_0 --> 0.3.7-py311haa95532_0
#   distributed                      2023.6.0-py311haa95532_0 --> 2023.11.0-py311haa95532_0
#   filelock                            3.9.0-py311haa95532_0 --> 3.13.1-py311haa95532_0
#   flake8                              6.0.0-py311haa95532_0 --> 7.0.0-py311haa95532_0
#   flask                               2.2.2-py311haa95532_0 --> 2.2.5-py311haa95532_0
#   frozenlist                          1.3.3-py311h2bbff1b_0 --> 1.4.0-py311h2bbff1b_0
#   fsspec                           2023.4.0-py311haa95532_0 --> 2023.10.0-py311haa95532_0
#   gflags                                   2.2.2-ha925a31_0 --> 2.2.2-hd77b12b_1
#   glog                                     0.5.0-hd77b12b_0 --> 0.5.0-hd77b12b_1
#   greenlet                            2.0.1-py311hd77b12b_0 --> 3.0.1-py311hd77b12b_0
#   holoviews                          1.17.1-py311haa95532_0 --> 1.18.3-py311haa95532_0
#   huggingface_hub                    0.15.1-py311haa95532_0 --> 0.20.3-py311haa95532_0
#   hvplot                              0.8.4-py311haa95532_0 --> 0.9.2-py311haa95532_0
#   icu                                       58.2-ha925a31_3 --> 73.1-h6c2663c_0
#   imageio                            2.26.0-py311haa95532_0 --> 2.33.1-py311haa95532_0
#   imbalanced-learn                   0.10.1-py311haa95532_1 --> 0.11.0-py311haa95532_1
#   importlib-metadata                  6.0.0-py311haa95532_0 --> 7.0.1-py311haa95532_0
#   importlib_metadata                       6.0.0-hd3eb1b0_0 --> 7.0.1-hd3eb1b0_0
#   incremental                           21.3.0-pyhd3eb1b0_0 --> 22.10.0-pyhd3eb1b0_0
#   intel-openmp                      2023.1.0-h59b6b97_46319 --> 2023.1.0-h59b6b97_46320
#   ipykernel                          6.25.0-py311h746a85d_0 --> 6.28.0-py311haa95532_0
#   ipython                            8.15.0-py311haa95532_0 --> 8.20.0-py311haa95532_0
#   ipywidgets                          8.0.4-py311haa95532_0 --> 8.1.2-py311haa95532_0
#   itemloaders        pkgs/main/noarch::itemloaders-1.0.4-p~ --> pkgs/main/win-64::itemloaders-1.1.0-py311haa95532_0
#   jinja2                              3.1.2-py311haa95532_0 --> 3.1.3-py311haa95532_0
#   jmespath           pkgs/main/noarch::jmespath-0.10.0-pyh~ --> pkgs/main/win-64::jmespath-1.0.1-py311haa95532_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/win-64::jsonpatch-1.33-py311haa95532_0
#   jsonschema                         4.17.3-py311haa95532_0 --> 4.19.2-py311haa95532_0
#   jupyter                             1.0.0-py311haa95532_8 --> 1.0.0-py311haa95532_9
#   jupyter_client                      7.4.9-py311haa95532_0 --> 8.6.0-py311haa95532_0
#   jupyter_core                        5.3.0-py311haa95532_0 --> 5.5.0-py311haa95532_0
#   jupyter_events                      0.6.3-py311haa95532_0 --> 0.8.0-py311haa95532_0
#   jupyter_server                     1.23.4-py311haa95532_0 --> 2.10.0-py311haa95532_0
#   jupyterlab                          3.6.3-py311haa95532_0 --> 4.0.11-py311haa95532_0
#   jupyterlab_server                  2.22.0-py311haa95532_0 --> 2.25.1-py311haa95532_0
#   jupyterlab_widgets                  3.0.5-py311haa95532_0 --> 3.0.10-py311haa95532_0
#   keyring                           23.13.1-py311haa95532_0 --> 24.3.1-py311haa95532_0
#   lazy_loader                           0.2-py311haa95532_0 --> 0.3-py311haa95532_0
#   libboost                                1.82.0-hae598e9_1 --> 1.82.0-h3399ecb_2
#   libcurl                                  8.1.1-h86230a5_0 --> 8.5.0-h86230a5_0
#   libdeflate                                1.17-h2bbff1b_0 --> 1.17-h2bbff1b_1
#   libmamba                                 1.5.1-hcd6fe79_0 --> 1.5.8-h99b1521_1
#   libmambapy                          1.5.1-py311h77c03ed_0 --> 1.5.8-py311h77c03ed_1
#   libpq                                    12.15-h906ac69_1 --> 12.17-h906ac69_0
#   llvmlite                           0.40.0-py311hf2fb9eb_0 --> 0.42.0-py311hf2fb9eb_0
#   markupsafe                          2.1.1-py311h2bbff1b_0 --> 2.1.3-py311h2bbff1b_0
#   matplotlib                          3.7.2-py311haa95532_0 --> 3.8.0-py311haa95532_0
#   matplotlib-base                     3.7.2-py311hf62ec03_0 --> 3.8.0-py311hf62ec03_0
#   mistune                          0.8.4-py311h2bbff1b_1000 --> 2.0.4-py311haa95532_0
#   mkl                               2023.1.0-h6b88ed4_46357 --> 2023.1.0-h6b88ed4_46358
#   more-itertools     pkgs/main/noarch::more-itertools-8.12~ --> pkgs/main/win-64::more-itertools-10.1.0-py311haa95532_0
#   multidict                           6.0.2-py311h2bbff1b_0 --> 6.0.4-py311h2bbff1b_0
#   nbclient                           0.5.13-py311haa95532_0 --> 0.8.0-py311haa95532_0
#   nbconvert                           6.5.4-py311haa95532_0 --> 7.10.0-py311haa95532_0
#   nest-asyncio                        1.5.6-py311haa95532_0 --> 1.6.0-py311haa95532_0
#   notebook                            6.5.4-py311haa95532_1 --> 7.0.8-py311haa95532_0
#   notebook-shim                       0.2.2-py311haa95532_0 --> 0.2.3-py311haa95532_0
#   numba                              0.57.1-py311hf62ec03_0 --> 0.59.1-py311hf62ec03_0
#   numexpr                             2.8.4-py311h1fcbade_1 --> 2.8.7-py311h1fcbade_0
#   numpy                              1.24.3-py311hdab7c0b_1 --> 1.26.4-py311hdab7c0b_0
#   numpy-base                         1.24.3-py311hd01c5d8_1 --> 1.26.4-py311hd01c5d8_0
#   packaging                            23.1-py311haa95532_0 --> 23.2-py311haa95532_0
#   panel                               1.2.3-py311haa95532_0 --> 1.4.1-py311haa95532_0
#   param                              1.13.0-py311haa95532_0 --> 2.1.0-py311haa95532_0
#   parsel                              1.6.0-py311haa95532_0 --> 1.8.1-py311haa95532_0
#   partd                               1.4.0-py311haa95532_0 --> 1.4.1-py311haa95532_0
#   plotly                              5.9.0-py311haa95532_0 --> 5.19.0-py311h746a85d_0
#   prompt-toolkit                     3.0.36-py311haa95532_0 --> 3.0.43-py311haa95532_0
#   prompt_toolkit                          3.0.36-hd3eb1b0_0 --> 3.0.43-hd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-py~ --> pkgs/main/win-64::py-cpuinfo-9.0.0-py311haa95532_0
#   pyarrow                            11.0.0-py311h8a3a540_1 --> 14.0.2-py311h847bd2a_0
#   pycodestyle                        2.10.0-py311haa95532_0 --> 2.11.1-py311haa95532_0
#   pycosat                             0.6.4-py311h2bbff1b_0 --> 0.6.6-py311h2bbff1b_0
#   pydantic                          1.10.12-py311h2bbff1b_1 --> 2.5.3-py311haa95532_0
#   pyflakes                            3.0.1-py311haa95532_0 --> 3.2.0-py311haa95532_0
#   pylint-venv                         2.3.0-py311haa95532_0 --> 3.0.3-py311haa95532_0
#   pyodbc                             4.0.34-py311hd77b12b_0 --> 5.0.1-py311hd77b12b_0
#   pyopenssl                          23.2.0-py311haa95532_0 --> 24.0.0-py311haa95532_0
#   pyqt                               5.15.7-py311hd77b12b_0 --> 5.15.10-py311hd77b12b_0
#   pyqt5-sip                         12.11.0-py311hd77b12b_0 --> 12.13.0-py311h2bbff1b_0
#   pyqtwebengine                      5.15.7-py311hd77b12b_0 --> 5.15.10-py311hd77b12b_0
#   pytables                            3.8.0-py311h4671533_3 --> 3.9.2-py311h91a9f6a_0
#   python-lsp-black                    1.2.1-py311haa95532_0 --> 2.0.0-py311haa95532_0
#   python-lsp-jsonrpc                     1.0.0-pyhd3eb1b0_0 --> 1.1.2-pyhd3eb1b0_0
#   python-lsp-server                   1.7.2-py311haa95532_0 --> 1.10.0-py311haa95532_0
#   pytoolconfig                        1.2.5-py311haa95532_1 --> 1.2.6-py311haa95532_0
#   pyviz_comms                         2.3.0-py311haa95532_0 --> 3.0.2-py311haa95532_0
#   pywavelets                          1.4.1-py311h2bbff1b_0 --> 1.5.0-py311hd7041d2_0
#   pywin32-ctypes                   0.2.0-py311haa95532_1000 --> 0.2.2-py311haa95532_0
#   pyyaml                                6.0-py311h2bbff1b_1 --> 6.0.1-py311h2bbff1b_0
#   pyzmq                              23.2.0-py311hd77b12b_0 --> 25.1.2-py311hd77b12b_0
#   qdarkstyle                             3.0.2-pyhd3eb1b0_0 --> 3.2.3-pyhd3eb1b0_0
#   qt-main                                 5.15.2-h879a1e9_9 --> 5.15.2-h19c9488_10
#   qtconsole                           5.4.2-py311haa95532_0 --> 5.5.1-py311haa95532_0
#   qtpy                                2.2.0-py311haa95532_0 --> 2.4.1-py311haa95532_0
#   queuelib                            1.5.0-py311haa95532_0 --> 1.6.2-py311haa95532_0
#   regex                            2022.7.9-py311h2bbff1b_0 --> 2023.10.3-py311h2bbff1b_0
#   requests                           2.31.0-py311haa95532_0 --> 2.31.0-py311haa95532_1
#   rope                                1.7.0-py311haa95532_0 --> 1.12.0-py311haa95532_0
#   s3fs                             2023.4.0-py311haa95532_0 --> 2023.10.0-py311haa95532_0
#   safetensors                         0.3.2-py311h062c2fa_0 --> 0.4.2-py311hcbdf901_0
#   scikit-image                       0.20.0-py311h3513d60_0 --> 0.22.0-py311hb4ba03d_0
#   scipy                              1.11.1-py311hc1ccb85_0 --> 1.12.0-py311h9f229c6_0
#   scrapy                              2.8.0-py311haa95532_0 --> 2.11.1-py311haa95532_0
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-py~ --> pkgs/main/win-64::send2trash-1.8.2-py311haa95532_0
#   sip                                 6.6.2-py311hd77b12b_0 --> 6.7.12-py311hd77b12b_0
#   snappy                                   1.1.9-h6c2663c_0 --> 1.1.10-h6c2663c_1
#   sniffio                             1.2.0-py311haa95532_1 --> 1.3.0-py311haa95532_0
#   soupsieve                             2.4-py311haa95532_0 --> 2.5-py311haa95532_0
#   spyder                              5.4.3-py311haa95532_1 --> 5.5.1-py311haa95532_0
#   spyder-kernels                      2.4.4-py311haa95532_0 --> 2.5.0-py311haa95532_0
#   sqlalchemy                         1.4.39-py311h2bbff1b_0 --> 2.0.25-py311h2bbff1b_0
#   sympy                              1.11.1-py311haa95532_0 --> 1.12-py311haa95532_0
#   tabulate                           0.8.10-py311haa95532_0 --> 0.9.0-py311haa95532_0
#   tokenizers                         0.13.2-py311h49fca51_1 --> 0.15.1-py311h49fca51_0
#   tornado                             6.3.2-py311h2bbff1b_0 --> 6.3.3-py311h2bbff1b_0
#   transformers                       4.32.1-py311haa95532_0 --> 4.37.2-py311haa95532_0
#   twisted                           22.10.0-py311h2bbff1b_0 --> 23.10.0-py311haa95532_0
#   typing-extensions                   4.7.1-py311haa95532_0 --> 4.9.0-py311haa95532_1
#   typing_extensions                   4.7.1-py311haa95532_0 --> 4.9.0-py311haa95532_1
#   tzdata                                   2023c-h04d1e81_0 --> 2024a-h04d1e81_0
#   urllib3                           1.26.16-py311haa95532_0 --> 2.0.7-py311haa95532_0
#   utf8proc                                 2.6.1-h2bbff1b_0 --> 2.6.1-h2bbff1b_1
#   w3lib              pkgs/main/noarch::w3lib-1.21.0-pyhd3e~ --> pkgs/main/win-64::w3lib-2.1.2-py311haa95532_0
#   widgetsnbextension                  4.0.5-py311haa95532_0 --> 4.0.10-py311haa95532_0
#   xz                                       5.4.2-h8cc25b3_0 --> 5.4.6-h8cc25b3_0
#   yaml-cpp                                 0.7.0-hd77b12b_1 --> 0.8.0-hd77b12b_0
#   yapf               pkgs/main/noarch::yapf-0.31.0-pyhd3eb~ --> pkgs/main/win-64::yapf-0.40.2-py311haa95532_0
#   yarl                                1.8.1-py311h2bbff1b_0 --> 1.9.3-py311h2bbff1b_0
#   zeromq                                   4.3.4-hd77b12b_0 --> 4.3.5-hd77b12b_0
#   zict                                2.2.0-py311haa95532_0 --> 3.0.0-py311haa95532_0
#   zipp                               3.11.0-py311haa95532_0 --> 3.17.0-py311haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   scikit-learn                        1.3.0-py311hf62ec03_0 --> 1.2.2-py311hd77b12b_1
#
#
#
# Downloading and Extracting Packages
#
# anaconda-cloud-auth- | 50 KB     |            |   0%
#
# aiobotocore-2.7.0    | 153 KB    |            |   0%
#
#
# widgetsnbextension-4 | 949 KB    |            |   0%
#
#
#
# tomli-2.0.1          | 31 KB     |            |   0%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    |            |   0%
#
#
#
#
#
# jsonpatch-1.33       | 54 KB     |            |   0%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   |            |   0%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    |            |   0%
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 247 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# py-cpuinfo-9.0.0     | 87 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# aws-c-cal-0.5.20     | 41 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 49 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_events-0.8.0 | 58 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.0     | 47 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.1. | 107 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.5.0        | 343 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpc-1.1.0            | 260 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# tomli-2.0.1          | 31 KB     | #####2     |  52%
#
#
#
#
#
# jsonpatch-1.33       | 54 KB     | ##9        |  30%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    |            |   0%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | 1          |   1%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | 3          |   4%
#
#
#
# tomli-2.0.1          | 31 KB     | ########## | 100%
#
#
#
# tomli-2.0.1          | 31 KB     | ########## | 100%
#
#
#
#
#
# jsonpatch-1.33       | 54 KB     | #####9     |  60%
#
# aiobotocore-2.7.0    | 153 KB    | #          |  10%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | 6          |   6%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   |            |   0%
# anaconda-cloud-auth- | 50 KB     | ###1       |  32%
#
#
# widgetsnbextension-4 | 949 KB    | 1          |   2%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    |            |   0%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | 8          |   8%
#
#
# widgetsnbextension-4 | 949 KB    | #5         |  15%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   |            |   1%
# anaconda-cloud-auth- | 50 KB     | ######3    |  64%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | 7          |   7%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 1          |   1%
#
#
# widgetsnbextension-4 | 949 KB    | ####       |  40%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | 9          |  10%
#
#
#
#
#
# jsonpatch-1.33       | 54 KB     | ########## | 100%
#
#
#
#
#
# jsonpatch-1.33       | 54 KB     | ########## | 100%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | #5         |  15%
# anaconda-cloud-auth- | 50 KB     | #########5 |  96%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 1          |   1%
#
#
# widgetsnbextension-4 | 949 KB    | ######7    |  67%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 247 KB    | 6          |   6%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 1          |   2%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #1         |  11%
#
#
# widgetsnbextension-4 | 949 KB    | #########2 |  93%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ###        |  31%
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 247 KB    | #9         |  19%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 2          |   2%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #2         |  13%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
#
# py-cpuinfo-9.0.0     | 87 KB     | #8         |  18%
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 247 KB    | ###8       |  39%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 3          |   3%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #4         |  14%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ####3      |  44%
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 247 KB    | #######1   |  71%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# aws-c-cal-0.5.20     | 41 KB     | ###8       |  39%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #5         |  15%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 49 KB     | ###2       |  33%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | 4          |   4%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_events-0.8.0 | 58 KB     | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
# frozenlist-1.4.0     | 47 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.4.0     | 47 KB     | ########## | 100%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###2       |  33%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ##7        |  27%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #4         |  15%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 49 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ##9        |  30%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 49 KB     | ########## | 100%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ###2       |  32%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###5       |  35%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ###4       |  34%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###6       |  36%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ###6       |  37%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###7       |  37%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.1. | 107 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.1. | 107 KB    | ########## | 100%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ###8       |  39%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ####2      |  42%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ###9       |  40%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #9         |  20%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_events-0.8.0 | 58 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_events-0.8.0 | 58 KB     | ########## | 100%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.5.0        | 343 KB    | ########## | 100%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ####8      |  48%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##1        |  22%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #####1     |  51%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##2        |  22%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 310 KB    | ########## | 100%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpc-1.1.0            | 260 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #####7     |  57%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ######     |  60%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####8      |  48%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##4        |  24%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ######3    |  63%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ####9      |  50%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ######5    |  66%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####      |  51%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ######8    |  68%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####1     |  52%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #######    |  71%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####2     |  53%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #######3   |  73%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####3     |  54%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #######5   |  75%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####4     |  55%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #######7   |  78%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########   |  80%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###1       |  31%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####6     |  57%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########2  |  83%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####8     |  58%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########4  |  85%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########6  |  87%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########8  |  89%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###4       |  35%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #####9     |  60%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###5       |  35%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #########  |  90%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #########1 |  92%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###5       |  36%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######2    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #########4 |  94%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###6       |  37%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #########7 |  97%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###7       |  37%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######4    |  65%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | #########9 |  99%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ###9       |  39%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######6    |  66%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####       |  40%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######7    |  67%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####1      |  41%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######7    |  68%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####2      |  42%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######8    |  69%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####3      |  43%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ######9    |  70%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####4      |  44%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######    |  71%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####5      |  45%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######1   |  72%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####6      |  46%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####6      |  47%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######2   |  73%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####8      |  48%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######3   |  74%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ####9      |  49%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######4   |  75%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####      |  50%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######5   |  76%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####1     |  52%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######6   |  76%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####2     |  53%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####3     |  54%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######7   |  77%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####5     |  55%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######8   |  78%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####6     |  56%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######9   |  79%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####7     |  58%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #####8     |  59%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########   |  81%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######     |  60%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########1  |  82%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######1    |  62%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########2  |  82%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######2    |  63%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########3  |  83%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######4    |  64%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########4  |  84%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######5    |  66%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########5  |  85%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######7    |  67%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ######9    |  69%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########6  |  86%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######    |  71%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########6  |  87%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######2   |  72%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########7  |  88%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######3   |  74%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######5   |  76%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########8  |  89%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########9  |  90%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######7   |  77%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #######8   |  79%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########  |  91%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########   |  81%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########1 |  92%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########2 |  93%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########2  |  82%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########3 |  94%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########3  |  84%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########5  |  85%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########4 |  95%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########6  |  87%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########6 |  96%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########8  |  88%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########7 |  97%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########9  |  90%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########8 |  98%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########1 |  91%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | #########9 | 100%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########3 |  93%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########4 |  95%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########6 |  96%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########7 |  98%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.10         | 4.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# libpq-12.17          | 3.2 MB    | ########## | 100%
#
#
#
#
# arrow-cpp-14.0.2     | 8.5 MB    | ########## | 100%
#
#
#
#
#
#
# transformers-4.37.2  | 10.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\User\anaconda3\Lib\site-packages\conda\plugins\types.py))
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\User\anaconda3\Lib\site-packages\conda\plugins\types.py))
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0

# %%
conda info --envs
# Out:
# # conda environments:
# Note: you may need to restart the kernel to use updated packages.
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\User\anaconda3\Lib\site-packages\conda\plugins\types.py))
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\User\anaconda3\Lib\site-packages\conda\plugins\types.py))
# #
# base                  *  C:\Users\User\anaconda3

# %%
conda activate myenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNameNotFound: Could not find conda environment: myenv
# You can list all discoverable environments with `conda info --envs`.

# %%
conda create --name newenv python=3.11
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate newenv

# %%
# Windows
env\Scripts\activate
# Out:
#   Cell In[36], line 2
#     env\Scripts\activate
#         ^
# SyntaxError: unexpected character after line continuation character

# %%
python -m venv env
# Out:
#   Cell In[12], line 1
#     python -m venv env
#               ^
# SyntaxError: invalid syntax

# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %%
python3 --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 python3 --version
#
# NameError: name 'python3' is not defined

# %%
pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
import os

# 올바른 디렉토리 경로로 변경
os.chdir(r'C:\Users\User\Desktop\jupytertest')

# 이제 현재 디렉토리는 'C:\Users\User\Desktop\jupytertest'
print("현재 작업 디렉토리:", os.getcwd())

# setup.py 파일 작업을 계속하려면 여기에서 코드를 추가할 수 있습니다.
# Out:
# 현재 작업 디렉토리: C:\Users\User\Desktop\jupytertest

# %%
python -m venv myenv
# Out:
#   Cell In[12], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
python -m venv myenv
myenv\Scripts\activate  # Windows
# source myenv/bin/activate  # macOS/Linux
pip install pandas
# Out:
#   Cell In[9], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
python setup.pbby build_ext --inplace
# Out:
#   Cell In[43], line 1
#     python setup.py build_ext --inplace
#            ^
# SyntaxError: invalid syntax

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Processing c:\b\abs_3cwz1w13nn\croot\aiobotocore_1701291550158\work (from -r requirements.txt (line 1))
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\b\\abs_3cwz1w13nn\\croot\\aiobotocore_1701291550158\\work'
#
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
python -m venv myenv
myenv\Scripts\activate  # Windows에서 활성화
# Out:
#   Cell In[18], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
Set-ExecutionPolicy -Scope Process -ExecutionPolicy Bypass
# Out:
#   Cell In[20], line 1
#     Set-ExecutionPolicy -Scope Process -ExecutionPolicy Bypass
#                                ^
# SyntaxError: invalid syntax

# %%
myenv\Scripts\Activate.ps1
# Out:
#   Cell In[21], line 1
#     myenv\Scripts\Activate.ps1
#           ^
# SyntaxError: unexpected character after line continuation character

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2024.2.2)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.7.0
# aiohttp                       3.9.3
# aiohttp-retry                 2.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.5.0
# anaconda-navigator            2.5.4
# anaconda-project              0.11.1
# annotated-types               0.6.0
# anyio                         4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.3.4
# asttokens                     2.0.5
# async-lru                     2.0.4
# atomicwrites                  1.4.0
# attrs                         23.1.0
# Automat                       20.2.0
# autopep8                      2.0.4
# Babel                         2.11.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# black                         24.3.0
# bleach                        4.1.0
# bokeh                         3.4.0
# boltons                       23.0.0
# botocore                      1.31.64
# Bottleneck                    1.3.7
# Brotli                        1.0.9
# certifi                       2024.2.2
# cffi                          1.16.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.1.7
# cloudpickle                   2.2.1
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      3.1.0
# comm                          0.2.1
# conda                         23.7.4
# conda-build                   3.26.1
# conda-content-trust           0.2.0
# conda_index                   0.4.0
# conda-libmamba-solver         23.7.0
# conda-pack                    0.6.0
# conda-package-handling        2.2.0
# conda_package_streaming       0.9.0
# conda-repo-cli                1.0.88
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    23.10.4
# contourpy                     1.2.0
# cookiecutter                  2.6.0
# cryptography                  42.0.5
# cssselect                     1.2.0
# cycler                        0.11.0
# cytoolz                       0.12.2
# daal4py                       2023.1.1
# dacite                        1.8.1
# dask                          2023.11.0
# datashader                    0.16.0
# debugpy                       1.6.7
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.7
# distributed                   2023.11.0
# docstring-to-markdown         0.11
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.16.2
# filelock                      3.13.1
# flake8                        7.0.0
# Flask                         2.2.5
# fonttools                     4.25.0
# frozenlist                    1.4.0
# fsspec                        2023.10.0
# future                        0.18.3
# gensim                        4.3.0
# glob2                         0.7
# gmpy2                         2.1.2
# greenlet                      3.0.1
# h5py                          3.9.0
# HeapDict                      1.0.1
# holoviews                     1.18.3
# htmlmin                       0.1.12
# huggingface-hub               0.20.3
# hvplot                        0.9.2
# hyperlink                     21.0.0
# idna                          3.4
# imagecodecs                   2023.1.23
# ImageHash                     4.3.1
# imageio                       2.33.1
# imagesize                     1.4.1
# imbalanced-learn              0.11.0
# importlib-metadata            7.0.1
# incremental                   22.10.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.28.0
# ipython                       8.20.0
# ipywidgets                    8.1.2
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.1.0
# itsdangerous                  2.0.1
# jaraco.classes                3.2.1
# jedi                          0.18.1
# jellyfish                     1.0.1
# Jinja2                        3.1.3
# jmespath                      1.0.1
# joblib                        1.1.1
# json5                         0.9.6
# jsonpatch                     1.33
# jsonpointer                   2.1
# jsonschema                    4.19.2
# jsonschema-specifications     2023.7.1
# jupyter                       1.0.0
# jupyter_client                8.6.0
# jupyter-console               6.6.3
# jupyter_core                  5.5.0
# jupyter-events                0.8.0
# jupyter-lsp                   2.2.0
# jupyter_server                2.10.0
# jupyter_server_terminals      0.4.4
# jupyterlab                    4.0.11
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.25.1
# jupyterlab-widgets            3.0.10
# kaleido                       0.2.1
# keyring                       24.3.1
# kiwisolver                    1.4.4
# lazy_loader                   0.3
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libmambapy                    1.5.8
# linkify-it-py                 2.0.0
# llvmlite                      0.42.0
# lmdb                          1.4.1
# locket                        1.0.0
# lxml                          4.9.3
# lz4                           4.3.2
# Markdown                      3.4.1
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.3
# matplotlib                    3.8.0
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mdit-py-plugins               0.3.0
# mdurl                         0.1.0
# menuinst                      1.4.19
# missingno                     0.5.2
# mistune                       2.0.4
# mkl-fft                       1.3.8
# mkl-random                    1.2.4
# mkl-service                   2.4.0
# more-itertools                10.1.0
# mpmath                        1.3.0
# msgpack                       1.0.3
# multidict                     6.0.4
# multimethod                   1.11.2
# multipledispatch              0.6.0
# munkres                       1.1.4
# mypy-extensions               1.0.0
# navigator-updater             0.4.0
# nbclient                      0.8.0
# nbconvert                     7.10.0
# nbformat                      5.9.2
# nest-asyncio                  1.6.0
# networkx                      3.1
# nltk                          3.8.1
# notebook                      7.0.8
# notebook_shim                 0.2.3
# numba                         0.59.1
# numexpr                       2.8.7
# numpy                         1.26.4
# numpydoc                      1.5.0
# openpyxl                      3.0.10
# overrides                     7.4.0
# packaging                     23.2
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         1.4.1
# param                         2.1.0
# paramiko                      2.8.1
# parsel                        1.8.1
# parso                         0.8.3
# partd                         1.4.1
# pathspec                      0.10.3
# patsy                         0.5.3
# pdfkit                        1.0.0
# pep8                          1.7.1
# pexpect                       4.8.0
# phik                          0.12.4
# pickleshare                   0.7.5
# pillow                        10.2.0
# pip                           23.3.1
# pkce                          1.0.3
# pkginfo                       1.9.6
# platformdirs                  3.10.0
# plotly                        5.19.0
# pluggy                        1.0.0
# ply                           3.11
# prometheus-client             0.14.1
# prompt-toolkit                3.0.43
# Protego                       0.1.16
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       14.0.2
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.11.1
# pycosat                       0.6.6
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.2
# pydantic                      2.5.3
# pydantic_core                 2.14.6
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pyerfa                        2.0.0
# pyflakes                      3.2.0
# Pygments                      2.15.1
# PyJWT                         2.4.0
# pylint                        2.16.2
# pylint-venv                   3.0.3
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        5.0.1
# pyOpenSSL                     24.0.0
# pyparsing                     3.0.9
# PyPDF2                        3.0.1
# PyQt5                         5.15.10
# PyQt5-sip                     12.13.0
# PyQtWebEngine                 5.15.6
# PySocks                       1.7.1
# pytesseract                   0.3.10
# pytest                        7.4.0
# python-dateutil               2.8.2
# python-dotenv                 0.21.0
# python-json-logger            2.0.7
# python-lsp-black              2.0.0
# python-lsp-jsonrpc            1.1.2
# python-lsp-server             1.10.0
# python-slugify                5.0.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.6
# pytz                          2023.3.post1
# pyviz_comms                   3.0.2
# pywavelets                    1.5.0
# pywin32                       305.1
# pywin32-ctypes                0.2.2
# pywinpty                      2.0.10
# pyxlsb                        1.0.10
# PyYAML                        6.0.1
# pyzmq                         25.1.2
# QDarkStyle                    3.2.3
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.5.1
# QtPy                          2.4.1
# queuelib                      1.6.2
# referencing                   0.30.2
# regex                         2023.10.3
# requests                      2.31.0
# requests-file                 1.5.1
# requests-toolbelt             1.0.0
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          13.3.5
# rope                          1.12.0
# rpds-py                       0.10.6
# Rtree                         1.0.1
# ruamel.yaml                   0.17.21
# ruamel-yaml-conda             0.17.21
# s3fs                          2023.10.0
# safetensors                   0.4.2
# scikit-image                  0.22.0
# scikit-learn                  1.2.2
# scikit-learn-intelex          20230426.121932
# scipy                         1.12.0
# Scrapy                        2.11.1
# seaborn                       0.12.2
# semver                        3.0.2
# Send2Trash                    1.8.2
# service-identity              18.1.0
# setuptools                    68.0.0
# sip                           6.7.12
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.5
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.5.1
# spyder-kernels                2.5.0
# SQLAlchemy                    2.0.25
# stack-data                    0.2.0
# statsmodels                   0.14.0
# sympy                         1.12
# tables                        3.9.2
# tabulate                      0.9.0
# tangled-up-in-unicode         0.2.0
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.2.2
# terminado                     0.17.1
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2023.4.12
# tinycss2                      1.2.1
# tkcalendar                    1.6.1
# tldextract                    3.2.0
# tokenizers                    0.15.1
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.12.0
# tornado                       6.3.3
# tqdm                          4.65.0
# traitlets                     5.7.1
# transformers                  4.37.2
# twilio                        9.0.2
# Twisted                       23.10.0
# twisted-iocpsupport           1.0.2
# typeguard                     4.1.5
# typing_extensions             4.9.0
# tzdata                        2023.3
# uc-micro-py                   1.0.1
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       2.0.7
# visions                       0.7.6
# w3lib                         2.1.2
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.2.3
# whatthepatch                  1.0.2
# wheel                         0.38.4
# widgetsnbextension            4.0.10
# win-inet-pton                 1.1.0
# wordcloud                     1.9.3
# wrapt                         1.14.1
# xarray                        2023.6.0
# xlrd                          2.0.1
# xlwings                       0.29.1
# xyzservices                   2022.9.0
# yapf                          0.40.2
# yarl                          1.9.3
# ydata-profiling               4.7.0
# zict                          3.0.0
# zipp                          3.17.0
# zope.interface                5.4.0
# zstandard                     0.19.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
python script.py
# Out:
#   Cell In[26], line 1
#     python script.py
#            ^
# SyntaxError: invalid syntax

# %%
deactivate

# %%
import subprocess

# script.py 파일을 실행
subprocess.run(["python", "script.py"])
# Out:
# CompletedProcess(args=['python', 'script.py'], returncode=2)

# %%
import subprocess

# 전체 경로를 사용하여 script.py 파일을 실행
subprocess.run(["python", "C:/path/to/your/script.py"])
# Out:
# CompletedProcess(args=['python', 'C:/path/to/your/script.py'], returncode=2)

# %%
import os

# 올바른 디렉토리 경로로 변경
os.chdir(r'C:\Users\User\Desktop\jupytertest')

# 이제 현재 디렉토리는 'C:\Users\User\Desktop\jupytertest'
print("현재 작업 디렉토리:", os.getcwd())

# setup.py 파일 작업을 계속하려면 여기에서 코드를 추가할 수 있습니다.
# Out:
# 현재 작업 디렉토리: C:\Users\User\Desktop\jupytertest

# %%
import csv

# 여기서 파일 경로를 직접 지정해주세요. 예를 들어, 'C:/Users/YourName/Documents/data.csv'
file_path = r'D:\공공기관 데이터모음\인허가자료\0403\변동0401_0403까지병합.csv'

# 저장할 새 파일 경로도 지정해주세요.
output_file_path = r'D:\공공기관 데이터모음\인허가자료\0403\0403까지병합조건_file_path.csv'

# 추출하고자 하는 열 이름들을 지정해주세요.
selected_columns = ['소재지전체주소','도로명전체주소','도로명우편번호','사업장명', '개방서비스명', '인허가일자', '인허가취소', '영업상태명', '폐업일자',
                    '휴업시작일', '휴업종료일', '재개업일자', '소재지전화', '소재지전체주소',
                    '도로명전체주소', '사업장명', '최종수정시점', '업태구분명','좌표정보(X)', '좌표정보(Y)', '총면적', '소재지면적']

try:
    # 원본 파일을 열기 (인코딩 방식 변경을 시도해보세요.)
    with open(file_path, mode='r', encoding='cp949') as file:  # 'utf-8' 대신 'cp949'로 변경해보세요.
        csv_reader = csv.DictReader(file)
        selected_data = []

        # 필요한 열만 추출하여 리스트에 저장
        for row in csv_reader:
            selected_row = {col: row.get(col, '') for col in selected_columns if col in row}
            selected_data.append(selected_row)

    # 새 파일에 저장
    with open(output_file_path, mode='w', newline='', encoding='cp949') as output_file:
        csv_writer = csv.DictWriter(output_file, fieldnames=selected_columns)
        csv_writer.writeheader()
        csv_writer.writerows(selected_data)

    print(f"작업이 완료되었습니다. 데이터가 저장된 파일의 경로: {output_file_path}")

except FileNotFoundError:
    print("입력한 파일 경로를 찾을 수 없습니다. 파일 경로를 확인해주세요.")
except Exception as e:
    print(f"예상치 못한 오류가 발생했습니다: {e}")
# Out:
# 예상치 못한 오류가 발생했습니다: 'cp949' codec can't decode byte 0xab in position 12: illegal multibyte sequence

# %%
# 판다스 삭제
# !pip uninstall pandas
# Out:
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
# 판다스 설치
# !pip install pandas
# Out:
# ^C
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
# 가상환경설정
python -m venv myenv

# %%
# 가상환경 활성화
myenv\Scripts\activate

# %%
# 패키지 재설치
pip install pandas

# %%
pip uninstall pandas -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
import pandas as pd
import os
import glob

# 병합하고자 하는 파일이 위치한 디렉토리 경로
input_directory = r'D:\공공기관 데이터모음\인허가자료\0423\LOCALDATA_NOWMON_CSV'

# 해당 디렉토리에서 모든 CSV 파일 목록을 가져옴
all_files = glob.glob(os.path.join(input_directory, "*.csv"))

if len(all_files) == 0:
    raise ValueError("No CSV files found in the specified directory.")

# 각 파일을 읽어서 하나의 DataFrame으로 병합
dfs = []
for file in all_files:
    try:
        df = pd.read_csv(file, encoding='cp949')
        dfs.append(df)
    except Exception as e:
        print(f"Error reading file {file}: {e}")

if len(dfs) == 0:
    raise ValueError("No valid CSV files found.")

concatenated_df = pd.concat(dfs, ignore_index=True)

# '인허가일자' 기준으로 내림차순 정렬
if '인허가일자' in concatenated_df.columns:
    concatenated_df['인허가일자'] = pd.to_datetime(concatenated_df['인허가일자'], format='%Y%m%d', errors='coerce')
    concatenated_df.sort_values(by='인허가일자', ascending=False, inplace=True)

# 저장할 새 파일의 경로
output_file_path = r'D:\공공기관 데이터모음\인허가자료\0423\변동0401_0423까지병합.csv'

# 병합된 데이터를 새 파일에 저장
concatenated_df.to_csv(output_file_path, index=False, encoding='cp949')

print(f"작업이 완료되었습니다. 정렬 및 줄 바꿈이 적용된 데이터가 저장된 파일의 경로: {output_file_path}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\__init__.py:39
#      37 try:
#      38     # numpy compat
# ---> 39     from pandas.compat import (
#      40         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      41     )
#      42 except ImportError as _err:  # pragma: no cover
#
# ModuleNotFoundError: No module named 'pandas.compat'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import pandas as pd
#       2 import os
#       3 import glob
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\__init__.py:44
#      42 except ImportError as _err:  # pragma: no cover
#      43     _module = _err.name
# ---> 44     raise ImportError(
#      45         f"C extension: {_module} not built. If you want to import "
#      46         "pandas from the source directory, you may need to run "
#      47         "'python setup.py build_ext' to build the C extensions first."
#      48     ) from _err
#      50 from pandas._config import (
#      51     get_option,
#      52     set_option,
#    (...)
#      56     options,
#      57 )
#      59 # let init-time option registration happen
#
# ImportError: C extension: pandas.compat not built. If you want to import pandas from the source directory, you may need to run 'python setup.py build_ext' to build the C extensions first.

# %%
import csv

file_path = r'D:\공공기관 데이터모음\인허가자료\0423\변동0401_0423까지병합.csv'
output_file_path = r'D:\공공기관 데이터모음\인허가자료\0423\0423까지병합조건_file_path.csv'
selected_columns = ['소재지전체주소','도로명전체주소','도로명우편번호','사업장명', '개방서비스명', '인허가일자', '인허가취소', '영업상태명', '폐업일자',
                    '휴업시작일', '휴업종료일', '재개업일자', '소재지전화', '소재지전체주소',
                    '도로명전체주소', '사업장명', '최종수정시점', '업태구분명','좌표정보(X)', '좌표정보(Y)', '총면적', '소재지면적']

try:
    with open(file_path, mode='r', encoding='cp949', errors='ignore') as file:
        csv_reader = csv.DictReader(file)
        selected_data = []

        for row in csv_reader:
            selected_row = {col: row.get(col, '') for col in selected_columns if col in row}
            selected_data.append(selected_row)

    with open(output_file_path, mode='w', newline='', encoding='cp949') as output_file:
        csv_writer = csv.DictWriter(output_file, fieldnames=selected_columns)
        csv_writer.writeheader()
        csv_writer.writerows(selected_data)

    print(f"작업이 완료되었습니다. 데이터가 저장된 파일의 경로: {output_file_path}")

except FileNotFoundError:
    print("입력한 파일 경로를 찾을 수 없습니다. 파일 경로를 확인해주세요.")
except Exception as e:
    print(f"예상치 못한 오류가 발생했습니다: {e}")
# Out:
# 작업이 완료되었습니다. 데이터가 저장된 파일의 경로: D:\공공기관 데이터모음\인허가자료\0423\0423까지병합조건_file_path.csv

# %%
# !pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
conda install pandas
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install pandas')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
#      25 if not Path(sys.prefix, "conda-meta", "history").exists():
#      26     raise ValueError(
#      27         "The python kernel does not appear to be a conda environment.  "
#      28         "Please use ``%pip install`` instead."
#      29     )
# ---> 30 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:128, in PackagingMagics.conda(self, line)
#     120 @line_magic
#     121 @is_conda_environment
#     122 def conda(self, line):
#     123     """Run the conda package manager within the current kernel.
#     124
#     125     Usage:
#     126       %conda install [pkgs]
#     127     """
# --> 128     conda = _get_conda_like_executable("conda")
#     129     self._run_command(conda, line)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:53, in _get_conda_like_executable(command)
#      50 # Otherwise, attempt to extract the executable from conda history.
#      51 # This applies in any conda environment.
#      52 history = Path(sys.prefix, "conda-meta", "history").read_text(encoding="utf-8")
# ---> 53 match = re.search(
#      54     rf"^#\s*cmd:\s*(?P<command>.*{executable})\s[create|install]",
#      55     history,
#      56     flags=re.MULTILINE,
#      57 )
#      58 if match:
#      59     return match.groupdict()["command"]
#
# File ~\anaconda3\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# File ~\anaconda3\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File ~\anaconda3\Lib\re\_compiler.py:743, in compile(p, flags)
#     741 if isstring(p):
#     742     pattern = p
# --> 743     p = _parser.parse(p, flags)
#     744 else:
#     745     pattern = None
#
# File ~\anaconda3\Lib\re\_parser.py:982, in parse(str, flags, state)
#     979 state.flags = flags
#     980 state.str = str
# --> 982 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     983 p.state.flags = fix_flags(str, p.state.flags)
#     985 if source.next is not None:
#
# File ~\anaconda3\Lib\re\_parser.py:457, in _parse_sub(source, state, verbose, nested)
#     455 start = source.tell()
#     456 while True:
# --> 457     itemsappend(_parse(source, state, verbose, nested + 1,
#     458                        not nested and not items))
#     459     if not sourcematch("|"):
#     460         break
#
# File ~\anaconda3\Lib\re\_parser.py:865, in _parse(source, state, verbose, nested, first)
#     862     group = None
#     863 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     864                not (del_flags & SRE_FLAG_VERBOSE))
# --> 865 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     866 if not source.match(")"):
#     867     raise source.error("missing ), unterminated subpattern",
#     868                        source.tell() - start)
#
# File ~\anaconda3\Lib\re\_parser.py:457, in _parse_sub(source, state, verbose, nested)
#     455 start = source.tell()
#     456 while True:
# --> 457     itemsappend(_parse(source, state, verbose, nested + 1,
#     458                        not nested and not items))
#     459     if not sourcematch("|"):
#     460         break
#
# File ~\anaconda3\Lib\re\_parser.py:541, in _parse(source, state, verbose, nested, first)
#     538         continue
#     540 if this[0] == "\\":
# --> 541     code = _escape(source, this, state)
#     542     subpatternappend(code)
#     544 elif this not in SPECIAL_CHARS:
#
# File ~\anaconda3\Lib\re\_parser.py:395, in _escape(source, escape, state)
#     393 escape += source.getwhile(8, HEXDIGITS)
#     394 if len(escape) != 10:
# --> 395     raise source.error("incomplete escape %s" % escape, len(escape))
#     396 c = int(escape[2:], 16)
#     397 chr(c) # raise ValueError for invalid code
#
# error: incomplete escape \U at position 28

# %%
python setup.py build_ext --inplace
# Out:
#   Cell In[12], line 1
#     python setup.py build_ext --inplace
#            ^
# SyntaxError: invalid syntax

# %%
pip install pandas-compat
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Collecting pandas-compat
#   Downloading pandas_compat-0.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting pandas (from pandas-compat)
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas->pandas-compat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas->pandas-compat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->pandas-compat) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->pandas-compat) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandas-compat) (1.16.0)
# Downloading pandas_compat-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas, pandas-compat
# Successfully installed pandas-2.1.4 pandas-compat-0.1.1
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
import pandas as pd
import os
import glob

# 병합하고자 하는 파일이 위치한 디렉토리 경로
input_directory = r'D:\공공기관 데이터모음\인허가자료\0423\LOCAL
DATA_NOWMON_CSV'

# 저장할 새 파일의 경로
output_file_path = r'D:\공공기관 데이터모음\인허가자료\0423\변동0401_0423까지병합.csv'

# 해당 디렉토리에서 모든 CSV 파일 목록을 가져옴
all_files = glob.glob(os.path.join(input_directory, "*.csv"))

# 각 파일을 읽어서 하나의 DataFrame으로 병합
df_from_each_file = (pd.read_csv(f, encoding='cp949') for f in all_files)
concatenated_df = pd.concat(df_from_each_file, ignore_index=True)

# '인허가일자' 기준으로 내림차순 정렬
if '인허가일자' in concatenated_df.columns:
    concatenated_df['인허가일자'] = pd.to_datetime(concatenated_df['인허가일자'], format='%Y%m%d', errors='coerce')
    concatenated_df.sort_values(by='인허가일자', ascending=False, inplace=True)

# 병합된 데이터를 새 파일에 저장
concatenated_df.to_csv(output_file_path, index=False, encoding='cp949')

print(f"작업이 완료되었습니다. 정렬 및 줄 바꿈이 적용된 데이터가 저장된 파일의 경로: {output_file_path}")
# Out:
#   Cell In[13], line 6
#     input_directory = r'D:\공공기관 데이터모음\인허가자료\0423\LOCAL
#                       ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
pip uninstall pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping pandas as it is not installed.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple/Note: you may need to restart the kernel to use updated packages.
#
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# ydata-profiling 4.7.0 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)

# %%
pip show pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Package(s) not found: pandas

# %%
# !python setup.py build_ext --inplace --force
# Out:
# python: can't open file 'C:\\Users\\User\\Desktop\\jupytertest\\setup.py': [Errno 2] No such file or directory

# %%
pip install build
# Out:
# Looking in indexes: https://pypi.org/simple/
# Collecting build
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: packaging>=19.1 in c:\users\user\anaconda3\lib\site-packages (from build) (23.2)
# Collecting pyproject_hooks (from build)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from build) (0.4.6)
# Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Installing collected packages: pyproject_hooks, build
# Successfully installed build-1.2.1 pyproject_hooks-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\User\AppData\Roaming\Python\Python311\site-packages)
