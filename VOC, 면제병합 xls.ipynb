# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 325.1 kB/s eta 0:00:01
#    -------------------------------------- - 92.2/96.5 kB 871.5 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 549.6 kB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import glob
import os

# 폴더 경로 설정
folder_path = r'D:\시설\정지\정지VOC'

# 모든 .xls 및 .xlsx 파일 경로 가져오기
all_files = glob.glob(folder_path + "/*.xls") + glob.glob(folder_path + "/*.xlsx")

# 병합할 데이터를 저장할 데이터프레임 초기화
all_data = pd.DataFrame()

# 파일 처리
for file in all_files:
    try:
        # 파일 확장자에 따라 처리
        if file.endswith(".xls") or file.endswith(".xlsx"):
            # Excel 파일 처리
            df = pd.read_excel(file, sheet_name=0)  # 첫 번째 시트만 읽기
        else:
            # HTML 형식으로 처리
            df_list = pd.read_html(file)
            df = df_list[0]  # 첫 번째 테이블만 사용
       
        # 데이터가 유효한 경우만 병합
        if not df.empty:
            all_data = pd.concat([all_data, df], ignore_index=True)
            print(f"{file} 데이터 미리보기:\n", df.head())
        else:
            print(f"{file} 데이터가 비어 있습니다. 건너뜁니다.")
    except Exception as e:
        print(f"파일을 읽는 중 오류 발생: {file}, 오류: {e}")

# 병합된 데이터를 csv 파일로 저장 (CP949 인코딩 적용)
output_path = os.path.join(folder_path, "정지VOC분석병합2023-20250113.csv")
if not all_data.empty:
    all_data.to_csv(output_path, index=False, encoding='cp949')
    print(f"병합된 파일이 {output_path}에 저장되었습니다.")
else:
    print("병합된 데이터가 비어 있습니다. 파일 형식과 데이터를 확인하세요.")
# Out:
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091240124.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30723579   51473225   61953403        김성*
# 2     미접수          N   30657043   50799058   60959127        김태*
# 3     미접수          N   30595013   51233468   61510262       새빛전*
# 4     미접수          N   30519735   51303285   61607777        오미*
#
#              Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                    상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1       다함께돌봄센터(2호)행복주택      변경/조회         정지       일시정지  ...  2025.08.31
# 2                   k푸드      변경/조회         정지       일시정지  ...  2025.12.31
# 3  새빛전력(GiGAeyes guard)      변경/조회         정지       일시정지  ...  2025.04.30
# 4               아톰(OCT)      변경/조회         정지       일시정지  ...  2025.02.28
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1       36,000           0        영업본부        리텐션팀          N2           N
# 2       67,000           0        영업본부        리텐션팀          N2           N
# 3            0           0        영업본부        리텐션팀          N2           N
# 4       60,000           1        영업본부        리텐션팀          P2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부       남양주지사         NaN
# 2     강북/강원본부       서대문지사         NaN
# 3     강북/강원본부       남양주지사         NaN
# 4     강북/강원본부       의정부지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091310381.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호             고객명
# 1     미접수          N   30830274   51664638   62361529  뷰티앤바이트글로벌 주식회*
# 2     미접수          N   30866269   51973139   63016048             문수*
# 3     미접수          N   30524757   51096346   61318756             오상*
# 4     미접수          N   30437053   50938971   61126105             오상*
#
#                 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                       상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1  브릭샌드삼청점(GiGAeyes guard)      변경/조회         정지       일시정지  ...  2025.08.30
# 2                 문수정주택(뷰)      변경/조회         정지       일시정지  ...  2027.04.29
# 3           민쥬얼리연지동(NVR-뷰)      변경/조회         정지       일시정지  ...  2025.02.28
# 4         (SG)민쥬얼리연지동(OCT)      변경/조회         정지       일시정지  ...  2024.12.12
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1            0           0        영업본부        리텐션팀          N2           N
# 2       22,000           0        영업본부        리텐션팀          N2           N
# 3      100,000           0        영업본부        리텐션팀          N2           N
# 4      151,000           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부        중앙지사         NaN
# 2     강북/강원본부       의정부지사         NaN
# 3     강북/강원본부        중앙지사         NaN
# 4     강북/강원본부        중앙지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091330622.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호          고객명
# 1     미접수          N   30798182   51609496   62241072  오티씨테크놀로지(주*
# 2     미접수          N   30970949   51927039   62917456          오남*
# 3     미접수          N   30825292   20557621   20557621          김선*
# 4     미접수          N   30953878   51779522   62600308          김두*
#
#               Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                     상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1  오티씨(GiGAeyes i-guard)      변경/조회         정지       일시정지  ...  2025.05.17
# 2                    오남균      변경/조회         정지       일시정지  ...  2027.01.22
# 3               시립금곡어린이집      변경/조회         정지       일시정지  ...  2025.12.29
# 4              김두호(NVR뷰)      변경/조회         정지       일시정지  ...  2025.09.03
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1            0           0        영업본부        리텐션팀          N2           N
# 2       22,100           0        영업본부        리텐션팀          N2           N
# 3       49,000           0        영업본부        리텐션팀          N2           N
# 4       40,000           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부       남양주지사         NaN
# 2     강북/강원본부        중앙지사         NaN
# 3     강북/강원본부       남양주지사         NaN
# 4     강북/강원본부       남양주지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091347092.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30850143   51699607   62437305        고명*
# 2     미접수          N   31014246   52007433   63088247        고승*
# 3     미접수          N   30568185   51993260   63058714  (주)알레스아우*
# 4    처리완료          N   30929950   51850275   62753695         모*
#
#                         Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                               상호     VOC유형대     VOC유형중     VOC유형소  ...
# 1            동명휴네스(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 2  미아2.5.8 발전협의회(GiGAeyes i-guard)      변경/조회         정지       일시정지  ...
# 3                        (주)알레스아우토      변경/조회         정지       일시정지  ...
# 4                               모어      변경/조회         정지       일시정지  ...
#
#   Unnamed: 31  Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0       계약종료일  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G
# 1         NaN          NaN           0        영업본부        리텐션팀          N2
# 2         NaN          NaN           0        영업본부        리텐션팀          N2
# 3         NaN          NaN           0        영업본부        리텐션팀          N2
# 4         NaN          NaN           0        영업본부        리텐션팀          N2
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0      4대지악유무        관리본부        관리지사   방문활동 완료여부
# 1           N     강북/강원본부       남양주지사         NaN
# 2           N     강북/강원본부        강북지사         NaN
# 3           N     강북/강원본부        강북지사         NaN
# 4           N     강북/강원본부        중앙지사        해당없음
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091404008.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30836201   51674863   62383660        임효*
# 2     미접수          N   30886889   51772401   62584694        김윤*
# 3     미접수          N   30962916   51911974   62885917        송사*
# 4     미접수          N   30952605   51892830   62845002        김완*
#
#              Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                    상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1         이와이엘(EYL)필라테스      변경/조회         정지       일시정지  ...         NaN
# 2  목로주점(GiGAeyes guard)      변경/조회         정지       일시정지  ...         NaN
# 3                   송사면      변경/조회         정지       일시정지  ...         NaN
# 4                   김완구      변경/조회         정지       일시정지  ...         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1          NaN           0        영업본부        리텐션팀          N2           N
# 2          NaN           0        영업본부        리텐션팀          N2           N
# 3          NaN           0        영업본부        리텐션팀          N2           N
# 4          NaN           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부        원주지사         NaN
# 2     강북/강원본부        강릉지사         NaN
# 3     강북/강원본부        원주지사         NaN
# 4     강북/강원본부       남양주지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091431369.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호         고객명
# 1    처리완료          N   30827748   51749543   62536710  (주)코어링크홀딩*
# 2     미접수          N   30753858   51528858   62070561         이재*
# 3     미접수          N   30878775   51756667   62552204         한다*
# 4     미접수          N   30961329   51908665   62879215         김형*
#
#                      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                            상호     VOC유형대     VOC유형중     VOC유형소  ...
# 1       코어링크홀딩스(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 2                       더코지(뷰N)      변경/조회         정지       일시정지  ...
# 3  킹스(kingsICS)(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 4                       재단법인 한올      변경/조회         정지       일시정지  ...
#
#   Unnamed: 31  Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0       계약종료일  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G
# 1         NaN          NaN           0        영업본부        리텐션팀          N2
# 2         NaN          NaN           1        영업본부        리텐션팀          N2
# 3         NaN          NaN           0        영업본부        리텐션팀          N2
# 4         NaN          NaN           0        영업본부        리텐션팀          N2
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0      4대지악유무        관리본부        관리지사   방문활동 완료여부
# 1           N     강북/강원본부        중앙지사        해당없음
# 2           N     강북/강원본부       의정부지사         NaN
# 3           N     강북/강원본부        고양지사         NaN
# 4           N     강북/강원본부        고양지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091440382.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1    처리완료          N   30813977   51636602   62300573        유수*
# 2     미접수          N   30788065   51780117   62601678        김성*
# 3     미접수          N   30788065   51592101   62202913        김성*
# 4     미접수          N   30691831   51468923   61944249        김성*
#
#                         Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                               상호     VOC유형대     VOC유형중     VOC유형소  ...
# 1           아그라센터원(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 2  세븐일레븐경동대문막기숙사점2(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 3                 세븐일레븐 경동대 문막기숙사점      변경/조회         정지       일시정지  ...
# 4    이마트24경동대양주캠퍼스(GiGAeyes guard)      변경/조회         정지       일시정지  ...
#
#   Unnamed: 31  Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0       계약종료일  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G
# 1         NaN          NaN           0        영업본부        리텐션팀          N2
# 2         NaN          NaN           0        영업본부        리텐션팀          N2
# 3         NaN          NaN           0        영업본부        리텐션팀          N2
# 4         NaN          NaN           0        영업본부        리텐션팀          N2
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0      4대지악유무        관리본부        관리지사   방문활동 완료여부
# 1           N     강북/강원본부        중앙지사        해당없음
# 2           N     강북/강원본부        원주지사         NaN
# 3           N     강북/강원본부        원주지사         NaN
# 4           N     강북/강원본부       의정부지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091459033.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30566191   51174120   61423737   육아종합지원센*
# 2     미접수          N   30913231   51819577   62686047    더웨이브컴퍼*
# 3     미접수          N   30615815   51321953   61643590        윤영*
# 4     미접수          N   30330862   51032510   61235627   주식회사피앤월*
#
#           Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                 상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1              까꿍놀이터      변경/조회         정지       일시정지  ...         NaN
# 2       더웨이브컴퍼니-파도의집      변경/조회         정지       일시정지  ...         NaN
# 3    피앤월드(수유점)(view)      변경/조회         정지       일시정지  ...         NaN
# 4  피앤월드(수유점)(텔레캅 큐브)      변경/조회         정지       일시정지  ...         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1          NaN           0        영업본부        리텐션팀          N2           N
# 2          NaN           2        영업본부        리텐션팀          P2           N
# 3          NaN           0        영업본부        리텐션팀          N2           N
# 4          NaN           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부       남양주지사         NaN
# 2     강북/강원본부        강릉지사         NaN
# 3     강북/강원본부        강북지사         NaN
# 4     강북/강원본부        강북지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091516185.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30692171   51417653   61835581        정나*
# 2    처리완료          N   30765509   51687942   62411762    극동건설(주*
# 3     미접수          N   30272586   50617635   60751210        김영*
# 4    처리완료          N   30742619   51511150   62031560       고모빵*
#
#                Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                      상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1  월정곰닭(GiGAeyes i-guard)      변경/조회         정지       일시정지  ...         NaN
# 2               극동건설삼척역-뷰      변경/조회         정지       일시정지  ...         NaN
# 3              라르떼의원(OCT)      변경/조회         정지       일시정지  ...         NaN
# 4                    고모빵집      변경/조회         정지       일시정지  ...         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1          NaN           0        영업본부        리텐션팀          N2           N
# 2          NaN           0        영업본부        리텐션팀          N2           N
# 3          NaN           0        영업본부        리텐션팀          N2           N
# 4          NaN           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부       서대문지사         NaN
# 2     강북/강원본부        강릉지사         NaN
# 3     강북/강원본부        강북지사         NaN
# 4     강북/강원본부        고양지사        해당없음
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091532514.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30634080   51622321   62269184     조형기술개*
# 2     미접수          N   30840109   51543593   62099897        김정*
# 3    처리완료          N   30706388   51408104   61815517        김민*
# 4    처리완료          N   30881670   51805771   62656267         김*
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                  상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1  조형기술개발양주옥정현장2(OCT)      변경/조회         정지       일시정지  ...         NaN
# 2             트리플단란주점      변경/조회         정지       일시정지  ...         NaN
# 3               베스트피싱      변경/조회         정지       일시정지  ...         NaN
# 4        (주)투케이글로벌(뷰)      변경/조회         정지       일시정지  ...         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1          NaN           0        영업본부        리텐션팀          N2           N
# 2          NaN           0        영업본부        리텐션팀          N2           N
# 3          NaN           0        영업본부        리텐션팀          N2           N
# 4          NaN           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부       의정부지사         NaN
# 2     강북/강원본부        강릉지사         NaN
# 3     강북/강원본부        고양지사         NaN
# 4     강북/강원본부       남양주지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091551197.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30373334   50801949   60962444        성정*
# 2     미접수          N   30575828   51440141   61883129    (주)필드나*
# 3     미접수          N   30892125   51781493   62604732        최승*
# 4    처리완료          N   30701857   51434889   61871494        이윤*
#
#               Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 31  \
# 0                     상호     VOC유형대     VOC유형중     VOC유형소  ...       계약종료일
# 1            BBQ 동서울터미널점      변경/조회         정지       일시정지  ...         NaN
# 2           (주)필드나인(OCT)      변경/조회         정지       일시정지  ...         NaN
# 3  아이큐브온(GiGAeyes guard)      변경/조회         정지       일시정지  ...         NaN
# 4            인셀덤포천대리점-뷰N      변경/조회         정지       일시정지  ...         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G      4대지악유무
# 1          NaN           0        영업본부        리텐션팀          N2           N
# 2          NaN           0        영업본부        리텐션팀          N2           N
# 3          NaN           0        영업본부        리텐션팀          N2           N
# 4          NaN           0        영업본부        리텐션팀          N2           N
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0        관리본부        관리지사   방문활동 완료여부
# 1     강북/강원본부        강북지사         NaN
# 2     강북/강원본부        강북지사         NaN
# 3     강북/강원본부        강북지사         NaN
# 4     강북/강원본부       의정부지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091605908.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1     미접수          N   30622535   51298857   61601670    (주)덕화빌*
# 2    처리완료          N   30615555   51286410   61584253        맹지*
# 3    처리완료          N   30360656   51702008   62442298         조*
# 4     미접수          N   30267716   50609928   60742602        황신*
#
#                          Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                                상호     VOC유형대     VOC유형중     VOC유형소  ...
# 1                              덕화빌딩      변경/조회         정지       일시정지  ...
# 2                         홍루이젠신원마을점      변경/조회         정지       일시정지  ...
# 3  월드타워건설(11차현장사무실)(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 4                 국수나무사가정점(kt DVR뷰)      변경/조회         정지       일시정지  ...
#
#   Unnamed: 31  Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0       계약종료일  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G
# 1         NaN          NaN           0        영업본부        리텐션팀          N2
# 2         NaN          NaN           0        영업본부        리텐션팀          N2
# 3         NaN          NaN           0        영업본부        리텐션팀          N2
# 4         NaN          NaN           0        영업본부        리텐션팀          N2
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0      4대지악유무        관리본부        관리지사   방문활동 완료여부
# 1           N     강북/강원본부        강북지사         NaN
# 2           N     강북/강원본부        고양지사        해당없음
# 3           N     강북/강원본부        고양지사        해당없음
# 4           N     강북/강원본부        강북지사         NaN
#
# [5 rows x 41 columns]
# D:\시설\정지\정지VOC\VOC정보조회-20250114-091620870.xls 데이터 미리보기:
#    VOC정보조회 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      상태       지령여부       고객번호       계약번호      서비스번호        고객명
# 1    처리완료          N   30748859   51519711   62050118        정준*
# 2    처리완료          N   30494659   51629167   62284212        김상*
# 3    처리완료          N   30494659   51613762   62250499  (주)하이드어웨*
# 4    처리완료          N   30494659   51370103   61737093  (주)하이드어웨*
#
#                       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                             상호     VOC유형대     VOC유형중     VOC유형소  ...
# 1  새김아트(한국전각예술원)(GiGAeyes guard)      변경/조회         정지       일시정지  ...
# 2                (주)하이드어웨이-장곡리창고      변경/조회         정지       일시정지  ...
# 3           (주)하이드어웨이-장곡리창고(OCT)      변경/조회         정지       일시정지  ...
# 4         (주)하이드어웨이(분수리2창고)(OCT)      변경/조회         정지       일시정지  ...
#
#   Unnamed: 31  Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0       계약종료일  월정료(VAT미포함)        접수횟수          본사           팀       P/N/G
# 1         NaN          NaN           0        영업본부        리텐션팀          N2
# 2         NaN          NaN           0        영업본부        리텐션팀          N2
# 3         NaN          NaN           0        영업본부        리텐션팀          N2
# 4         NaN          NaN           0        영업본부        리텐션팀          N2
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0      4대지악유무        관리본부        관리지사   방문활동 완료여부
# 1           N     강북/강원본부        중앙지사         NaN
# 2           N     강북/강원본부        고양지사        해당없음
# 3           N     강북/강원본부        고양지사        해당없음
# 4           N     강북/강원본부        고양지사        해당없음
#
# [5 rows x 41 columns]
# 병합된 파일이 D:\시설\정지\정지VOC\정지VOC분석병합2023-20250113.csv에 저장되었습니다.

# %%
import pandas as pd
import glob
import os

# 폴더 경로 설정
folder_path = r'd:\면제분석1111'

# 모든 파일 경로 가져오기
all_files = glob.glob(folder_path + "/*.xls")

# 모든 파일을 읽어 데이터프레임으로 병합
all_data = pd.DataFrame()

# 각 파일의 데이터를 확인하면서 병합
for file in all_files:
    try:
        # HTML 형식으로 파일 읽기
        df_list = pd.read_html(file)
        df = df_list[0]  # 첫 번째 테이블만 사용
        print(f"{file} 데이터 미리보기:\n", df.head())  # 각 파일의 데이터 확인
        all_data = pd.concat([all_data, df], ignore_index=True)
    except Exception as e:
        print(f"파일을 읽는 중 오류 발생: {file}, 오류: {e}")

# 병합된 데이터를 csv 파일로 저장 (CP949 인코딩 적용)
output_path = folder_path + "/면제병합1112.cs"
if not all_data.empty:
    all_data.to_csv(output_path, index=False, encoding='cp949')
    print(f"병합된 파일이 {output_path}에 저장되었습니다.")
else:
    print("병합된 데이터가 비어 있습니다. 엑셀 파일들을 확인하세요.")
# Out:
# 병합된 데이터가 비어 있습니다. 엑셀 파일들을 확인하세요.

# %%
import pandas as pd
import glob
import os

# 폴더 경로 설정
folder_path = r'D:\시설\정지\정지VOC'

# 모든 파일 경로 가져오기
all_files = glob.glob(folder_path + "/*.xls")

# 모든 파일을 읽어 데이터프레임으로 병합
all_data = pd.DataFrame()

# 각 파일의 데이터를 확인하면서 병합
for file in all_files:
    try:
        # HTML 형식으로 파일 읽기
        df_list = pd.read_html(file)
        df = df_list[0]  # 첫 번째 테이블만 사용
        print(f"{file} 데이터 미리보기:\n", df.head())  # 각 파일의 데이터 확인
        all_data = pd.concat([all_data, df], ignore_index=True)
    except Exception as e:
        print(f"파일을 읽는 중 오류 발생: {file}, 오류: {e}")

# 병합된 데이터를 csv 파일로 저장 (CP949 인코딩 적용)
output_path = folder_path + "/정지VOC분석병합2023-20250113.cs"
if not all_data.empty:
    all_data.to_csv(output_path, index=False, encoding='cp949')
    print(f"병합된 파일이 {output_path}에 저장되었습니다.")
else:
    print("병합된 데이터가 비어 있습니다. 엑셀 파일들을 확인하세요.")
# Out:
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091240124.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091310381.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091330622.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091347092.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091404008.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091431369.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091440382.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091459033.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091516185.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091532514.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091551197.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091605908.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 파일을 읽는 중 오류 발생: D:\시설\정지\정지VOC\VOC정보조회-20250114-091620870.xls, 오류: Missing optional dependency 'html5lib'.  Use pip or conda to install html5lib.
# 병합된 데이터가 비어 있습니다. 엑셀 파일들을 확인하세요.
