# %%
<!DOCTYPE html>
<html lang="ko">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>현장방문 FAQ</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
        }
        h1, h2, h3 {
            color: #333;
        }
        ul {
            list-style-type: none;
            padding-left: 1em;
        }
        ul li::before {
            content: "• ";
        }
        .section {
            margin-bottom: 2em;
        }
    </style>
</head>
<body>
    <h1>현장방문 FAQ</h1>

    <div class="section">
        <h2>프로세스</h2>
        <ul>
            <li>정해진 절차가 있나요?</li>
            <ul>
                <li>지사별 할당된 고객시설에 방문 → GiGAeyes 자동출금이체 신청서 작성, 상품전환 및 고객 Care활동</li>
            </ul>
            <li>어떤 고객이 현장방문 대상인 건가요?</li>
            <ul>
                <li>고객 Care가 우선적으로 필요한 관리고객(필수), 법인(권장), 고ARPU(권장)</li>
            </ul>
            <li>왜 GiGAeyes 이용요금 자동출금이체 신청서를 작성받아야 하나요?</li>
            <ul>
                <li>KT OCT 사업이 KT에서 KTT로 일원화되며 출금주체도 변경됩니다. 이에 Care가 우선적으로 필요한 "관리고객(필수), 법인(권장), 고ARPU(권장)" 대상으로 우선적으로 자동출금이체 신청서를 작성받는 것입니다.</li>
            </ul>
            <li>어떤 내용에 대한 GiGAeyes 이용요금 자동출금이체 신청서를 받는 건가요?</li>
            <ul>
                <li>KT OCT가 KT와 KTT 그룹공동상품에서 KTT 단독 상품이 됨에 따라, 청구주체가 KTT로 변경된다는 것에 대한 출금동의를 받는 것입니다.</li>
            </ul>
        </ul>
    </div>

    <div class="section">
        <h2>상품전환</h2>
        <ul>
            <li>상품전환을 제안해야 하는 이유와 상품전환 정책이 궁금합니다.</li>
            <ul>
                <li>KT OCT는 L형 상품으로 kt텔레캅이 유지관리하고 있으나, 제조사 App을 사용하고 있습니다. KTT 단독 사업시 관리의 효율성을 제고하기 위해 통합App을 이용할 수 있는 KTT L형 상품(view, Guard)으로 변경할 필요가 있으며, 월정료 2개월 면제(비연속/13,25개월차) 적용됩니다.</li>
            </ul>
        </ul>
    </div>

    <div class="section">
        <h2>고객 공지내용</h2>
        <ul>
            <li>고객님께 보냈던 문자는 어떤 내용인가요?</li>
            <ul>
                <li>고객님께서 현재 이용중이신 서비스가 KT와 KTT가 공동으로 제공하던 서비스였으나, 더 나은 서비스 제공과 고객님의 상담업무 편의를 위해 사업 통합 준비 중에 있다는 내용입니다. 현재 이용하고 계신 서비스에서 변경되는 사항은 없습니다. (상품전환 할 경우 사용하시고 계신 제조사 App대신 통합App을 다운받으셔야 합니다.)</li>
            </ul>
            <li>서비스를 제공하는 회사가 KT에서 KTT로 바뀐 게 맞냐는 고객문의에는 어떻게 답변해야 하나요?</li>
            <ul>
                <li>답변예시 : "KT와 KTT가 공동으로 서비스를 제공하고 있었으나, 더 나은 서비스를 제공하기 위해 사업이 KTT로 통합되었습니다."</li>
            </ul>
            <li>고객이 사업이관 안내문자를 받지 못했다고 하면 어떻게 안내하면 되나요?</li>
            <ul>
                <li>고객 정보 변경시 회사에 정보현행화를 위해 고객님이 고객센터로 직접 변경 요청주셔야 하는 것이라고 안내</li>
            </ul>
            <li>앞으로 문제가 발생할 경우, 고객이 어디로 문의하면 되는 건지?</li>
            <ul>
                <li>KT OCT는 사업이관 이전, 이후 동일하게 KTT고객센터(1588-0112)로 문의</li>
            </ul>
        </ul>
    </div>

    <div class="section">
        <h2>서비스 관련</h2>
        <ul>
            <li>KTT로 통합되면 카메라나 서비스 어플리케이션(App/Web) 신규 설치가 필요한가요?</li>
            <ul>
                <li>서비스 변경사항은 없기 때문에 기존에 사용하시던 방식 그대로 이용이 가능합니다. 다만, 상품전환의 경우 기존에 사용하던 제조사 App을 지우고 KTT가 유지관리하는 통합 App을 새로 설치해야 합니다.</li>
            </ul>
            <li>기존에 재약정할인, 인터넷 결합할인을 받던 고객은 어떻게 되나요?</li>
            <ul>
                <li>기존 할인 정책은 그대로 유지되며 현재 할인 받고있는 요금 그대로 이용 가능합니다.</li>
            </ul>
            <li>사업이관 이후에도 기존에 저장된 영상데이터 보관은 안전한가요?</li>
            <ul>
                <li>고객님 댁내의 영상장치에 영상이 저장되기 때문에, 사업통합과 관련하여 영상이 삭제되지 않습니다.</li>
            </ul>
            <li>서비스 통합으로 인해 일시적인 중단이나 서비스 장애가 발생하나요?</li>
            <ul>
                <li>서비스 영향은 없습니다.</li>
            </ul>
        </ul>
    </div>

    <div class="section">
        <h2>해지</h2>
        <ul>
            <li>고객이 해지요청할 경우 어떻게 하면 되나요?</li>
            <ul>
                <li>기존 해지절차와 동일하며, 해지방어 및 상품전환 제안 후에도 해지요청한다면 해지처리 및 해지위약금(공사비/철거비위약금) 면제 안내 (※ 해지 후 신규 실적 인정)</li>
            </ul>
            <li>해지 시 실적인정 여부가 궁금합니다.</li>
            <ul>
                <li>해지, 신규 실적 모두 인정</li>
            </ul>
            <li>KTT로 통합되면 서비스를 이용할 계획이 없습니다. 해지 및 보상 정책은 어떻게 되나요?</li>
            <ul>
                <li>서비스 통합(개인정보 이전) 미 동의하신 고객분들께서는 위약금 없이 서비스 해지가 가능하며 별도 보상 정책은 없습니다.</li>
            </ul>
            <li>해지 시, 저장된 영상 데이터는 보존/다운로드 기간이 어떻게 되나요?</li>
            <ul>
                <li>서비스 해지시 장비철거를 진행하므로 영상데이터를 보존하지 않으며, 녹화영상 다운로드는 고객님께서 USB 등 저장장치로 직접 받으셔야 합니다.</li>
            </ul>
            <li>서비스 품질에 불만이 있었는데, 부분적으로 환불받을 수는 없나요?</li>
            <ul>
                <li>원칙적으로는 불가하나, 한번 해지방어 후에도 해지요청시 해지 접수 진행 (* 사유 : 서비스 품질불만)</li>
            </ul>
            <li>해지신청이 누락된 것 같다는 문의에는 어떻게 대응하면 되나요?</li>
            <ul>
                <li>해지누락 등 요금조정 신청은 KTT 사업부서로 기존 요금조정 프로세스 준용 (사업이관일인 11.01일 전까지 나간 금액은 KT에서 환급이 이루어지며, 사업이관일 이후부터 나가는 금액은 KTT에서 요금조정 진행됩니다.)</li>
            </ul>
        </ul>
    </div>
</body>
</html>
# Out:
#   Cell In[1], line 17
#     padding-left: 1em;
#                   ^
# SyntaxError: invalid decimal literal
