# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
sns.histplot(tips['total_bill'], kde=True)
plt.show()

# %%
# KDE 플롯 그리기
sns.kdeplot(tips['total_bill'], shade=True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22496\4236165089.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
sns.histplot(tips['total_bill'], kde=True, color='blue')
plt.title('Total Bill Distribution')
plt.xlabel('Total Bill ($)')
plt.ylabel('Frequency')
plt.show()

# %%
print("총 지불금액(total_bill)의 평균:", tips['total_bill'].mean())
print("총 지불금액(total_bill)의 중앙값:", tips['total_bill'].median())
# Out:
# 총 지불금액(total_bill)의 평균: 19.78594262295082
# 총 지불금액(total_bill)의 중앙값: 17.795

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='pastel')
plt.title('Total Bill by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22496\2665664660.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=tips, palette='pastel')

# %%
weekday_analysis = tips.groupby('day')['total_bill'].describe()
print(weekday_analysis)
# Out:
#       count       mean       std   min      25%    50%      75%    max
# day
# Thur   62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11
# Fri    19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat    87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun    76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
# C:\Users\User\AppData\Local\Temp\ipykernel_22496\30389721.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weekday_analysis = tips.groupby('day')['total_bill'].describe()

# %%
sns.scatterplot(x='total_bill', y='tip', hue='day', data=tips, palette='viridis')
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill ($)')
plt.ylabel('Tip ($)')
plt.legend(title='Day')
plt.show()

# %%
correlation = tips[['total_bill', 'tip']].corr()
print("총 지불금액과 팁 간 상관계수:")
print(correlation)
# Out:
# 총 지불금액과 팁 간 상관계수:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
corr_matrix = tips.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 corr_matrix = tips.corr()
#       2 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#       3 plt.title('Correlation Matrix')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
print("강한 양의 상관관계 변수:")
print(corr_matrix[(corr_matrix > 0.5) & (corr_matrix != 1)])
# Out:
# 강한 양의 상관관계 변수:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 print("강한 양의 상관관계 변수:")
# ----> 2 print(corr_matrix[(corr_matrix > 0.5) & (corr_matrix != 1)])
#
# NameError: name 'corr_matrix' is not defined

# %%
sns.pairplot(tips, hue='day', palette='muted')
plt.show()
